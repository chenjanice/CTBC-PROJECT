# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# # Dataroma
#
# https://www.dataroma.com/m/holdings.php?m=psc
#
# https://www.dataroma.com/m/holdings.php?m=LMM
#
# ### Target
#
# 1. Track holding history automatically.
#
# 2. Grab the weights from the table, and transform it into a usable dataframe in R

# %%
import requests
from bs4 import BeautifulSoup
import sys
import codecs
#from selenium import webdriver
#from selenium.webdriver.support.ui import WebDriverWait
#from selenium.webdriver.common.keys import Keys
import requests
import time
from fake_useragent import UserAgent
import csv
import pandas as pd
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.25.9) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %% [markdown]
# ### Super Investors
#
# https://www.dataroma.com/m/managers.php
#
# e.g.
# https://www.dataroma.com/m/holdings.php?m=tp
# https://www.dataroma.com/m/hist/p_hist.php?f=tp
#
#
# https://www.dataroma.com/m/holdings.php?m=AV
# https://www.dataroma.com/m/hist/p_hist.php?f=AV

# %%
#Use fake UserAgent
def set_header_user_agent():
    user_agent = UserAgent()
    return user_agent.random

#open browser #打開瀏覽器，但不要載入圖片
#options = webdriver.ChromeOptions()
#prefs = {
#    'profile.default_content_setting_values': {
#        'images': 2,
#        #'javascript': 2
#    }
#}
#options.add_experimental_option('prefs', prefs)

#driver = webdriver.Chrome('./chromedriver', chrome_options=options)


#define urls
user_agent = set_header_user_agent()
super_investor_url = 'https://www.dataroma.com/m/managers.php'
res = requests.get(super_investor_url, headers={ 'user-agent': user_agent })

#res
soup = BeautifulSoup(res.text, 'html.parser')

# %% [markdown]
# ### Get All Investors ID

# %%
links = soup.find_all("a")

# %%
IDs = []
for link in links:
    #print(link.text, link['href'])
    if "holdings" in link['href']:
        IDs.append(link['href'])
        #print(link['href'])

# %%
investor = []
for ID in IDs:
    investor.append(ID.split(sep = '=')[1])
print(investor)
# Out:
# ['AIM', 'AV', 'GFT', 'psc', 'LMM', 'HRSVX', 'oaklx', 'fairx', 'ic', 'ARFFX', 'DJCO', 'tci', 'SA', 'cfimx', 'AC', 'tp', 'abc', 'GLRE', 'MAVFX', 'WP', 'AM', 'DODGX', 'YAFFX', 'EL', 'FPPTX', 'ca', 'CCM', 'aq', 'SSHFX', 'oc', 'FEVAX', 'LUK', 'VA', 'CAAPX', 'KB', 'mc', 'oa', 'MPGFX', 'hcmax', 'LLPFX', 'MVALX', 'SAM', 'MFP', 'PI', 'TF', 'DA', 'FFH', 'pzfvx', 'OFALX', 'TORYX', 'jensx', 'SEQUX', 'lmvtx', 'BAUPOST', 'LPC', 'FPACX', 'FS', 'TA', 'MKL', 'GR', 'TVAFX', 'TWEBX', 'WVALX', 'BRK', 'cc']

# %% [markdown]
# # Loop: 把Super Investors各季的權重抓下來
#
# 1. 依據Super Investor頁面找到的縮寫來跑迴圈
#
# 2. 每一個super investor會有一張weighting matrix
#
# 3. 每一個matrix的row都是season, col是個股名稱
#
# 4. unique_spam是一個dictionary，key是investor的縮寫，value是他的股池

# %% [markdown]
# # remark
#
# * 2020.05.14 更新
#
# 將權重的名稱簡化，如`BRK.A`, `BRK.B`都會變成`BRK`
#
# 如果簡化前和後的權重都存在，則將cell的值相加，再將column name簡化成`BRK`

# %%
#define urls
url = "https://www.dataroma.com/m/hist/p_hist.php?f=" #holding history prefix+ID

unique_spam = {} #存dataroma上所有出現過的股票名稱

#對每個投資人跑找權重
for inv in investor:
    investor_url = "https://www.dataroma.com/m/hist/p_hist.php?f="+inv


    user_agent = set_header_user_agent()
    res = requests.get(investor_url, headers={ 'user-agent': user_agent })
    #res
    soup = BeautifulSoup(res.text, 'html.parser')
    
    #拿Table
    table = soup.find_all('table')
    df = pd.read_html(str(table))[0]
    
    #把period當作index
    df.set_index("Period", inplace = True)

    #type(df.iloc[2][1]) #是str
    #stock_name = testrow.split()[0] #先用空格split
    #print(stock_name) #拿到個股名稱

    #拿個股權重    
    #先做一個有各個股票名稱作為col的array
    #所以要先取出所有的個股名稱存起來在一個list裡，再取unique

    stock_names = []
    for i in range(0,df.shape[0]): #在row裡
        for j in range(0,df.shape[1]): #在col裡
            obs = df.iloc[i][j]       # i-th j-th obs
            try:
                stock_name = obs.split()[0] #用空格分隔後的第一個即是個股名稱
                stock_names.append(stock_name)
            except:
                continue
    uni_names = pd.unique(stock_names)
    uni_names.sort()
    #print(uni_names)

    #排序
    uni_names = uni_names[uni_names>="A"]

    print("The following stocks are hold by: "+inv, end = '\n')
    for i in range(0, len(uni_names)):
        print(uni_names[i], end = ' ')
    print("\n")
    unique_spam[inv] = uni_names #把某個投資人的股池放進對應的dict
        
    #創造很多dict
    names = locals()
    for stock_nam in uni_names:
        names["dict_%s" % stock_nam] = {}
    
    
    #assign dictionary
    names = locals()
    for stock_nam in uni_names:
        names["dict_%s" % stock_nam] = {}

        #前是row, 後是col
        for row in range(0, df.shape[0]):    
            for col in range(0, df.shape[1]):
                try: #因為可能碰到NaN
                    if stock_nam == df.iloc[row][col].split()[0]: #如果stock_nam這個string在某個cell裡
                        testrow = df.iloc[row][col] #為了拿到數值部分
                        test_wei = testrow.split()[-3].split('%')
                        test_wei = test_wei[0][-5:]
                        try: #因為可能取到只有個位數的weight
                            test_wei = float(test_wei)
                        except: #那就退一位數
                            test_wei = test_wei[-4:]
                            test_wei = float(test_wei)

                        names["dict_%s" % stock_nam][row] = test_wei#把數值當作value新增至字典，這時key是所在的row
                except:
                    continue
                    
    dict_stock = [] #list of dictionaries
    dict_stock_str = [] #list of dictionary names, are strings

    for stock_nam in uni_names:
        dict_stock.append(names["dict_%s" % stock_nam]) #把dictionary存進list裡面
        dict_stock_str.append(stock_nam) #存的是字串名稱

    #df_weight = pd.DataFrame(dict_stock) #相當於 pd.DataFrame([dict_1, dict_2]) 這樣的寫法
    df_weight = pd.DataFrame.from_dict(dict_stock)
    df_weight = df_weight.T #因為是by row的加進dataframe裡，所以要transpose

    #rename columns
    df_weight.columns = dict_stock_str
    
    #rename
    rownames = df.index.tolist()
    
    #make a dict of row names
    row_name_dict = {}
    for i in range(0, len(rownames)):
        row_name_dict[i] = rownames[i]
    df_weight = pd.DataFrame.rename(df_weight, index= row_name_dict)
    df_weight.head()
    
    #rename columns again:如果遇到"."或者"-"就刪掉
    #遇到同名則合併
    for col in df_weight.columns:
        if "." in col:
            new_col = col.split(sep = '.')[0]
            if new_col in df_weight.columns: #如果去掉標籤的舊名有在原本的colnam中，代表需要加在一起
                df_weight[new_col] = df_weight[new_col]+df_weight[col]
                df_weight.drop(col, axis = 1, inplace=True) #把舊名丟掉
            else: #直接把colnam換掉
                df_weight.rename(columns={col:new_col}, inplace=True) #直接重新命名
        elif "-" in col:
            new_col = col.split(sep = '-')[0]
            if new_col in df_weight.columns: #如果去掉標籤的舊名有在原本的colnam中，代表需要加在一起
                df_weight[new_col] = df_weight[new_col]+df_weight[col]
                df_weight.drop(col, axis = 1, inplace=True) #把舊名丟掉
            else: #直接把colnam換掉
                df_weight.rename(columns={col:new_col}, inplace=True) #直接重新命名
    
    file_name = "super_investors/"+inv+"_weight.csv"
    df_weight.to_csv(file_name, index=True)
# Out:
# The following stocks are hold by: AIM
# ABG ACM ADNT ADT AGCO ALK APTV ARRS ASH ATI AVT AXE AXL AXLL AXTA AYI BDC BGC BHI BW BWXT CAG CAH CAM CBT CCK COMM CPRI CR CSC CSX CTB CW CYT DAN DBD DRC DXC EMN ENR FLEX FLS FMC FTI GDI GEO GPI GPK GRA GT HAR HII HPE HPQ HSC HUN IGT IM IP IPGP ITT JOY KEX KFY KLXI KMT KS LEA LEN LSKD MAS MGA MHK MOS MRC MTW MU MWA NAV NCR NOMD NOV NSC NWSA ODP OI OIS OSK PAY RHI RL ROC RRD SCS SEE SJM SPLS SPR SPXC TAM TECD TEN TEX TGI TIF TKR TSLA TTM TW-OLD UNF VC VEC WCC WFT WRK XLS ZTO
#
# The following stocks are hold by: AV
# AAP ADS AN ARES AWI BAC BRK.A BRK.B CHEF CHRW CHTR CMPR CPRT CVET DFZ DNOW DSWL DTV FFH FL FWONK GLIBA GRUB HBI HEI IBKR IBM INWK JEF LB LBTYK LTRPA MCO MNRO MSM OUTR RAVN RBA RCII RUE SAM SAVE SD SNE SPB ST TAP TRIP VIAB VMI W WFC XPO XRAY Y
#
# The following stocks are hold by: GFT
# AAPL ABT ADM AMX AMZN AN APD ARCO BABA BAX BP BRK.B BYND CAT CCI CNI CNR COST CSX CX DDAIF DMND ECL EXPD FDX FMX GOOG GOOGL GS JNJ KO KOF LBTYA LBTYK LILA LILAK MCD MRK MSFT MTB PFE PG RSG SDGR SGP TM TSCO TTF TV TYC UPS WBA WM WMT WYE XOM XTO
#
# The following stocks are hold by: psc
# A ACT ADP AGN AIG AIV ALEX ALX APD BEAM BGP BHC BKS BKW-OLD BRK.B BX C CBY CEN CMG CP CSG CXW DPS EMC FBHS FDO FO GGP GLRE GM H HHC HLT HME JCP LDG LNY LOW MA MATX MCD MDLZ NKE NOMD PAH PG PK QSR RTX SBUX SHLDQ SKS SPLS TGT V WB-OLD WEN YUM ZTS
#
# The following stocks are hold by: LMM
# AAL ADT ALXN AMZN AVP BABA BAC BHC BHF C CELG CTL DAL DISCA EIGI ENDP FB FCAU FL FLXN FTCH GILD GME GNW GOOGL JPM JPM.WS KBH LEN MED MNK MTG MU NXPI OMF P PAH PHM PTON QUOT RH TEVA TMHC TVTY TWTR UAL W XON
#
# The following stocks are hold by: HRSVX
# AA ABB ABT ADM ADT ADTN AEO AGCO AGU AIN ALK ALL AMH APC ATMI AUQ AVD AVT AXP BAC BAX BBT BCC BEN BG BHE BHI BK BKH BPFH BRK.B BSX BXS CA CALM CAT CBWBF CCG CLD CNI COF COP COV CSCO CVS DGX DLR DNB DOW DVN EME EMR ENDP ENH EQC ESRX ETR EXC FDX FE FFH FLR FLS FN FRX FSP FTO GE GL GLT GOOGL GR GRS GTS GW HAR HE HES HRB HRL HSP HTCH HUM IAG INTC IRC IVC JBHT JBLU JCI JNJ JOY KBR KEX KMT KSS KSU LPNT LUV LXU MAN MCRL MDU MHK MI MOS MRO MS MTZ MUSA OMI ORCL OSG OSK PFE PFG PG PLAB PLXS PNC PNM PNR PSO PTEN PWR R RCII RCL RFMD RHI RJF RPM RTI SAWLF SCHW SFD SFY SIGI SLB SM SNY STI STNG STX STZ SU SUG SWKS SWY T TDW TEG TEL TEVA TFC TKR TT TYC UFPI UGI ULTR UNM UNT URS USTR UVV VAL VZ WAFD WBA WERN WFC WFR WLTW WMS-OLD WMT WPS WPX WYE XEC XOM XRAY ZBH ZION
#
# The following stocks are hold by: oaklx
# AAL ADNT AIG ALLY AMZN APA APC BAC BBY BEN BKNG BMC BMY C CBRE CHK CHTR CMCSA COF CPN CVE CXO DELL-OL DISCA DISCK DNB DTV EBAY EOG FB FCAU FDX FNF FRX GE GOOG GOOGL GPS HD HLT HOG HRB IMS INTC JPM KMT LEA LMDIA LNKD LTD MA MAT MCD MDT MGM MON MS NFLX NFX ORCL PHM QRTEA REGN S SGP STZ TEL TRW TWX TXN VIAB WFT WM-OLD WU XRX YUM
#
# The following stocks are hold by: fairx
# AAIGF ACF AIG AIG.WS ANTM ASA AXP BA BAC BAC.WS.A BAC.WS.B BAM BMY BNI BRK.A BRK.B C CHK CHPXF CIT CLMT CLPR CMCSA CMCSK-OLD CNQ CSCO DISH DJCO DNOW DUK EMN ESVIF FCX FMCC FNMA FRX FSUMF FUR GD GE GGP GS HOFD HRG HTZ HUM IBM IDT IDT.B IDT.C IPMLF JEF JEF-OLD JOE JZEOF KHC LE MBI MHK MMC MRC MS MWA MWA.B MYL NOC NOV OAK OBE OSH OXY PD PFE RF RRR SATS SE-OLD SHLD.WS SHLDQ SHOS SPB SPG SPR SRG SRSC T UNH URI USG USMO VST VSTO WCG WES WPG WTM XTO
#
# The following stocks are hold by: ic
# AAPL AFSI AGN AIG ARII CHK CI CLDR CNDT CVI CVRR CZR DELL DELL-OL DK DVMT EBAY EGN ENZN FANG FCX FDML FRX GCI HAIN HLF HOLX HPQ HRI HTZ IEP LNG MENT MTW NAV NFLX NUAN NWL OXY PYPL RIG SD SSE TEN TGNA TLM TTWO VLTC VMW WBMD WBT XRX
#
# The following stocks are hold by: ARFFX
# ABT ACN AFL APA APOL ATGE AXE AXP BAX BBBY BDK BEN BK BOKF BRK.B BWA BX C CAH CBS CCL CHK COV CVS DELL-OL DIS DTV EBAY FAF GCI GOLD GS HD HES HEW HNGR HRB HSP IBM IGT IMS IPG ITW JNJ JPM KKR KMT LAZ LH LMT LOW MOS MRK MS MSFT NLSN NOV NTRS NWL OMC ORCL PFE PGR PIR SJM SNA SRCL STJ STZ SWK TGT TIF TM TYC UBS USG VIAB VIAC WBA WM WU XOM ZBH ZBRA
#
# The following stocks are hold by: DJCO
# BAC PKX USB WFC
#
# The following stocks are hold by: tci
# AABA ABKFQ ADBE ADSK AMZN ANTM AXP AY BIDU CHTR CMCSA CNI CP EFX FOX FOXA FWONK GOOG GOOGL LNAGF MA MCO MON MSFT NOC NSC PCG RTN SPGI TDG TWC TWX UNP UNVR V YHOO
#
# The following stocks are hold by: SA
# ALK AVX AXP BRK.A BRK.B CKH CMI COST DG DIS EQNR GG GPC HXL KGC MCY MRK NEM NKE NXPI OLN SBUX SNY SWKS TRV USG XOM Y
#
# The following stocks are hold by: cfimx
# AAIGF ADNT AET AIG AMAT AMP AMZN APA AXP BABA BAM BBBY BK BRK.A CFG CNQ COF COG COP COST COV CVS DEO DGX EDU ESRX FB GE GOOG GOOGL HCMLF HOG HPQ IBM INTC IRM JBHGF JCI JNJ JPM KMX KO L LBTYK LFGEF LH LVS MEL MER MKL MO MON MRK MSFT NPPKF NPSNY NWSA OAK OVV OXY PG RE RHHVF RHJIF RTX RWT S SAFRY SCHW SYY TEL TKOMY TRH TXN TYC UNH USB WB-OLD WFC WMT WOSCF Y
#
# The following stocks are hold by: AC
# AAPL ADBE ALRM AMT AMTD ANSS ARO BAC BAM BDX BRK.A BRK.B BYI CFX CSGP CSX DG DHIL DHR DISCA DLTR DTV EQIX ESGR FDS FOCS FTV GSHD HIG JEF KKR KMX LAMR LKQ LPLA LYV MA MBRG MCO MKL MNRO MSCI MWE NDN NLY NS OLLI ORLY OXPS PENN PRMW ROP ROST RVR SBAC SHLDQ TECH TJX TRH TROW UI V VRSK WMS-OLD
#
# The following stocks are hold by: tp
# AAL AAPL ABT ACT ADBE AET AGN AIG ALLY AMGN AMTD AMZN ANTM APC AVGO AXP AXTA BABA BAC BAX BBBY BEAV BID BKI BLK BSX BUD BURL BXLT C CB CCE-OLD CCK CELG CF CHTR CI CNC COG CPB CRM CTXS DAL DD DG DHR DIS DOV DOW DVN EA EBAY ELN EMC EQT FB FDX FIS FIVE FMC FOXA FPAC FPAC.UN GD GOOGL HTZ HUM IAA IAC ICE IP IQV JPM KHC LBTYA LBTYK LEN LNG LOW MAS MHK MON MPC MRK MS MSFT NFLX NWSA NXPI PH PSX PVTB PYPL QCOM RACE RAX ROP ROST RTX SEE SHPG SHW SJM SPGI ST STJ STZ SUNE TAP TDG TEL TIBX TIF TMO TMUS TWC TWX V VMC VZ WCC WMB WP WYNN YHOO YPF YUM ZAYO
#
# The following stocks are hold by: abc
# AABA ABG AET AGN AIG AIZ AKBA BEN BKS BMC BMY.R BNED CARS CCO CELG CLNS CNL COV CST CWH CWH-OLD DELL-OL DTV EGL ENT ESRX ETP FB GCVRZ GOOGL GPI GTIV INXN JCP KERX KMI LAD LAMR MANT MGI MSFT MTW NAVI NRF NSAM NXY OI OPB ORLY OXSQ OZM PACD PCG QCP RYAM RYN SCU SHPG SLGN SLM SPH SYT TDG TEVA TMDX TWC TWX UHAL VEON WAIR WBT WEN WFC WLTW WU
#
# The following stocks are hold by: GLRE
# AABA AAPL ACM ADNT ADP AER AET AGN AGNC AGR AHL AHMIQ AMAT AMP ANTM APC ATUS AXP AYE BAGL BBY BDX BHF BIOF BJS BK BOL BP BRK.B BSC BSX BWXT CAH CBI CBS CC CCK CCR CEIX CF CFG CFN CHNG CI CIT CNC CNDT CNW CNX COMM CONN COV CPN CPRI CSC CVEO CVH CVS DAN DBI DDS DELL-OL DFS DHR DIS DLPH DOW DOX DPS DST DXC EIG EMC EPL FDC FICC FLML-OLD FOXA FSC FWLT FWONA GFG GM GNW GRBK GS GTS HAR HCA HES HEW HGV HII HLX HMA HNT HPE HSP HTS HUM IAC ICO IPCR KAR KBR KEYS KGC LBTYA LBTYK LM LRCX LTM-OLD LYB M MDC MDCO MDR MERC MIM MO MON MRVL MSFT MU MYL NBSE NCR NEW NOV NVR OAK OI OIS ON PAYX PCX PFE PLCE PRGO PTEN RAD RAH RE RJET RSYS S SAI SATS SCT SDRL SFLY SGMS SHW SPR STX SUNE SYT TDC TGP TGT TKTM TPX TRH TRV TSCO TSG TTWO TWTR TWX TX UHAL UIL UNH URS USBE VAL VMED VOYA VR WBA WFR WLT WNG WPX WU WYE XELT XRX YELP YHOO
#
# The following stocks are hold by: MAVFX
# AA AAPL ABBV ADI ADM AIG AXP BAC BBT BK BMY C CB CBS CCL CMCSA CMCSK-OLD COF COP COV CSCO CVS CVX DD-OLD DELL-OL DG DIS DVN EBAY EMR ETN FB FDC FDX GE GENZ GILD GLW GOOG GPS GS HOLX HPQ HRS INTC JCI JNJ JPM K MCD MDLZ MEDI MER MET MMM MS MSFT MWW NVLS-OLD OXY PEP PFE PG QCOM RTX SBL SCHW SLB SPGI SPLS STJ STT TDW TEL TEVA TMO TWX TYC VIAB VIAC VLO VOD VSH WBA WFC WMT WU WYE ZBH
#
# The following stocks are hold by: WP
# AAPL ALC AXP BKNG BMY BRK.B CDW CELG CHRW CLB CMI CPRT CTSH EA EMC ESRX EW EXPD FAST FB FLT GILD GOOG GOOGL ISRG KEYS KHC LKQ MJN MSFT MSI MTB NOV NVDA ODFL PRGO PYPL QCOM ROST SBUX SCHW SLB SPGI SRCL TEVA THS TJX TPR TSCO ULTA USB V VAR VRSK
#
# The following stocks are hold by: AM
# AABA AAL AAPL ADBE AGN AIG ALL ALLY AMAT AMLP AMR AMZN APA APC AVGO AXLL AY BA BABA BAC BBT BC BEE BKNG BRCM-OLD BSX BZH C CBI CBS CCI CF CFG CHK CLMT CNC CNO COF COOP COP CRM CSCO CVI CVX CWEN CWEN.A CYH CZR DAL DAN DDAIF DDS DF DG DIS DLPH DTV DVN EMC EMN ET ETFC ETP EXP F FB FITB FLR FOXA GM GOOG GOOGL GPT GT HAIN HAL HCA HDS HFC HIG HOT HPQ HUM HUN I IP JAVA JBLU JNJ JPM KEY KLAC KMI KMT LCC LNG LO LRCX LUV M MAS MDT MEE MET MGM MHK MOS MPG MRK MRO MS MSFT MU MWA MYL NAV NFLX NRG NXPI NXY OC ODP OMX ORCL OXY PAH PCG PCX PCZ PENN PFE PHH PNC PPG PRU QCOM RAD RBS RF RIG RTH S SBAC SLM SMH STI STT SYF TERP TEVA TEX TGI TLM TMO TMUS TPX TSLA TWTR UAL UAUA UBS UNH URI USG VCI VLO VST WB-OLD WDC WFC WHR WLTW WMB WNR WPZ XL XLE XPO XTO YHOO
#
# The following stocks are hold by: DODGX
# AIG AMGN ANTM APA APC AXP AZN BAC BHI BK BMY C CAH CHTR CI CMCSA COF CSCO CVX DOW EBAY EMC ESRX FDX FOXA GE GOOG GS GSK HD HPE HPQ JCI JPM LLY MC-OLD MCD MCHP MET MOT MRK MSFT NLOK NVS NWSA OXY PFE RHHBY RTX S SCHW SLB SNE SNY TRV TWC TWX UNH UNP VOD WB-OLD WFC WMT WYE XRX
#
# The following stocks are hold by: YAFFX
# ACF AIG ANF ANTM APOL ARGKF ASBFF AVP AXP BBBY BCR BDX BK BKNG BNTGF BOIVF CHRW CL CLX CMCSA CMCSK-OLD CON.DE COP COV CSCO CTSH DELL-OL DIS DISH EBAY FBN FDC FMCC FOX FOXA FWONA GLW GOOG HD HEGIF HENKY HPQ HRB INFY IPG JNJ KO L LANC M MBI MDLZ MSFT NWSA ORCL PEP PFE PG PHM QRTEA REXI S SLM STT SYK SYY TBBK TYC TYIDF UN UNH USB USG VIAB WFT WMT WWY XOM
#
# The following stocks are hold by: EL
# ACXM AN AVP AZO BAC BIG C CIT COF CSCO CTX FNMA FOSL GNW GPS HD HIG HOS HRB HSNI IBM KBH LE NFLX OSH PHH SFI SHLD.WS SHLDQ SHOS SLM SRG SRSC STX SWY WAC WFC
#
# The following stocks are hold by: FPPTX
# AAN ACIW AGCO AGP ALGT AM-OLD AMBA APOL ARRS ARW ATGE ATW AVT BHI BIG BJS BW BWXT CAKE CC-OLD CFFN CHB CHRS CISN CNC COG CRI CUB CXG DAN DPTHL FHB FI FII FL FLE GNTX GPK HMHC HMN HP IDCC ISBC MATX MCY MKSI MTN NBL NFX NOV OSK PDE PTEN R RCII RDC ROSE ROST RS RSH SAIC SAVE SIG SM TEN THO THS TRN TWI VAL VECO VG VMI VNOM VSTO WDC XEC ZLC
#
# The following stocks are hold by: ca
# ACT ALGT ASCMA AZN BAC BAC.WS.A BB BHC BP BRK.A C CBI CHT CYD DELL-OL DVA ENDP FCAU GS GSK JPM JPM.WS LE MBI MGA NOK OSTK PKX PTGI RFP RSH RYAAY S SAVE SD SHLDQ SHOS SNY SRSC TEVA UTSI VOD VZ WFC WFC.WS
#
# The following stocks are hold by: CCM
# ACGL ADBE ADS AMGP AMX ANTM AON AR AREX AXP AXTA BAC BAM BBU BHC BHI BIP BPY BR BRK.B C CMCSA CMCSK-OLD CMPR COL DELL-OL DHI DLTR EQIX ESRX ETN FB FISV FMCC FTDR GD GOOG GOOGL GSM HAL HCA HPQ IQV IR JPM JPM.WS JW.A KMI LBTYA LBTYK LEN LEN.B LH LILA LILAK LMT LVNTA MA MCO MSFT MSI NICK NLSN ONE ORCL PCP PGR PRI RJF RNR RRC RYAAY SCHW SERV SGU ST T TDW UNH USB V VAR WAT WFC XTEX XTXI
#
# The following stocks are hold by: aq
# AXP BAC BAC.WS.A BRK.A BRK.B C DTV ENLC FCAU GM.WS.B GS MA MCO MU PKX RACE SRG TERP TOO WFC WFC.WS ZINC
#
# The following stocks are hold by: SSHFX
# A ABT ADI AER AES AET AGN AIG ALXN AMAT ANTM AON APOL AR BAC BAX BG BHI BP BRK.A BRK.B BRL BSX C CAH CB CBS CFG CI CIT CMCSA COF COP CPN CS CSCO CTXS CVS CVX DAL DD-OLD DIS DTV DUK DVN EBAY ELAN EP EQT ETN EXC FDC FLEX FLR FWONA GE GENZ GHC GM GNW GOLD GOOGL GT HES HMC HPE HSP IGT INTU IP IPG IVZ KEYS KMB KO LBTYK LEN LIFE LOW LUV LYB LYO MDLZ MET MMC MRK MRO MS MSFT NEM NLOK NVS NXPI OI ORCL OXY PFE PG PGR PNR PRGO PXD QCOM RDS.A RLGY RS RSG SABR SCHW SE-OLD SIVB SLB SNY ST STT SUN SYY TDC TMO TOT TWX TXN UN UNH UNM USB V VLO VOD VZ WBA WFT WM WMT YHOO
#
# The following stocks are hold by: oc
# AABA ABEV AIG AIQ ALLY AMX APFH APO AU AZUL BABA BANR BBD BCEI BIDU BRFS BRY CCS CEO CHTR CIT CMLS CX CXPO CZR DLPH DMND DOOR DYN EGC EGLE ETFC EURN FBP FCNCA GNRT GTY IBN INFN INFY ITUB JD LBTYA LNCE LVLT LVNTA MCF MTG MX NMIH NRG NSM NTAP ORBK ORIG PBR PCG PULS SBLK SCAI SMCI STKL STOR SWY TMHC TMS-OLD TPCO TRCO TRMD TSL TSM TTM TV VALE VICI VIV VRS VSH VST XCO YHOO
#
# The following stocks are hold by: FEVAX
# AEM ANTM APA ASCMA AXP BBT BK BLT BOL BRK.A BRO CHRW CINF CL CMCSA CMCSK-OLD CMTL CNQ COP COST CPRT CSCO CTAS DE DVN FE FLS FTI FWONA GOOGL GYI HD HP INTC ISCA JNJ LLTC LMT LO MCD MMM MSFT MUR NEM NOC NOV NTR NYT OA OMC ORCL PCL PM POT QRTEA RSTI RYN SJT SLB SNY SYF SYY TDC TFC TXN TYC UNF UNP USB UTIW VAR WLTW WMT WRB WY XLNX XOM Y
#
# The following stocks are hold by: LUK
# AABA ABBV ACCL ACF ACN ADBE AET ALA ALR APD ATVI AVGO AVY AXTA BAX BCR BF.B BHP BIIB CHTR CMCSA CME CNC CNI COL COLD COP COTY COWN CRESY CSWC CXO D DB DG DISCA DISCK DISH DRI DVMT DXC EMC EMN ENWV EQNR FANG FB FCX FDX FEIC FNB FOX FOXA FRGI FTI FWONA FWONK GD GEOI GLIBA GLPW GOLD-OLD HES HPE HPQ HRG HRS HUN IAAC IAC INTL ITC JEF-OLD JNS KEQU LBRDA LCAHW LGF.A LGF.B LONE LSXMA LSXMK LTRPA LVLT LVNTA MAM MBLY MEG MHK MLI MNRL MOMO MON MSG NDAQ NSAM NWSA NXPI NYRT PAHC PE PG PGR PVTB QCP RAD RAI REGI REGN RTLR SABR SBLK SE-OLD SIG SINA SMCG SMMX SNI SODA SPB SPNC STBZ STJ STZ SXT SYT T TA TEX TGT TPIC TRCO TTD TWX UA UNH URBN UWBK VAR VECO VLO VZ WINN WNG WPX WR WTRH XL YHOO ZBH ZEUS
#
# The following stocks are hold by: VA
# ACA ADBE ADS ADSK AES AFI AGU ALB ALSN AOS ARMK AWI AXP BCR BHC BHI BIVV BKNG BKR BP C CBRE CF COL CPWR DAR DRC EIX ES-OLD ESRX EVA EXPD FDX FNF FOX FOXA GDI HAL HE ICE INT KAR KKR LIND LKQ MCO MCRS MOS MOT MS MSCI MSFT MSI NLOK NTCT NYT OUT PCG PCP PPO PSN SLE SLM SPGI STRA STX TECH TIBX TRN TSG TW-OLD UFI VLO VRRM VRSN WCC WLTW XPO XRAY
#
# The following stocks are hold by: CAAPX
# ACN AFL ATGE AXE BAX BDK BEN BOKF BRS BWA BX CAH CBRE CBS CCL CHK CLX CRL CYN DELL-OL DNB EFX ENR FAF GCI HEW HLI HRB HSP IGT IMS IPG ISCA ITW JLL JNS JWN KEYS KKR KMT LAZ LH MAT MHK MNI MSGN NLSN NOV NTRS OMC PBI PGR SJM SNA SRCL STJ STZ SWK TIF TMO TPR TRB-OLD TROW TW-OLD VIAB VIAC WLTW WU YUM ZBH
#
# The following stocks are hold by: KB
# AGO ASTE BB BMY BP C GNE GSK HOLX IDT IDWM MBI MODL MRK NAVI NTP NVS NYCB NYT ORI PBNY PFE PTEN RFL RSTK-D SEB SLM STL STRP SYMS TPHS USG VOXX
#
# The following stocks are hold by: mc
# AAPL ABBV ADBE AER AET AGN ALNY ALSN AMZN ANDV ANTM ARMK ARRS ASH AVGO AVTR AXP BABA BHC BIDU BKNG BTI BUD CBS CCI CCK CHTR CI CIT CMCSA CNC COF COMM CPN CSC CTRX CTSH CTVA CTXS CYH DD DG DIS DLTR DOW DXC EVHC EXP FB FIS FISV FLT FOXA FTNT GOOG GPK HCA HD HUM INTC IPXL KAR KHC KKR KSU LBTYK LOW LRCX LVLT MA MCK MDCO MGM MHK MLM MNST MON MSFT MTG MU NFLX NKE NKTR NOC NRF NWL OC ONEM ORLY PANW PF PFE PM PRSP QCOM QIHU QSR RDN RL SABR SC SCHW SHPG SNAP SSNC ST STNE STZ SWI TAP TDG TMH TMUS UHS UNH USB USFD V VMC WCN WLK WP WYNN
#
# The following stocks are hold by: oa
# ABR ACT ADBE AER AGN AIG AMCX AMZN APL ASH ASPS ATLS BKNG BLL BSX C CCL CI CIM CNC COF COOP CVS CZR DD DISH DOW DVMT EBAY EMN ESRX ET ETE ETFC ETP FANG FB FDC FISV FNF FOE FOXA GCI GLPI GM GOOGL HAL HCA HES HRG HUM JPM KAR KEA KFN KMI LINE LORL LYB MCK MET MGM MMR MPC MSFT MSI MXL NAVI NBR NEWM NGLS NLSN NRG NRZ NYX OCN OMF PE PFE PFSI PVH PYPL QCOM RIG RLGY S SBGI SD SHPG SIRI SLM SNR SUNE SYF TIME TMO TRCO TRGP TRN TRWH UAL UNH VICI VVV WBA WPX XL
#
# The following stocks are hold by: MPGFX
# ABT AXP BAX BMS CEN CHRW COR DCI DIS ECL EMR FAST FISV FUL GE GGG GIS GOOG HON HRL JNJ MDT MMM MSFT MTSC NVDA PFE PFG PNR RHHBY SLB STJ TCF TECH TGT TTC UNH USB V VAL-OLD WFC ZBH
#
# The following stocks are hold by: hcmax
# AA AAPL ADBE ADP AEP AET AKAM ALD ALL AMD AMGN AMZN AXP BA BAC BBY BDX BIIB BK BMY BUD C CAT CL CMG CMP CPB CSCO CVS DD DD-OLD DHI DIS EBAY EMC EMR EPD FB FDX GE GIS GLW GPS GR GS HD HNZ HOT HPQ HST HSY IBM INTC IR JNJ JOY JPM JWN K KHC LH LLY LRCX MCD MDLZ MDT MKC MOT MRK MSFT NKE NSC NUE ODP ORCL PANL PETM PFE PG QCOM RIG ROK RTN SBUX SJM SO SPG SPLS SRCL SYY T TGT TIF TXN VZ WFC WFM WMT WU XOM YHOO YUM
#
# The following stocks are hold by: LLPFX
# ABT AGN AMG ANK AON BEN BK BRK.A BRK.B CEIX CHK CHKGF CKHUY CMCSA CNHI CNX CPB CTL CX DD DD-OLD DELL-OL DIS DTV EBAY FDX FFH FWONA GE GM GOOG H HCMLF IHG JAVA L LFGEF LMDIA LVLT MAR MAT MCD MDLZ MUR NLOK NPPKF NWSA PHG PHGFF PK PXD QRTEA RL RTX S SNI TDS TDS.S TROW TRV UBS VIVEF VMC WBA WLTW WMB WYNN YUM
#
# The following stocks are hold by: MVALX
# AAPL ABM ABT ACXM ADBE ADSK AGR AGU AIG AIN AIZ AJG ALEX AMD AMMD AMTD APA AT ATR AVA AVP AW BAX BBY BCR BDK BEAV BEC BEN BG BKC BOH BOKF BR BUD BYI C CACI CBT CCL CELG CEPH CFG CLH CMP CNW COGN COST COV CRI CRL CSCO CSL CTAS CTXS CVA CVBF CVS CVX CW DBD DENN DEO DKS DYN EA EAT EBAY EFX ENS EOG FELE FEYE FII FLIR FLO FLS FNFG FRED FST FTNT GFI GIL GMT GPK GWR GWW HAE HBI HE HEES HOLX HPY HUM HURN ICLR IFF INFA INTC IPXL IRDM JPM KBR KMB KMI KSS KW LAZ LECO LGF.B LII LIZ LKQ LLTC LOGM LVS MASI MAT MATX MDLZ MDU MLNX MOGN MON MSA MSFT MU MVL NEM NKTR NLC NLY NOK NOMD NSC NTR NUAN NVDA NWL OAK OI ORI OXY PENN PFE PGN PHG PII PLCE POWI PRGO PTV QCOM RAMP RAX RBA RBC RF RIG RYN SCHN SCS SCSS SEE SEIC SERV SHW SKX SMG SRCL STE STT SUM SWCH SWK SWY SYF SYNA SYY TAP TERP THS TOT TRMB TRV UMPQ UNP USB UTIW UVV VICI VRNT VRSN VZ WDC WFC WLTW WM WMS WWW XYL YUM ZBRA
#
# The following stocks are hold by: SAM
# AABA ALEX BA BABA BB BBBY BIIB CAH CELG CLF CNQ CPLG CVE CVET DIS DISCA FB FDX FPH GME GOOG GOOGL GSKY JBX JD MAXR MCK MHK MIK NVTRQ PETQ QRVO SPWH TLRD WDC
#
# The following stocks are hold by: MFP
# ABBC ABCW ABFS ACBI ADES ADS AIG AJRD ALC ALLY AM-OLD AMZN APC ARIA AWH AWI BAC BANC BCBP BDX BEN BG BHF BKS BLT BMCH BPOP BRK.A BSX BUD C CAB CACH CARE CBS CCE-OLD CELG CF CIT CLR CNO COLB COP COT COV CPB CWGL DAL DD DD-OLD DEST DJ DLB DO DOW ECPG ELN EMC EP EQ ESGR FARM FBTX FCE.A FLA FMC FOSL FRNK FRSH FSGI FTI GBL GENZ GLBR GLF GR GT GYI HCBK HEOP HES HPQ HRS HSP HTH HTV HURN INTC IR ISBC ITT JCP JEF JNS KALU KLXI KRNY LABC LTD MDCO MDLZ MDP MNI MOT MVC MWE NFG NODK NPK NWA NWEC OABC OGBY OKE PAA PAY PFE PM PNC RDC RF RUTH SANW SFD SHLDQ SLM SNE SPGI SYA T TCO TDS TEL TEVA TFSL TIF TOWN TPHS TRA TRB-OLD TRC TRH TT TWC TWX TYC VNO VPHM WBC WCBO WLK WMGI WSBF WWY WYE XPO Y
#
# The following stocks are hold by: PI
# AER ATSG BAC BIP BPO BRK.A BRK.B BRP C CCRT CHK CRESY CRYP CSE DTV EAF FCAU FFH GM GM.WS.B GOOG GS HNR IBKR ICO JEF LUV MU NXEO NXEOU PKX PNCL POT RACE SHLDQ SRG TECK TEX TX WFC ZINC
#
# The following stocks are hold by: TF
# ALLE BK CC DD DD-OLD FDO GE IR LM MDLZ NVT PEP PG PNR PPG SYY TIF WEN
#
# The following stocks are hold by: DA
# ANSS AVLR AYX BAM CHGG CMPR DESP DG DSGX EBAY FB GOOG PYPL ROKU ROP SITE TTD WIX WK YELP
#
# The following stocks are hold by: FFH
# AA ABH ABT AGX ALR ALTR ATCO AZN BB BCE BEN BKNG BNI BNS BRK.A BRK.B BRO BWINB-OLD BYI C CBI CBST CCAP CRAY CRESY CRR CSX CTB CTL CTRX CVX DELL-OL DRC DSSI DXM EROS FIT FLR FTR GCI GE GM GOOGL GSK HP IBM IBN ICO IDIX INTC IPI JEC JEF JNJ KG KLIC KW LMNS LRN LVLT LXK MCFT MDLZ MDR MGA MHK MMI MON MU MYRG NEU NTES NVDQ NWPX NXY NYCB NYT ONCE ORH ORI OSTK PFE PGH PGR PKX PPO RAIL RE RFP RPXC RYAAY RYAM SBNY SD SIX SLCA SLH SPMD SSW STEI TRQ TSM UPL USB USG VRUS WFC WMT XCO ZNT
#
# The following stocks are hold by: pzfvx
# ABC ABT AET AIG ALA ALL AMGN ANTM APOL AXS BA BAC BAX BDX BEN BHI BKR BMY BP C CA CAH CB CI CMA COF CSC CTSH DELL-OL DLPH DOV EIX EQH ESRX ETR F FMCC FNF FNMA FO FRX GE GL GM GOOGL GS HAL HD HLT HPE HPQ INTC IPG IVZ JCP JNJ JPM KMB LEA LH LLL MAS MAT MCK MET MGA MHK MOT MRK MS MSFT MUR MYL NOC NOV NWL NWSA OMC ORCL PFE PH PNC PPG PVH RDS.A RF SHW SPLS SRE STT STX SWK TAP TEL TJX TRW UBS VOYA WAB WB-OLD WEC WFC WHR WLTW WMT XL XOM ZBH
#
# The following stocks are hold by: OFALX
# A AAPL AB ABB ABM ABT AIG AON AVY AXP BAX BBBY BBT BDX BEN BER BK BKC BLK BSX BX BYD C CAKE CFG CFN CMCSA CMI CNDT COF COMM COV CRI CSCO CTAS CVS DAL DBI DBRN DD-OLD DDS DE DELL-OL DENN DGX DIS DISCK DPS EBAY EFX ESRX EXPR FD FDX FITB FL FOSL FOX GBX GDI GE GM GNRC GNW GOOG GPS GS GT HAL HAR HAS HD HEW HLX HOG HPQ HSP IBM IGT IN INTC IR IVZ JAS JLL JNJ JNS JPM KEYS KLIC KSS LIFE LM LOW M MCD MDT MER MHK MMC MMM MS MSFT NAFC NCR NOV NP NR NWL NYX ODP OI OMC ORCL OSK PB PBI PDCO PEP PETM PLL PSS PWR RBC ROST RSH RT RTX SAVE SCHW SEAS SNI SPLS SRCL ST STZ SYK TAP TDC TEL TER TFX TKR TMO TPR TW-OLD TYC UNH UPS USB V VIAB VIAC VLO VSI VWR WBA WCC WDC WHR WMB WRK XL XOM XRX ZBH ZBRA ZQK
#
# The following stocks are hold by: TORYX
# ABKFQ ABT ADP AFL AIG AMAT AMGN ANTM AXP BAC BAX BDX BMY BP BRK.B BWP C CAH CB CBI CHK CL CSCO CTAS DD DD-OLD DHR DIS DOW DTV EDS EMC ETN FFH GCI GD GE GM GRA GS HAE HPE HPQ IBM INTC ITW JNJ JPM KBR KHC KMX L LAB LLY MDLZ MDT MKL MMC MMM OC ORLY PG RDS.A RSG SPGI SWK SYY T TGNA TRB-OLD TUP UNH USEC USG VIAB VMW WBA WFC WU
#
# The following stocks are hold by: jensx
# AAPL ABT ACN ADBE ADP AME APH BCR BDX CDW CHRW CL CTSH DHR ECL EFX EMR GE GIS GOOGL INTU JNJ KO LNAGF MA MDT MMM MSFT NKE OMC ORCL PAYX PEP PFE PG PX RTX SPGI SYK SYY TJX TROW UNH UPS VAR VFC WAT WFC
#
# The following stocks are hold by: SEQUX
# AAP ACOPF AMZN ANET APOL BBBY BDX BHC BKNG BMBLF BRK.A BRK.B BRO CACC CAT CMG CMI CNSWF COIHF COST DHR DLRUF EA ERFSF EXPD FAST FB FSLR FWONK GOOG GOOGL GS HCXLF IBM IDXX IMIAF INT JEC KMX KNX LBRDK LOW MA MHK MLM MLSPF NPSNY NVZMY OMC ORLY PAH3.DE PCAR PCP PDCO PGR PPAMF PRGO PROSF PX QNTQF RBA RYCEF SCHW SIRO-OLD SMTGF TGT TIF TJX UNH VIVEF VMC VOPKF W WAT WBA WFC WFM WMT XRAY
#
# The following stocks are hold by: lmvtx
# AAPL ABBV ADNT AES AET AFL AGN AIG ALB ALXN AMGN AMH AMP AMZN ANET APA AXP AZO BAC BB BIIB BLK BMY BP BRCM-OLD BUD C CA CAG CELG CFC CL CNX COF COP CPN CSCO CTSH CVS CVX DAL DTV DVN DXC EA EBAY EK EMC EQH ESRX EXC EXPE F FB FITB FMCC GE GENZ GILD GNW GOOGL GS GSK HAL HD HNT HPQ IAC IBM ICE INTC JCI JNJ JPM KMI LOW LYB MCD MDLZ MDT MER MET MRK MRVL MSFT MYL NEM NLY NXPI NYX ORCL PAGP PEP PFE PG PHM PM PNC PSX PXD Q-OLD QCOM QRVO RGLD RIG RLGY RTX S SHLDQ SRCL STT SYF TDC TEVA TGT TWX TXN TYC UAL UHS UNH VIAB WFC YHOO
#
# The following stocks are hold by: BAUPOST
# AA AABA ABC ACMR ADCT AER AGN AIG AKBA ALDW ALR AMV ANTM ANV APL APOL AR AROC ATRA AUY AVEO BBEP BGP BMY BP BR BXE BYD C C.WS.A CAH CAR CBIO CBS CDS.U CELG CIT CLNS CLNY CORE CPF CSE DSP DTV DVMT EBAY EGC ELN ELOS EMC ENZN ESRX EST FACT FAF FB FNF FOX FOXA FRH FTR FWONA FWP FYR GAV GHC-OLD GHQ GNW GOOG HD HDS HEK HES HLS HPQ HRZ IAC IDIX IMOS INSP INVA IP ITRN JAZ KERX KGC KIN KLXI KOS LBTYA LBTYK LINE LMDIA LNG LVNTA MAQ MCK MGAM-OL MLS MSFT MU NAO-OLD NAQ NCQ NFG NG NLX NRF NSAM NUAN NWS NWSA NXST OCN OLN OMN ORCL PAX PBF PCG PDLI PRTK PVG PXD PYPL PYX QCOM QNTA QRVO REGN RFMD RHIE ROVI SCHS SCMR SEA SEMI SHA SLM SLRC STRZA SYF T TAK TBIO TBPH TCW TOH TQNT TRCO TWX UCO UFS UNH UNVR VIAC VMW VOXX VRTV VSAT
#
# The following stocks are hold by: LPC
# AAPL ACN ACT ADBE ADSK AGN AMP AMX AMZN APH APOL ATVI AVGO AXP AZO BABA BAC BAM BAX BBBY BHC BIDU BKNG BLK BUD C CBRE CCI CCL CHTR CL CMCSA CME CP CPRI CRM CSX CTRP CTSH CVS CX DG DHI DIS DISCA DKS DLB DLTR DPZ DVA EA EBAY ECL EDU EFX EL EP EQIX ESRX ETR EXP EXPE FAST FB FDC FDO FLIR FLT FMX FOXA FTI GMCR GOOG GOOGL GPN GPS GR HANS HPQ HSBC HTZ HUM ICE ILMN INFY IQV ISRG JD JPM KMI KO LBTYK LK LMDIA LNG LO LOW LULU LVS MA MCD MELI MHS MJN MNST MON MSFT MSM MTCH NCC NFLX NKE NLOK NOC NOW NTAP NTES NVDA NWSA OII ORLY PCP PEP PM PNC PYPL QCOM RL RLGY SAI SBAC SCHW SD SFD SHOP SLB SPGI SQ STRA STZ SWN TDC TDG TECK TIF TMUS TPR TRU TSM TV ULTA UNH UNP UPS URBN V VMC VRSN WBA WBC WFC WFT WMB WYN WYNN XTO YUM
#
# The following stocks are hold by: FPACX
# AA AABA ABT ADI AIG AIZ ALLY ANTM AON APA ARKAY ARNC ARRS AVGO AXP BAC BIDU BUD C CABJF CFN CHKP CHTR CIT CKSNF CMCSA CNQ COV CSCO CVS EBAY ESL ESRX EXPE FB GBLBF GE GMALF GOOG GOOGL HCMLF HPQ IPG JEF JNJ KMI LOW MEGGF MSFT MYL NPSNY OCR OI ORCL ORKLY OXY PETM PFE PHG RNSDF RTX TEL TMO TOT TRH TSCDF UN VAL VOD WBA WDC WFC WMT WPP YHOO
#
# The following stocks are hold by: FS
# ADP BDX BF.B CHKP CL CLX EFX EL FB IDXX INTU JNJ MAR MASI MKC MMM MSFT NKE PEP PM PYPL SABR SBUX SYK V VRSK WAT
#
# The following stocks are hold by: TA
# AKR BAM BK CMA CVCO ESS EXP FCE.A FNF FPH FR GBGS HA HCC LEN LEN.B LOW MAC MHK ORI ORIG PLD PNC PNC.WS PSA RYN TDW TPHS TRC UHAL VNO WY Y ZION
#
# The following stocks are hold by: MKL
# AAPL ADI ADM ADP AMZN BAC BAM BLK BRK.A BRK.B BUD C CFX DE DEO DIS FCE.A FFH FII FNF GD GE GOOG GOOGL HD IGT JNJ KMX LFG MAR MBI MMC MSFT NVO RLI SPGI SYY TXN UBSH UL UNH UPS V WBA WMT WPC WTM XL XOM
#
# The following stocks are hold by: GR
# ABT BF.A BF.B BRK.A BRK.B BTI BUD CFRHF CMCSA CMCSK-OLD DEO GHC GOOG HAS HKHHF HRL JCDXF JPM MA MKL MLHR MLM MO NSRGY PDRDF PG PM SBMRY SNI UHR-D UN V WFC XOM
#
# The following stocks are hold by: TVAFX
# AA AAPL ACN ADT AGO AHONY AIG ALKS ALL AMZN ANTM APA APD APO ARMK ATVI BA BABA BAC BBY BHC BHI BKNG BNKJF BX C CB CCI CCK CFG CHL CHT CINF CMCSA CME COF COP CSC CTSH CVA CVX CYH DELL-OL DISH DLMAF DLPH DNA DOX DPS DTV DVN EPD ESNT ESRX ETR FB FCX FISV FITB FMCC FTE GE GILD GLW GNW GOLF GOOG GOOGL GPS GS GSK HAL HFC HIG HPQ HSBC HTZ HUN IFF IMS ING INTC IPXHF ITC JBLU JNJ JPM KDDIF KHC LLY LOPE LTM-OLD LVLT LVS MDLZ MDT MET MHK MJN MON MOT MRO MSFT MTU NCLH NFLX NLSN NMIH NOMD NORD OAK OGZPY ORLY PAHC PCU PMT PRGO PSTG RAD RHHVF RIG RPCGY RSG SBUX SCHW SD SFTBF SGEN SHLDQ SPLS STJ SWCEY T TEVA TGT TM TMO TOKSF TOT TPH TRH TUP UBS USB USFD VAL VAR VIVEF VRSN WB-OLD WBA WFR WFT WH WMT WYE X XOM YHOO YUM ZAYO ZTS
#
# The following stocks are hold by: TWEBX
# ABN AIG ANAT ANFGF AXELF AXP AZO BAC BAESF BAX BIDU BK BNI BRK.A BSBR BTI CMCSA CMCSK-OLD CNHI CNPAF CNW COP CSCO DEO DVN EMR FII FMCC GETVF GL GOOG GOOGL GSK HAL HD HENKY HKHHF HYMLF JEF JNJ LNAGF MA MBI MMM MRC MURGF NSRGY NVS NWLI PFE PM PNC RDS.A RHHVF RYN SCBFF SKM SNY SWCEY TOT TRH UL UN UNF UNP UOVEY WFC WMT WPP ZFSVF
#
# The following stocks are hold by: WVALX
# ACN ADI AGN AIG AMZN ANTM AON APA APOL AXP AZO BHC BKNG BRK.B BUD CFC CMCSA CMCSK-OLD COP COV CRM CSGP CTRX CVS DELL-OL DEO DHR DIS DISCA DISCK DLTR DTV EBAY ENDP EOG ESRX EXPE FB FNMA FOX FOXA FWONA FWONK GHC GOOG GOOGL HPQ IAC JPM KMX LBRDK LBTYK LH LMDIA LMT LNAGF LOW LSXMK MA MLM MON MSFT MSI NWSA OCR OMC ORCL PCP PX PXD QRTEA RRC RWT SCHW SWN TDG TDS.S TGT TMO TXN TYC UNH UPS USG V VMC WFC WMT
#
# The following stocks are hold by: BRK
# AAL AAPL AMP AMZN ANTM AXP BAC BK BNI BUD CBI CEG CHTR CMCSK-OLD COP COST CVS DAL DE DG DJ DTV DVA FISV FWONA GD GE GHC GL GM GS GSK IBM INTC IR IRM JNJ JPM KHC KMX KO LSXMK LUV MA MCO MDLZ MON MTB NKE NLC NOV NRG NSC NSRGY ORCL PCP PG PSX RSG SNY SU T TT TYC UAL UNP UPS USB USG V VIAB VRSN VZ WFC WMT WSC XOM
#
# The following stocks are hold by: cc
# A ABEV ABV-OLD ACN ADI ADSK AGN ALTR AMT AMZN AON AVGO AVP AXP AZO BAP BAX BBD BCO BDX BIDU BITA BKNG BTI CACC CAG CBRE CL CLB CME CMPR COV ECL EFX FIS GOOG GOOGL GWW HOG HRB ICE KMB KO LKQ MSM NXPI OPEN ORCL PFE PM SERV SIRO-OLD SLH SNN SPGI SSNC ST TMO TNET TRV UL V VRSN WAT WLTW ZTS

# %% [markdown]
# #rename columns again:如果遇到"."或者"-"就刪掉
# #遇到同名則合併
# #shorten_colnam_lst = []
# for col in df_weight.columns:
#     #print(col)
#     if "." in col:
#         new_col = col.split(sep = '.')[0]
#         #shorten_colnam_lst.append(new_col)
#         #temp_df = df_weight[col] #把舊名的col挑出來
#         if new_col in df_weight.columns: #如果去掉標籤的舊名有在原本的colnam中，代表需要加在一起
#             df_weight[new_col] = df_weight[new_col]+df_weight[col]
#             df_weight.drop(col, axis = 1, inplace=True) #把舊名丟掉
#         else: #直接把colnam換掉
#             df_weight.rename(columns={col:new_col}, inplace=True) #直接重新命名
#         #df_weight = pd.concat([df_weight, temp_df], axis = 1) #合併
#     elif "-" in col:
#         new_col = col.split(sep = '-')[0]
#         if new_col in df_weight.columns: #如果去掉標籤的舊名有在原本的colnam中，代表需要加在一起
#             df_weight[new_col] = df_weight[new_col]+df_weight[col]
#             df_weight.drop(col, axis = 1, inplace=True) #把舊名丟掉
#         else: #直接把colnam換掉
#             df_weight.rename(columns={col:new_col}, inplace=True) #直接重新命名
#     #else:
#         #shorten_colnam_lst.append(col)
# #print(shorten_colnam_lst)
# df_weight

# %% [markdown]
# ## 找出unique的股池
#
# 1. 從investors對應的股池，只取聯集
#
# 2. 利用set()來做聯集

# %%
unique_spam.values()
# Out:
# dict_values([array(['ABG', 'ACM', 'ADNT', 'ADT', 'AGCO', 'ALK', 'APTV', 'ARRS', 'ASH',
#        'ATI', 'AVT', 'AXE', 'AXL', 'AXLL', 'AXTA', 'AYI', 'BDC', 'BGC',
#        'BHI', 'BW', 'BWXT', 'CAG', 'CAH', 'CAM', 'CBT', 'CCK', 'COMM',
#        'CPRI', 'CR', 'CSC', 'CSX', 'CTB', 'CW', 'CYT', 'DAN', 'DBD',
#        'DRC', 'DXC', 'EMN', 'ENR', 'FLEX', 'FLS', 'FMC', 'FTI', 'GDI',
#        'GEO', 'GPI', 'GPK', 'GRA', 'GT', 'HAR', 'HII', 'HPE', 'HPQ',
#        'HSC', 'HUN', 'IGT', 'IM', 'IP', 'IPGP', 'ITT', 'JOY', 'KEX',
#        'KFY', 'KLXI', 'KMT', 'KS', 'LEA', 'LEN', 'LSKD', 'MAS', 'MGA',
#        'MHK', 'MOS', 'MRC', 'MTW', 'MU', 'MWA', 'NAV', 'NCR', 'NOMD',
#        'NOV', 'NSC', 'NWSA', 'ODP', 'OI', 'OIS', 'OSK', 'PAY', 'RHI',
#        'RL', 'ROC', 'RRD', 'SCS', 'SEE', 'SJM', 'SPLS', 'SPR', 'SPXC',
#        'TAM', 'TECD', 'TEN', 'TEX', 'TGI', 'TIF', 'TKR', 'TSLA', 'TTM',
#        'TW-OLD', 'UNF', 'VC', 'VEC', 'WCC', 'WFT', 'WRK', 'XLS', 'ZTO'],
#       dtype=object), array(['AAP', 'ADS', 'AN', 'ARES', 'AWI', 'BAC', 'BRK.A', 'BRK.B', 'CHEF',
#        'CHRW', 'CHTR', 'CMPR', 'CPRT', 'CVET', 'DFZ', 'DNOW', 'DSWL',
#        'DTV', 'FFH', 'FL', 'FWONK', 'GLIBA', 'GRUB', 'HBI', 'HEI', 'IBKR',
#        'IBM', 'INWK', 'JEF', 'LB', 'LBTYK', 'LTRPA', 'MCO', 'MNRO', 'MSM',
#        'OUTR', 'RAVN', 'RBA', 'RCII', 'RUE', 'SAM', 'SAVE', 'SD', 'SNE',
#        'SPB', 'ST', 'TAP', 'TRIP', 'VIAB', 'VMI', 'W', 'WFC', 'XPO',
#        'XRAY', 'Y'], dtype=object), array(['AAPL', 'ABT', 'ADM', 'AMX', 'AMZN', 'AN', 'APD', 'ARCO', 'BABA',
#        'BAX', 'BP', 'BRK.B', 'BYND', 'CAT', 'CCI', 'CNI', 'CNR', 'COST',
#        'CSX', 'CX', 'DDAIF', 'DMND', 'ECL', 'EXPD', 'FDX', 'FMX', 'GOOG',
#        'GOOGL', 'GS', 'JNJ', 'KO', 'KOF', 'LBTYA', 'LBTYK', 'LILA',
#        'LILAK', 'MCD', 'MRK', 'MSFT', 'MTB', 'PFE', 'PG', 'RSG', 'SDGR',
#        'SGP', 'TM', 'TSCO', 'TTF', 'TV', 'TYC', 'UPS', 'WBA', 'WM', 'WMT',
#        'WYE', 'XOM', 'XTO'], dtype=object), array(['A', 'ACT', 'ADP', 'AGN', 'AIG', 'AIV', 'ALEX', 'ALX', 'APD',
#        'BEAM', 'BGP', 'BHC', 'BKS', 'BKW-OLD', 'BRK.B', 'BX', 'C', 'CBY',
#        'CEN', 'CMG', 'CP', 'CSG', 'CXW', 'DPS', 'EMC', 'FBHS', 'FDO',
#        'FO', 'GGP', 'GLRE', 'GM', 'H', 'HHC', 'HLT', 'HME', 'JCP', 'LDG',
#        'LNY', 'LOW', 'MA', 'MATX', 'MCD', 'MDLZ', 'NKE', 'NOMD', 'PAH',
#        'PG', 'PK', 'QSR', 'RTX', 'SBUX', 'SHLDQ', 'SKS', 'SPLS', 'TGT',
#        'V', 'WB-OLD', 'WEN', 'YUM', 'ZTS'], dtype=object), array(['AAL', 'ADT', 'ALXN', 'AMZN', 'AVP', 'BABA', 'BAC', 'BHC', 'BHF',
#        'C', 'CELG', 'CTL', 'DAL', 'DISCA', 'EIGI', 'ENDP', 'FB', 'FCAU',
#        'FL', 'FLXN', 'FTCH', 'GILD', 'GME', 'GNW', 'GOOGL', 'JPM',
#        'JPM.WS', 'KBH', 'LEN', 'MED', 'MNK', 'MTG', 'MU', 'NXPI', 'OMF',
#        'P', 'PAH', 'PHM', 'PTON', 'QUOT', 'RH', 'TEVA', 'TMHC', 'TVTY',
#        'TWTR', 'UAL', 'W', 'XON'], dtype=object), array(['AA', 'ABB', 'ABT', 'ADM', 'ADT', 'ADTN', 'AEO', 'AGCO', 'AGU',
#        'AIN', 'ALK', 'ALL', 'AMH', 'APC', 'ATMI', 'AUQ', 'AVD', 'AVT',
#        'AXP', 'BAC', 'BAX', 'BBT', 'BCC', 'BEN', 'BG', 'BHE', 'BHI', 'BK',
#        'BKH', 'BPFH', 'BRK.B', 'BSX', 'BXS', 'CA', 'CALM', 'CAT', 'CBWBF',
#        'CCG', 'CLD', 'CNI', 'COF', 'COP', 'COV', 'CSCO', 'CVS', 'DGX',
#        'DLR', 'DNB', 'DOW', 'DVN', 'EME', 'EMR', 'ENDP', 'ENH', 'EQC',
#        'ESRX', 'ETR', 'EXC', 'FDX', 'FE', 'FFH', 'FLR', 'FLS', 'FN',
#        'FRX', 'FSP', 'FTO', 'GE', 'GL', 'GLT', 'GOOGL', 'GR', 'GRS',
#        'GTS', 'GW', 'HAR', 'HE', 'HES', 'HRB', 'HRL', 'HSP', 'HTCH',
#        'HUM', 'IAG', 'INTC', 'IRC', 'IVC', 'JBHT', 'JBLU', 'JCI', 'JNJ',
#        'JOY', 'KBR', 'KEX', 'KMT', 'KSS', 'KSU', 'LPNT', 'LUV', 'LXU',
#        'MAN', 'MCRL', 'MDU', 'MHK', 'MI', 'MOS', 'MRO', 'MS', 'MTZ',
#        'MUSA', 'OMI', 'ORCL', 'OSG', 'OSK', 'PFE', 'PFG', 'PG', 'PLAB',
#        'PLXS', 'PNC', 'PNM', 'PNR', 'PSO', 'PTEN', 'PWR', 'R', 'RCII',
#        'RCL', 'RFMD', 'RHI', 'RJF', 'RPM', 'RTI', 'SAWLF', 'SCHW', 'SFD',
#        'SFY', 'SIGI', 'SLB', 'SM', 'SNY', 'STI', 'STNG', 'STX', 'STZ',
#        'SU', 'SUG', 'SWKS', 'SWY', 'T', 'TDW', 'TEG', 'TEL', 'TEVA',
#        'TFC', 'TKR', 'TT', 'TYC', 'UFPI', 'UGI', 'ULTR', 'UNM', 'UNT',
#        'URS', 'USTR', 'UVV', 'VAL', 'VZ', 'WAFD', 'WBA', 'WERN', 'WFC',
#        'WFR', 'WLTW', 'WMS-OLD', 'WMT', 'WPS', 'WPX', 'WYE', 'XEC', 'XOM',
#        'XRAY', 'ZBH', 'ZION'], dtype=object), array(['AAL', 'ADNT', 'AIG', 'ALLY', 'AMZN', 'APA', 'APC', 'BAC', 'BBY',
#        'BEN', 'BKNG', 'BMC', 'BMY', 'C', 'CBRE', 'CHK', 'CHTR', 'CMCSA',
#        'COF', 'CPN', 'CVE', 'CXO', 'DELL-OL', 'DISCA', 'DISCK', 'DNB',
#        'DTV', 'EBAY', 'EOG', 'FB', 'FCAU', 'FDX', 'FNF', 'FRX', 'GE',
#        'GOOG', 'GOOGL', 'GPS', 'HD', 'HLT', 'HOG', 'HRB', 'IMS', 'INTC',
#        'JPM', 'KMT', 'LEA', 'LMDIA', 'LNKD', 'LTD', 'MA', 'MAT', 'MCD',
#        'MDT', 'MGM', 'MON', 'MS', 'NFLX', 'NFX', 'ORCL', 'PHM', 'QRTEA',
#        'REGN', 'S', 'SGP', 'STZ', 'TEL', 'TRW', 'TWX', 'TXN', 'VIAB',
#        'WFT', 'WM-OLD', 'WU', 'XRX', 'YUM'], dtype=object), array(['AAIGF', 'ACF', 'AIG', 'AIG.WS', 'ANTM', 'ASA', 'AXP', 'BA', 'BAC',
#        'BAC.WS.A', 'BAC.WS.B', 'BAM', 'BMY', 'BNI', 'BRK.A', 'BRK.B', 'C',
#        'CHK', 'CHPXF', 'CIT', 'CLMT', 'CLPR', 'CMCSA', 'CMCSK-OLD', 'CNQ',
#        'CSCO', 'DISH', 'DJCO', 'DNOW', 'DUK', 'EMN', 'ESVIF', 'FCX',
#        'FMCC', 'FNMA', 'FRX', 'FSUMF', 'FUR', 'GD', 'GE', 'GGP', 'GS',
#        'HOFD', 'HRG', 'HTZ', 'HUM', 'IBM', 'IDT', 'IDT.B', 'IDT.C',
#        'IPMLF', 'JEF', 'JEF-OLD', 'JOE', 'JZEOF', 'KHC', 'LE', 'MBI',
#        'MHK', 'MMC', 'MRC', 'MS', 'MWA', 'MWA.B', 'MYL', 'NOC', 'NOV',
#        'OAK', 'OBE', 'OSH', 'OXY', 'PD', 'PFE', 'RF', 'RRR', 'SATS',
#        'SE-OLD', 'SHLD.WS', 'SHLDQ', 'SHOS', 'SPB', 'SPG', 'SPR', 'SRG',
#        'SRSC', 'T', 'UNH', 'URI', 'USG', 'USMO', 'VST', 'VSTO', 'WCG',
#        'WES', 'WPG', 'WTM', 'XTO'], dtype=object), array(['AAPL', 'AFSI', 'AGN', 'AIG', 'ARII', 'CHK', 'CI', 'CLDR', 'CNDT',
#        'CVI', 'CVRR', 'CZR', 'DELL', 'DELL-OL', 'DK', 'DVMT', 'EBAY',
#        'EGN', 'ENZN', 'FANG', 'FCX', 'FDML', 'FRX', 'GCI', 'HAIN', 'HLF',
#        'HOLX', 'HPQ', 'HRI', 'HTZ', 'IEP', 'LNG', 'MENT', 'MTW', 'NAV',
#        'NFLX', 'NUAN', 'NWL', 'OXY', 'PYPL', 'RIG', 'SD', 'SSE', 'TEN',
#        'TGNA', 'TLM', 'TTWO', 'VLTC', 'VMW', 'WBMD', 'WBT', 'XRX'],
#       dtype=object), array(['ABT', 'ACN', 'AFL', 'APA', 'APOL', 'ATGE', 'AXE', 'AXP', 'BAX',
#        'BBBY', 'BDK', 'BEN', 'BK', 'BOKF', 'BRK.B', 'BWA', 'BX', 'C',
#        'CAH', 'CBS', 'CCL', 'CHK', 'COV', 'CVS', 'DELL-OL', 'DIS', 'DTV',
#        'EBAY', 'FAF', 'GCI', 'GOLD', 'GS', 'HD', 'HES', 'HEW', 'HNGR',
#        'HRB', 'HSP', 'IBM', 'IGT', 'IMS', 'IPG', 'ITW', 'JNJ', 'JPM',
#        'KKR', 'KMT', 'LAZ', 'LH', 'LMT', 'LOW', 'MOS', 'MRK', 'MS',
#        'MSFT', 'NLSN', 'NOV', 'NTRS', 'NWL', 'OMC', 'ORCL', 'PFE', 'PGR',
#        'PIR', 'SJM', 'SNA', 'SRCL', 'STJ', 'STZ', 'SWK', 'TGT', 'TIF',
#        'TM', 'TYC', 'UBS', 'USG', 'VIAB', 'VIAC', 'WBA', 'WM', 'WU',
#        'XOM', 'ZBH', 'ZBRA'], dtype=object), array(['BAC', 'PKX', 'USB', 'WFC'], dtype=object), array(['AABA', 'ABKFQ', 'ADBE', 'ADSK', 'AMZN', 'ANTM', 'AXP', 'AY',
#        'BIDU', 'CHTR', 'CMCSA', 'CNI', 'CP', 'EFX', 'FOX', 'FOXA',
#        'FWONK', 'GOOG', 'GOOGL', 'LNAGF', 'MA', 'MCO', 'MON', 'MSFT',
#        'NOC', 'NSC', 'PCG', 'RTN', 'SPGI', 'TDG', 'TWC', 'TWX', 'UNP',
#        'UNVR', 'V', 'YHOO'], dtype=object), array(['ALK', 'AVX', 'AXP', 'BRK.A', 'BRK.B', 'CKH', 'CMI', 'COST', 'DG',
#        'DIS', 'EQNR', 'GG', 'GPC', 'HXL', 'KGC', 'MCY', 'MRK', 'NEM',
#        'NKE', 'NXPI', 'OLN', 'SBUX', 'SNY', 'SWKS', 'TRV', 'USG', 'XOM',
#        'Y'], dtype=object), array(['AAIGF', 'ADNT', 'AET', 'AIG', 'AMAT', 'AMP', 'AMZN', 'APA', 'AXP',
#        'BABA', 'BAM', 'BBBY', 'BK', 'BRK.A', 'CFG', 'CNQ', 'COF', 'COG',
#        'COP', 'COST', 'COV', 'CVS', 'DEO', 'DGX', 'EDU', 'ESRX', 'FB',
#        'GE', 'GOOG', 'GOOGL', 'HCMLF', 'HOG', 'HPQ', 'IBM', 'INTC', 'IRM',
#        'JBHGF', 'JCI', 'JNJ', 'JPM', 'KMX', 'KO', 'L', 'LBTYK', 'LFGEF',
#        'LH', 'LVS', 'MEL', 'MER', 'MKL', 'MO', 'MON', 'MRK', 'MSFT',
#        'NPPKF', 'NPSNY', 'NWSA', 'OAK', 'OVV', 'OXY', 'PG', 'RE', 'RHHVF',
#        'RHJIF', 'RTX', 'RWT', 'S', 'SAFRY', 'SCHW', 'SYY', 'TEL', 'TKOMY',
#        'TRH', 'TXN', 'TYC', 'UNH', 'USB', 'WB-OLD', 'WFC', 'WMT', 'WOSCF',
#        'Y'], dtype=object), array(['AAPL', 'ADBE', 'ALRM', 'AMT', 'AMTD', 'ANSS', 'ARO', 'BAC', 'BAM',
#        'BDX', 'BRK.A', 'BRK.B', 'BYI', 'CFX', 'CSGP', 'CSX', 'DG', 'DHIL',
#        'DHR', 'DISCA', 'DLTR', 'DTV', 'EQIX', 'ESGR', 'FDS', 'FOCS',
#        'FTV', 'GSHD', 'HIG', 'JEF', 'KKR', 'KMX', 'LAMR', 'LKQ', 'LPLA',
#        'LYV', 'MA', 'MBRG', 'MCO', 'MKL', 'MNRO', 'MSCI', 'MWE', 'NDN',
#        'NLY', 'NS', 'OLLI', 'ORLY', 'OXPS', 'PENN', 'PRMW', 'ROP', 'ROST',
#        'RVR', 'SBAC', 'SHLDQ', 'TECH', 'TJX', 'TRH', 'TROW', 'UI', 'V',
#        'VRSK', 'WMS-OLD'], dtype=object), array(['AAL', 'AAPL', 'ABT', 'ACT', 'ADBE', 'AET', 'AGN', 'AIG', 'ALLY',
#        'AMGN', 'AMTD', 'AMZN', 'ANTM', 'APC', 'AVGO', 'AXP', 'AXTA',
#        'BABA', 'BAC', 'BAX', 'BBBY', 'BEAV', 'BID', 'BKI', 'BLK', 'BSX',
#        'BUD', 'BURL', 'BXLT', 'C', 'CB', 'CCE-OLD', 'CCK', 'CELG', 'CF',
#        'CHTR', 'CI', 'CNC', 'COG', 'CPB', 'CRM', 'CTXS', 'DAL', 'DD',
#        'DG', 'DHR', 'DIS', 'DOV', 'DOW', 'DVN', 'EA', 'EBAY', 'ELN',
#        'EMC', 'EQT', 'FB', 'FDX', 'FIS', 'FIVE', 'FMC', 'FOXA', 'FPAC',
#        'FPAC.UN', 'GD', 'GOOGL', 'HTZ', 'HUM', 'IAA', 'IAC', 'ICE', 'IP',
#        'IQV', 'JPM', 'KHC', 'LBTYA', 'LBTYK', 'LEN', 'LNG', 'LOW', 'MAS',
#        'MHK', 'MON', 'MPC', 'MRK', 'MS', 'MSFT', 'NFLX', 'NWSA', 'NXPI',
#        'PH', 'PSX', 'PVTB', 'PYPL', 'QCOM', 'RACE', 'RAX', 'ROP', 'ROST',
#        'RTX', 'SEE', 'SHPG', 'SHW', 'SJM', 'SPGI', 'ST', 'STJ', 'STZ',
#        'SUNE', 'TAP', 'TDG', 'TEL', 'TIBX', 'TIF', 'TMO', 'TMUS', 'TWC',
#        'TWX', 'V', 'VMC', 'VZ', 'WCC', 'WMB', 'WP', 'WYNN', 'YHOO', 'YPF',
#        'YUM', 'ZAYO'], dtype=object), array(['AABA', 'ABG', 'AET', 'AGN', 'AIG', 'AIZ', 'AKBA', 'BEN', 'BKS',
#        'BMC', 'BMY.R', 'BNED', 'CARS', 'CCO', 'CELG', 'CLNS', 'CNL',
#        'COV', 'CST', 'CWH', 'CWH-OLD', 'DELL-OL', 'DTV', 'EGL', 'ENT',
#        'ESRX', 'ETP', 'FB', 'GCVRZ', 'GOOGL', 'GPI', 'GTIV', 'INXN',
#        'JCP', 'KERX', 'KMI', 'LAD', 'LAMR', 'MANT', 'MGI', 'MSFT', 'MTW',
#        'NAVI', 'NRF', 'NSAM', 'NXY', 'OI', 'OPB', 'ORLY', 'OXSQ', 'OZM',
#        'PACD', 'PCG', 'QCP', 'RYAM', 'RYN', 'SCU', 'SHPG', 'SLGN', 'SLM',
#        'SPH', 'SYT', 'TDG', 'TEVA', 'TMDX', 'TWC', 'TWX', 'UHAL', 'VEON',
#        'WAIR', 'WBT', 'WEN', 'WFC', 'WLTW', 'WU'], dtype=object), array(['AABA', 'AAPL', 'ACM', 'ADNT', 'ADP', 'AER', 'AET', 'AGN', 'AGNC',
#        'AGR', 'AHL', 'AHMIQ', 'AMAT', 'AMP', 'ANTM', 'APC', 'ATUS', 'AXP',
#        'AYE', 'BAGL', 'BBY', 'BDX', 'BHF', 'BIOF', 'BJS', 'BK', 'BOL',
#        'BP', 'BRK.B', 'BSC', 'BSX', 'BWXT', 'CAH', 'CBI', 'CBS', 'CC',
#        'CCK', 'CCR', 'CEIX', 'CF', 'CFG', 'CFN', 'CHNG', 'CI', 'CIT',
#        'CNC', 'CNDT', 'CNW', 'CNX', 'COMM', 'CONN', 'COV', 'CPN', 'CPRI',
#        'CSC', 'CVEO', 'CVH', 'CVS', 'DAN', 'DBI', 'DDS', 'DELL-OL', 'DFS',
#        'DHR', 'DIS', 'DLPH', 'DOW', 'DOX', 'DPS', 'DST', 'DXC', 'EIG',
#        'EMC', 'EPL', 'FDC', 'FICC', 'FLML-OLD', 'FOXA', 'FSC', 'FWLT',
#        'FWONA', 'GFG', 'GM', 'GNW', 'GRBK', 'GS', 'GTS', 'HAR', 'HCA',
#        'HES', 'HEW', 'HGV', 'HII', 'HLX', 'HMA', 'HNT', 'HPE', 'HSP',
#        'HTS', 'HUM', 'IAC', 'ICO', 'IPCR', 'KAR', 'KBR', 'KEYS', 'KGC',
#        'LBTYA', 'LBTYK', 'LM', 'LRCX', 'LTM-OLD', 'LYB', 'M', 'MDC',
#        'MDCO', 'MDR', 'MERC', 'MIM', 'MO', 'MON', 'MRVL', 'MSFT', 'MU',
#        'MYL', 'NBSE', 'NCR', 'NEW', 'NOV', 'NVR', 'OAK', 'OI', 'OIS',
#        'ON', 'PAYX', 'PCX', 'PFE', 'PLCE', 'PRGO', 'PTEN', 'RAD', 'RAH',
#        'RE', 'RJET', 'RSYS', 'S', 'SAI', 'SATS', 'SCT', 'SDRL', 'SFLY',
#        'SGMS', 'SHW', 'SPR', 'STX', 'SUNE', 'SYT', 'TDC', 'TGP', 'TGT',
#        'TKTM', 'TPX', 'TRH', 'TRV', 'TSCO', 'TSG', 'TTWO', 'TWTR', 'TWX',
#        'TX', 'UHAL', 'UIL', 'UNH', 'URS', 'USBE', 'VAL', 'VMED', 'VOYA',
#        'VR', 'WBA', 'WFR', 'WLT', 'WNG', 'WPX', 'WU', 'WYE', 'XELT',
#        'XRX', 'YELP', 'YHOO'], dtype=object), array(['AA', 'AAPL', 'ABBV', 'ADI', 'ADM', 'AIG', 'AXP', 'BAC', 'BBT',
#        'BK', 'BMY', 'C', 'CB', 'CBS', 'CCL', 'CMCSA', 'CMCSK-OLD', 'COF',
#        'COP', 'COV', 'CSCO', 'CVS', 'CVX', 'DD-OLD', 'DELL-OL', 'DG',
#        'DIS', 'DVN', 'EBAY', 'EMR', 'ETN', 'FB', 'FDC', 'FDX', 'GE',
#        'GENZ', 'GILD', 'GLW', 'GOOG', 'GPS', 'GS', 'HOLX', 'HPQ', 'HRS',
#        'INTC', 'JCI', 'JNJ', 'JPM', 'K', 'MCD', 'MDLZ', 'MEDI', 'MER',
#        'MET', 'MMM', 'MS', 'MSFT', 'MWW', 'NVLS-OLD', 'OXY', 'PEP', 'PFE',
#        'PG', 'QCOM', 'RTX', 'SBL', 'SCHW', 'SLB', 'SPGI', 'SPLS', 'STJ',
#        'STT', 'TDW', 'TEL', 'TEVA', 'TMO', 'TWX', 'TYC', 'VIAB', 'VIAC',
#        'VLO', 'VOD', 'VSH', 'WBA', 'WFC', 'WMT', 'WU', 'WYE', 'ZBH'],
#       dtype=object), array(['AAPL', 'ALC', 'AXP', 'BKNG', 'BMY', 'BRK.B', 'CDW', 'CELG',
#        'CHRW', 'CLB', 'CMI', 'CPRT', 'CTSH', 'EA', 'EMC', 'ESRX', 'EW',
#        'EXPD', 'FAST', 'FB', 'FLT', 'GILD', 'GOOG', 'GOOGL', 'ISRG',
#        'KEYS', 'KHC', 'LKQ', 'MJN', 'MSFT', 'MSI', 'MTB', 'NOV', 'NVDA',
#        'ODFL', 'PRGO', 'PYPL', 'QCOM', 'ROST', 'SBUX', 'SCHW', 'SLB',
#        'SPGI', 'SRCL', 'TEVA', 'THS', 'TJX', 'TPR', 'TSCO', 'ULTA', 'USB',
#        'V', 'VAR', 'VRSK'], dtype=object), array(['AABA', 'AAL', 'AAPL', 'ADBE', 'AGN', 'AIG', 'ALL', 'ALLY', 'AMAT',
#        'AMLP', 'AMR', 'AMZN', 'APA', 'APC', 'AVGO', 'AXLL', 'AY', 'BA',
#        'BABA', 'BAC', 'BBT', 'BC', 'BEE', 'BKNG', 'BRCM-OLD', 'BSX',
#        'BZH', 'C', 'CBI', 'CBS', 'CCI', 'CF', 'CFG', 'CHK', 'CLMT', 'CNC',
#        'CNO', 'COF', 'COOP', 'COP', 'CRM', 'CSCO', 'CVI', 'CVX', 'CWEN',
#        'CWEN.A', 'CYH', 'CZR', 'DAL', 'DAN', 'DDAIF', 'DDS', 'DF', 'DG',
#        'DIS', 'DLPH', 'DTV', 'DVN', 'EMC', 'EMN', 'ET', 'ETFC', 'ETP',
#        'EXP', 'F', 'FB', 'FITB', 'FLR', 'FOXA', 'GM', 'GOOG', 'GOOGL',
#        'GPT', 'GT', 'HAIN', 'HAL', 'HCA', 'HDS', 'HFC', 'HIG', 'HOT',
#        'HPQ', 'HUM', 'HUN', 'I', 'IP', 'JAVA', 'JBLU', 'JNJ', 'JPM',
#        'KEY', 'KLAC', 'KMI', 'KMT', 'LCC', 'LNG', 'LO', 'LRCX', 'LUV',
#        'M', 'MAS', 'MDT', 'MEE', 'MET', 'MGM', 'MHK', 'MOS', 'MPG', 'MRK',
#        'MRO', 'MS', 'MSFT', 'MU', 'MWA', 'MYL', 'NAV', 'NFLX', 'NRG',
#        'NXPI', 'NXY', 'OC', 'ODP', 'OMX', 'ORCL', 'OXY', 'PAH', 'PCG',
#        'PCX', 'PCZ', 'PENN', 'PFE', 'PHH', 'PNC', 'PPG', 'PRU', 'QCOM',
#        'RAD', 'RBS', 'RF', 'RIG', 'RTH', 'S', 'SBAC', 'SLM', 'SMH', 'STI',
#        'STT', 'SYF', 'TERP', 'TEVA', 'TEX', 'TGI', 'TLM', 'TMO', 'TMUS',
#        'TPX', 'TSLA', 'TWTR', 'UAL', 'UAUA', 'UBS', 'UNH', 'URI', 'USG',
#        'VCI', 'VLO', 'VST', 'WB-OLD', 'WDC', 'WFC', 'WHR', 'WLTW', 'WMB',
#        'WNR', 'WPZ', 'XL', 'XLE', 'XPO', 'XTO', 'YHOO'], dtype=object), array(['AIG', 'AMGN', 'ANTM', 'APA', 'APC', 'AXP', 'AZN', 'BAC', 'BHI',
#        'BK', 'BMY', 'C', 'CAH', 'CHTR', 'CI', 'CMCSA', 'COF', 'CSCO',
#        'CVX', 'DOW', 'EBAY', 'EMC', 'ESRX', 'FDX', 'FOXA', 'GE', 'GOOG',
#        'GS', 'GSK', 'HD', 'HPE', 'HPQ', 'JCI', 'JPM', 'LLY', 'MC-OLD',
#        'MCD', 'MCHP', 'MET', 'MOT', 'MRK', 'MSFT', 'NLOK', 'NVS', 'NWSA',
#        'OXY', 'PFE', 'RHHBY', 'RTX', 'S', 'SCHW', 'SLB', 'SNE', 'SNY',
#        'TRV', 'TWC', 'TWX', 'UNH', 'UNP', 'VOD', 'WB-OLD', 'WFC', 'WMT',
#        'WYE', 'XRX'], dtype=object), array(['ACF', 'AIG', 'ANF', 'ANTM', 'APOL', 'ARGKF', 'ASBFF', 'AVP',
#        'AXP', 'BBBY', 'BCR', 'BDX', 'BK', 'BKNG', 'BNTGF', 'BOIVF',
#        'CHRW', 'CL', 'CLX', 'CMCSA', 'CMCSK-OLD', 'CON.DE', 'COP', 'COV',
#        'CSCO', 'CTSH', 'DELL-OL', 'DIS', 'DISH', 'EBAY', 'FBN', 'FDC',
#        'FMCC', 'FOX', 'FOXA', 'FWONA', 'GLW', 'GOOG', 'HD', 'HEGIF',
#        'HENKY', 'HPQ', 'HRB', 'INFY', 'IPG', 'JNJ', 'KO', 'L', 'LANC',
#        'M', 'MBI', 'MDLZ', 'MSFT', 'NWSA', 'ORCL', 'PEP', 'PFE', 'PG',
#        'PHM', 'QRTEA', 'REXI', 'S', 'SLM', 'STT', 'SYK', 'SYY', 'TBBK',
#        'TYC', 'TYIDF', 'UN', 'UNH', 'USB', 'USG', 'VIAB', 'WFT', 'WMT',
#        'WWY', 'XOM'], dtype=object), array(['ACXM', 'AN', 'AVP', 'AZO', 'BAC', 'BIG', 'C', 'CIT', 'COF',
#        'CSCO', 'CTX', 'FNMA', 'FOSL', 'GNW', 'GPS', 'HD', 'HIG', 'HOS',
#        'HRB', 'HSNI', 'IBM', 'KBH', 'LE', 'NFLX', 'OSH', 'PHH', 'SFI',
#        'SHLD.WS', 'SHLDQ', 'SHOS', 'SLM', 'SRG', 'SRSC', 'STX', 'SWY',
#        'WAC', 'WFC'], dtype=object), array(['AAN', 'ACIW', 'AGCO', 'AGP', 'ALGT', 'AM-OLD', 'AMBA', 'APOL',
#        'ARRS', 'ARW', 'ATGE', 'ATW', 'AVT', 'BHI', 'BIG', 'BJS', 'BW',
#        'BWXT', 'CAKE', 'CC-OLD', 'CFFN', 'CHB', 'CHRS', 'CISN', 'CNC',
#        'COG', 'CRI', 'CUB', 'CXG', 'DAN', 'DPTHL', 'FHB', 'FI', 'FII',
#        'FL', 'FLE', 'GNTX', 'GPK', 'HMHC', 'HMN', 'HP', 'IDCC', 'ISBC',
#        'MATX', 'MCY', 'MKSI', 'MTN', 'NBL', 'NFX', 'NOV', 'OSK', 'PDE',
#        'PTEN', 'R', 'RCII', 'RDC', 'ROSE', 'ROST', 'RS', 'RSH', 'SAIC',
#        'SAVE', 'SIG', 'SM', 'TEN', 'THO', 'THS', 'TRN', 'TWI', 'VAL',
#        'VECO', 'VG', 'VMI', 'VNOM', 'VSTO', 'WDC', 'XEC', 'ZLC'],
#       dtype=object), array(['ACT', 'ALGT', 'ASCMA', 'AZN', 'BAC', 'BAC.WS.A', 'BB', 'BHC',
#        'BP', 'BRK.A', 'C', 'CBI', 'CHT', 'CYD', 'DELL-OL', 'DVA', 'ENDP',
#        'FCAU', 'GS', 'GSK', 'JPM', 'JPM.WS', 'LE', 'MBI', 'MGA', 'NOK',
#        'OSTK', 'PKX', 'PTGI', 'RFP', 'RSH', 'RYAAY', 'S', 'SAVE', 'SD',
#        'SHLDQ', 'SHOS', 'SNY', 'SRSC', 'TEVA', 'UTSI', 'VOD', 'VZ', 'WFC',
#        'WFC.WS'], dtype=object), array(['ACGL', 'ADBE', 'ADS', 'AMGP', 'AMX', 'ANTM', 'AON', 'AR', 'AREX',
#        'AXP', 'AXTA', 'BAC', 'BAM', 'BBU', 'BHC', 'BHI', 'BIP', 'BPY',
#        'BR', 'BRK.B', 'C', 'CMCSA', 'CMCSK-OLD', 'CMPR', 'COL', 'DELL-OL',
#        'DHI', 'DLTR', 'EQIX', 'ESRX', 'ETN', 'FB', 'FISV', 'FMCC', 'FTDR',
#        'GD', 'GOOG', 'GOOGL', 'GSM', 'HAL', 'HCA', 'HPQ', 'IQV', 'IR',
#        'JPM', 'JPM.WS', 'JW.A', 'KMI', 'LBTYA', 'LBTYK', 'LEN', 'LEN.B',
#        'LH', 'LILA', 'LILAK', 'LMT', 'LVNTA', 'MA', 'MCO', 'MSFT', 'MSI',
#        'NICK', 'NLSN', 'ONE', 'ORCL', 'PCP', 'PGR', 'PRI', 'RJF', 'RNR',
#        'RRC', 'RYAAY', 'SCHW', 'SERV', 'SGU', 'ST', 'T', 'TDW', 'UNH',
#        'USB', 'V', 'VAR', 'WAT', 'WFC', 'XTEX', 'XTXI'], dtype=object), array(['AXP', 'BAC', 'BAC.WS.A', 'BRK.A', 'BRK.B', 'C', 'DTV', 'ENLC',
#        'FCAU', 'GM.WS.B', 'GS', 'MA', 'MCO', 'MU', 'PKX', 'RACE', 'SRG',
#        'TERP', 'TOO', 'WFC', 'WFC.WS', 'ZINC'], dtype=object), array(['A', 'ABT', 'ADI', 'AER', 'AES', 'AET', 'AGN', 'AIG', 'ALXN',
#        'AMAT', 'ANTM', 'AON', 'APOL', 'AR', 'BAC', 'BAX', 'BG', 'BHI',
#        'BP', 'BRK.A', 'BRK.B', 'BRL', 'BSX', 'C', 'CAH', 'CB', 'CBS',
#        'CFG', 'CI', 'CIT', 'CMCSA', 'COF', 'COP', 'CPN', 'CS', 'CSCO',
#        'CTXS', 'CVS', 'CVX', 'DAL', 'DD-OLD', 'DIS', 'DTV', 'DUK', 'DVN',
#        'EBAY', 'ELAN', 'EP', 'EQT', 'ETN', 'EXC', 'FDC', 'FLEX', 'FLR',
#        'FWONA', 'GE', 'GENZ', 'GHC', 'GM', 'GNW', 'GOLD', 'GOOGL', 'GT',
#        'HES', 'HMC', 'HPE', 'HSP', 'IGT', 'INTU', 'IP', 'IPG', 'IVZ',
#        'KEYS', 'KMB', 'KO', 'LBTYK', 'LEN', 'LIFE', 'LOW', 'LUV', 'LYB',
#        'LYO', 'MDLZ', 'MET', 'MMC', 'MRK', 'MRO', 'MS', 'MSFT', 'NEM',
#        'NLOK', 'NVS', 'NXPI', 'OI', 'ORCL', 'OXY', 'PFE', 'PG', 'PGR',
#        'PNR', 'PRGO', 'PXD', 'QCOM', 'RDS.A', 'RLGY', 'RS', 'RSG', 'SABR',
#        'SCHW', 'SE-OLD', 'SIVB', 'SLB', 'SNY', 'ST', 'STT', 'SUN', 'SYY',
#        'TDC', 'TMO', 'TOT', 'TWX', 'TXN', 'UN', 'UNH', 'UNM', 'USB', 'V',
#        'VLO', 'VOD', 'VZ', 'WBA', 'WFT', 'WM', 'WMT', 'YHOO'],
#       dtype=object), array(['AABA', 'ABEV', 'AIG', 'AIQ', 'ALLY', 'AMX', 'APFH', 'APO', 'AU',
#        'AZUL', 'BABA', 'BANR', 'BBD', 'BCEI', 'BIDU', 'BRFS', 'BRY',
#        'CCS', 'CEO', 'CHTR', 'CIT', 'CMLS', 'CX', 'CXPO', 'CZR', 'DLPH',
#        'DMND', 'DOOR', 'DYN', 'EGC', 'EGLE', 'ETFC', 'EURN', 'FBP',
#        'FCNCA', 'GNRT', 'GTY', 'IBN', 'INFN', 'INFY', 'ITUB', 'JD',
#        'LBTYA', 'LNCE', 'LVLT', 'LVNTA', 'MCF', 'MTG', 'MX', 'NMIH',
#        'NRG', 'NSM', 'NTAP', 'ORBK', 'ORIG', 'PBR', 'PCG', 'PULS', 'SBLK',
#        'SCAI', 'SMCI', 'STKL', 'STOR', 'SWY', 'TMHC', 'TMS-OLD', 'TPCO',
#        'TRCO', 'TRMD', 'TSL', 'TSM', 'TTM', 'TV', 'VALE', 'VICI', 'VIV',
#        'VRS', 'VSH', 'VST', 'XCO', 'YHOO'], dtype=object), array(['AEM', 'ANTM', 'APA', 'ASCMA', 'AXP', 'BBT', 'BK', 'BLT', 'BOL',
#        'BRK.A', 'BRO', 'CHRW', 'CINF', 'CL', 'CMCSA', 'CMCSK-OLD', 'CMTL',
#        'CNQ', 'COP', 'COST', 'CPRT', 'CSCO', 'CTAS', 'DE', 'DVN', 'FE',
#        'FLS', 'FTI', 'FWONA', 'GOOGL', 'GYI', 'HD', 'HP', 'INTC', 'ISCA',
#        'JNJ', 'LLTC', 'LMT', 'LO', 'MCD', 'MMM', 'MSFT', 'MUR', 'NEM',
#        'NOC', 'NOV', 'NTR', 'NYT', 'OA', 'OMC', 'ORCL', 'PCL', 'PM',
#        'POT', 'QRTEA', 'RSTI', 'RYN', 'SJT', 'SLB', 'SNY', 'SYF', 'SYY',
#        'TDC', 'TFC', 'TXN', 'TYC', 'UNF', 'UNP', 'USB', 'UTIW', 'VAR',
#        'WLTW', 'WMT', 'WRB', 'WY', 'XLNX', 'XOM', 'Y'], dtype=object), array(['AABA', 'ABBV', 'ACCL', 'ACF', 'ACN', 'ADBE', 'AET', 'ALA', 'ALR',
#        'APD', 'ATVI', 'AVGO', 'AVY', 'AXTA', 'BAX', 'BCR', 'BF.B', 'BHP',
#        'BIIB', 'CHTR', 'CMCSA', 'CME', 'CNC', 'CNI', 'COL', 'COLD', 'COP',
#        'COTY', 'COWN', 'CRESY', 'CSWC', 'CXO', 'D', 'DB', 'DG', 'DISCA',
#        'DISCK', 'DISH', 'DRI', 'DVMT', 'DXC', 'EMC', 'EMN', 'ENWV',
#        'EQNR', 'FANG', 'FB', 'FCX', 'FDX', 'FEIC', 'FNB', 'FOX', 'FOXA',
#        'FRGI', 'FTI', 'FWONA', 'FWONK', 'GD', 'GEOI', 'GLIBA', 'GLPW',
#        'GOLD-OLD', 'HES', 'HPE', 'HPQ', 'HRG', 'HRS', 'HUN', 'IAAC',
#        'IAC', 'INTL', 'ITC', 'JEF-OLD', 'JNS', 'KEQU', 'LBRDA', 'LCAHW',
#        'LGF.A', 'LGF.B', 'LONE', 'LSXMA', 'LSXMK', 'LTRPA', 'LVLT',
#        'LVNTA', 'MAM', 'MBLY', 'MEG', 'MHK', 'MLI', 'MNRL', 'MOMO', 'MON',
#        'MSG', 'NDAQ', 'NSAM', 'NWSA', 'NXPI', 'NYRT', 'PAHC', 'PE', 'PG',
#        'PGR', 'PVTB', 'QCP', 'RAD', 'RAI', 'REGI', 'REGN', 'RTLR', 'SABR',
#        'SBLK', 'SE-OLD', 'SIG', 'SINA', 'SMCG', 'SMMX', 'SNI', 'SODA',
#        'SPB', 'SPNC', 'STBZ', 'STJ', 'STZ', 'SXT', 'SYT', 'T', 'TA',
#        'TEX', 'TGT', 'TPIC', 'TRCO', 'TTD', 'TWX', 'UA', 'UNH', 'URBN',
#        'UWBK', 'VAR', 'VECO', 'VLO', 'VZ', 'WINN', 'WNG', 'WPX', 'WR',
#        'WTRH', 'XL', 'YHOO', 'ZBH', 'ZEUS'], dtype=object), array(['ACA', 'ADBE', 'ADS', 'ADSK', 'AES', 'AFI', 'AGU', 'ALB', 'ALSN',
#        'AOS', 'ARMK', 'AWI', 'AXP', 'BCR', 'BHC', 'BHI', 'BIVV', 'BKNG',
#        'BKR', 'BP', 'C', 'CBRE', 'CF', 'COL', 'CPWR', 'DAR', 'DRC', 'EIX',
#        'ES-OLD', 'ESRX', 'EVA', 'EXPD', 'FDX', 'FNF', 'FOX', 'FOXA',
#        'GDI', 'HAL', 'HE', 'ICE', 'INT', 'KAR', 'KKR', 'LIND', 'LKQ',
#        'MCO', 'MCRS', 'MOS', 'MOT', 'MS', 'MSCI', 'MSFT', 'MSI', 'NLOK',
#        'NTCT', 'NYT', 'OUT', 'PCG', 'PCP', 'PPO', 'PSN', 'SLE', 'SLM',
#        'SPGI', 'STRA', 'STX', 'TECH', 'TIBX', 'TRN', 'TSG', 'TW-OLD',
#        'UFI', 'VLO', 'VRRM', 'VRSN', 'WCC', 'WLTW', 'XPO', 'XRAY'],
#       dtype=object), array(['ACN', 'AFL', 'ATGE', 'AXE', 'BAX', 'BDK', 'BEN', 'BOKF', 'BRS',
#        'BWA', 'BX', 'CAH', 'CBRE', 'CBS', 'CCL', 'CHK', 'CLX', 'CRL',
#        'CYN', 'DELL-OL', 'DNB', 'EFX', 'ENR', 'FAF', 'GCI', 'HEW', 'HLI',
#        'HRB', 'HSP', 'IGT', 'IMS', 'IPG', 'ISCA', 'ITW', 'JLL', 'JNS',
#        'JWN', 'KEYS', 'KKR', 'KMT', 'LAZ', 'LH', 'MAT', 'MHK', 'MNI',
#        'MSGN', 'NLSN', 'NOV', 'NTRS', 'OMC', 'PBI', 'PGR', 'SJM', 'SNA',
#        'SRCL', 'STJ', 'STZ', 'SWK', 'TIF', 'TMO', 'TPR', 'TRB-OLD',
#        'TROW', 'TW-OLD', 'VIAB', 'VIAC', 'WLTW', 'WU', 'YUM', 'ZBH'],
#       dtype=object), array(['AGO', 'ASTE', 'BB', 'BMY', 'BP', 'C', 'GNE', 'GSK', 'HOLX', 'IDT',
#        'IDWM', 'MBI', 'MODL', 'MRK', 'NAVI', 'NTP', 'NVS', 'NYCB', 'NYT',
#        'ORI', 'PBNY', 'PFE', 'PTEN', 'RFL', 'RSTK-D', 'SEB', 'SLM', 'STL',
#        'STRP', 'SYMS', 'TPHS', 'USG', 'VOXX'], dtype=object), array(['AAPL', 'ABBV', 'ADBE', 'AER', 'AET', 'AGN', 'ALNY', 'ALSN',
#        'AMZN', 'ANDV', 'ANTM', 'ARMK', 'ARRS', 'ASH', 'AVGO', 'AVTR',
#        'AXP', 'BABA', 'BHC', 'BIDU', 'BKNG', 'BTI', 'BUD', 'CBS', 'CCI',
#        'CCK', 'CHTR', 'CI', 'CIT', 'CMCSA', 'CNC', 'COF', 'COMM', 'CPN',
#        'CSC', 'CTRX', 'CTSH', 'CTVA', 'CTXS', 'CYH', 'DD', 'DG', 'DIS',
#        'DLTR', 'DOW', 'DXC', 'EVHC', 'EXP', 'FB', 'FIS', 'FISV', 'FLT',
#        'FOXA', 'FTNT', 'GOOG', 'GPK', 'HCA', 'HD', 'HUM', 'INTC', 'IPXL',
#        'KAR', 'KHC', 'KKR', 'KSU', 'LBTYK', 'LOW', 'LRCX', 'LVLT', 'MA',
#        'MCK', 'MDCO', 'MGM', 'MHK', 'MLM', 'MNST', 'MON', 'MSFT', 'MTG',
#        'MU', 'NFLX', 'NKE', 'NKTR', 'NOC', 'NRF', 'NWL', 'OC', 'ONEM',
#        'ORLY', 'PANW', 'PF', 'PFE', 'PM', 'PRSP', 'QCOM', 'QIHU', 'QSR',
#        'RDN', 'RL', 'SABR', 'SC', 'SCHW', 'SHPG', 'SNAP', 'SSNC', 'ST',
#        'STNE', 'STZ', 'SWI', 'TAP', 'TDG', 'TMH', 'TMUS', 'UHS', 'UNH',
#        'USB', 'USFD', 'V', 'VMC', 'WCN', 'WLK', 'WP', 'WYNN'],
#       dtype=object), array(['ABR', 'ACT', 'ADBE', 'AER', 'AGN', 'AIG', 'AMCX', 'AMZN', 'APL',
#        'ASH', 'ASPS', 'ATLS', 'BKNG', 'BLL', 'BSX', 'C', 'CCL', 'CI',
#        'CIM', 'CNC', 'COF', 'COOP', 'CVS', 'CZR', 'DD', 'DISH', 'DOW',
#        'DVMT', 'EBAY', 'EMN', 'ESRX', 'ET', 'ETE', 'ETFC', 'ETP', 'FANG',
#        'FB', 'FDC', 'FISV', 'FNF', 'FOE', 'FOXA', 'GCI', 'GLPI', 'GM',
#        'GOOGL', 'HAL', 'HCA', 'HES', 'HRG', 'HUM', 'JPM', 'KAR', 'KEA',
#        'KFN', 'KMI', 'LINE', 'LORL', 'LYB', 'MCK', 'MET', 'MGM', 'MMR',
#        'MPC', 'MSFT', 'MSI', 'MXL', 'NAVI', 'NBR', 'NEWM', 'NGLS', 'NLSN',
#        'NRG', 'NRZ', 'NYX', 'OCN', 'OMF', 'PE', 'PFE', 'PFSI', 'PVH',
#        'PYPL', 'QCOM', 'RIG', 'RLGY', 'S', 'SBGI', 'SD', 'SHPG', 'SIRI',
#        'SLM', 'SNR', 'SUNE', 'SYF', 'TIME', 'TMO', 'TRCO', 'TRGP', 'TRN',
#        'TRWH', 'UAL', 'UNH', 'VICI', 'VVV', 'WBA', 'WPX', 'XL'],
#       dtype=object), array(['ABT', 'AXP', 'BAX', 'BMS', 'CEN', 'CHRW', 'COR', 'DCI', 'DIS',
#        'ECL', 'EMR', 'FAST', 'FISV', 'FUL', 'GE', 'GGG', 'GIS', 'GOOG',
#        'HON', 'HRL', 'JNJ', 'MDT', 'MMM', 'MSFT', 'MTSC', 'NVDA', 'PFE',
#        'PFG', 'PNR', 'RHHBY', 'SLB', 'STJ', 'TCF', 'TECH', 'TGT', 'TTC',
#        'UNH', 'USB', 'V', 'VAL-OLD', 'WFC', 'ZBH'], dtype=object), array(['AA', 'AAPL', 'ADBE', 'ADP', 'AEP', 'AET', 'AKAM', 'ALD', 'ALL',
#        'AMD', 'AMGN', 'AMZN', 'AXP', 'BA', 'BAC', 'BBY', 'BDX', 'BIIB',
#        'BK', 'BMY', 'BUD', 'C', 'CAT', 'CL', 'CMG', 'CMP', 'CPB', 'CSCO',
#        'CVS', 'DD', 'DD-OLD', 'DHI', 'DIS', 'EBAY', 'EMC', 'EMR', 'EPD',
#        'FB', 'FDX', 'GE', 'GIS', 'GLW', 'GPS', 'GR', 'GS', 'HD', 'HNZ',
#        'HOT', 'HPQ', 'HST', 'HSY', 'IBM', 'INTC', 'IR', 'JNJ', 'JOY',
#        'JPM', 'JWN', 'K', 'KHC', 'LH', 'LLY', 'LRCX', 'MCD', 'MDLZ',
#        'MDT', 'MKC', 'MOT', 'MRK', 'MSFT', 'NKE', 'NSC', 'NUE', 'ODP',
#        'ORCL', 'PANL', 'PETM', 'PFE', 'PG', 'QCOM', 'RIG', 'ROK', 'RTN',
#        'SBUX', 'SJM', 'SO', 'SPG', 'SPLS', 'SRCL', 'SYY', 'T', 'TGT',
#        'TIF', 'TXN', 'VZ', 'WFC', 'WFM', 'WMT', 'WU', 'XOM', 'YHOO',
#        'YUM'], dtype=object), array(['ABT', 'AGN', 'AMG', 'ANK', 'AON', 'BEN', 'BK', 'BRK.A', 'BRK.B',
#        'CEIX', 'CHK', 'CHKGF', 'CKHUY', 'CMCSA', 'CNHI', 'CNX', 'CPB',
#        'CTL', 'CX', 'DD', 'DD-OLD', 'DELL-OL', 'DIS', 'DTV', 'EBAY',
#        'FDX', 'FFH', 'FWONA', 'GE', 'GM', 'GOOG', 'H', 'HCMLF', 'IHG',
#        'JAVA', 'L', 'LFGEF', 'LMDIA', 'LVLT', 'MAR', 'MAT', 'MCD', 'MDLZ',
#        'MUR', 'NLOK', 'NPPKF', 'NWSA', 'PHG', 'PHGFF', 'PK', 'PXD',
#        'QRTEA', 'RL', 'RTX', 'S', 'SNI', 'TDS', 'TDS.S', 'TROW', 'TRV',
#        'UBS', 'VIVEF', 'VMC', 'WBA', 'WLTW', 'WMB', 'WYNN', 'YUM'],
#       dtype=object), array(['AAPL', 'ABM', 'ABT', 'ACXM', 'ADBE', 'ADSK', 'AGR', 'AGU', 'AIG',
#        'AIN', 'AIZ', 'AJG', 'ALEX', 'AMD', 'AMMD', 'AMTD', 'APA', 'AT',
#        'ATR', 'AVA', 'AVP', 'AW', 'BAX', 'BBY', 'BCR', 'BDK', 'BEAV',
#        'BEC', 'BEN', 'BG', 'BKC', 'BOH', 'BOKF', 'BR', 'BUD', 'BYI', 'C',
#        'CACI', 'CBT', 'CCL', 'CELG', 'CEPH', 'CFG', 'CLH', 'CMP', 'CNW',
#        'COGN', 'COST', 'COV', 'CRI', 'CRL', 'CSCO', 'CSL', 'CTAS', 'CTXS',
#        'CVA', 'CVBF', 'CVS', 'CVX', 'CW', 'DBD', 'DENN', 'DEO', 'DKS',
#        'DYN', 'EA', 'EAT', 'EBAY', 'EFX', 'ENS', 'EOG', 'FELE', 'FEYE',
#        'FII', 'FLIR', 'FLO', 'FLS', 'FNFG', 'FRED', 'FST', 'FTNT', 'GFI',
#        'GIL', 'GMT', 'GPK', 'GWR', 'GWW', 'HAE', 'HBI', 'HE', 'HEES',
#        'HOLX', 'HPY', 'HUM', 'HURN', 'ICLR', 'IFF', 'INFA', 'INTC',
#        'IPXL', 'IRDM', 'JPM', 'KBR', 'KMB', 'KMI', 'KSS', 'KW', 'LAZ',
#        'LECO', 'LGF.B', 'LII', 'LIZ', 'LKQ', 'LLTC', 'LOGM', 'LVS',
#        'MASI', 'MAT', 'MATX', 'MDLZ', 'MDU', 'MLNX', 'MOGN', 'MON', 'MSA',
#        'MSFT', 'MU', 'MVL', 'NEM', 'NKTR', 'NLC', 'NLY', 'NOK', 'NOMD',
#        'NSC', 'NTR', 'NUAN', 'NVDA', 'NWL', 'OAK', 'OI', 'ORI', 'OXY',
#        'PENN', 'PFE', 'PGN', 'PHG', 'PII', 'PLCE', 'POWI', 'PRGO', 'PTV',
#        'QCOM', 'RAMP', 'RAX', 'RBA', 'RBC', 'RF', 'RIG', 'RYN', 'SCHN',
#        'SCS', 'SCSS', 'SEE', 'SEIC', 'SERV', 'SHW', 'SKX', 'SMG', 'SRCL',
#        'STE', 'STT', 'SUM', 'SWCH', 'SWK', 'SWY', 'SYF', 'SYNA', 'SYY',
#        'TAP', 'TERP', 'THS', 'TOT', 'TRMB', 'TRV', 'UMPQ', 'UNP', 'USB',
#        'UTIW', 'UVV', 'VICI', 'VRNT', 'VRSN', 'VZ', 'WDC', 'WFC', 'WLTW',
#        'WM', 'WMS', 'WWW', 'XYL', 'YUM', 'ZBRA'], dtype=object), array(['AABA', 'ALEX', 'BA', 'BABA', 'BB', 'BBBY', 'BIIB', 'CAH', 'CELG',
#        'CLF', 'CNQ', 'CPLG', 'CVE', 'CVET', 'DIS', 'DISCA', 'FB', 'FDX',
#        'FPH', 'GME', 'GOOG', 'GOOGL', 'GSKY', 'JBX', 'JD', 'MAXR', 'MCK',
#        'MHK', 'MIK', 'NVTRQ', 'PETQ', 'QRVO', 'SPWH', 'TLRD', 'WDC'],
#       dtype=object), array(['ABBC', 'ABCW', 'ABFS', 'ACBI', 'ADES', 'ADS', 'AIG', 'AJRD',
#        'ALC', 'ALLY', 'AM-OLD', 'AMZN', 'APC', 'ARIA', 'AWH', 'AWI',
#        'BAC', 'BANC', 'BCBP', 'BDX', 'BEN', 'BG', 'BHF', 'BKS', 'BLT',
#        'BMCH', 'BPOP', 'BRK.A', 'BSX', 'BUD', 'C', 'CAB', 'CACH', 'CARE',
#        'CBS', 'CCE-OLD', 'CELG', 'CF', 'CIT', 'CLR', 'CNO', 'COLB', 'COP',
#        'COT', 'COV', 'CPB', 'CWGL', 'DAL', 'DD', 'DD-OLD', 'DEST', 'DJ',
#        'DLB', 'DO', 'DOW', 'ECPG', 'ELN', 'EMC', 'EP', 'EQ', 'ESGR',
#        'FARM', 'FBTX', 'FCE.A', 'FLA', 'FMC', 'FOSL', 'FRNK', 'FRSH',
#        'FSGI', 'FTI', 'GBL', 'GENZ', 'GLBR', 'GLF', 'GR', 'GT', 'GYI',
#        'HCBK', 'HEOP', 'HES', 'HPQ', 'HRS', 'HSP', 'HTH', 'HTV', 'HURN',
#        'INTC', 'IR', 'ISBC', 'ITT', 'JCP', 'JEF', 'JNS', 'KALU', 'KLXI',
#        'KRNY', 'LABC', 'LTD', 'MDCO', 'MDLZ', 'MDP', 'MNI', 'MOT', 'MVC',
#        'MWE', 'NFG', 'NODK', 'NPK', 'NWA', 'NWEC', 'OABC', 'OGBY', 'OKE',
#        'PAA', 'PAY', 'PFE', 'PM', 'PNC', 'RDC', 'RF', 'RUTH', 'SANW',
#        'SFD', 'SHLDQ', 'SLM', 'SNE', 'SPGI', 'SYA', 'T', 'TCO', 'TDS',
#        'TEL', 'TEVA', 'TFSL', 'TIF', 'TOWN', 'TPHS', 'TRA', 'TRB-OLD',
#        'TRC', 'TRH', 'TT', 'TWC', 'TWX', 'TYC', 'VNO', 'VPHM', 'WBC',
#        'WCBO', 'WLK', 'WMGI', 'WSBF', 'WWY', 'WYE', 'XPO', 'Y'],
#       dtype=object), array(['AER', 'ATSG', 'BAC', 'BIP', 'BPO', 'BRK.A', 'BRK.B', 'BRP', 'C',
#        'CCRT', 'CHK', 'CRESY', 'CRYP', 'CSE', 'DTV', 'EAF', 'FCAU', 'FFH',
#        'GM', 'GM.WS.B', 'GOOG', 'GS', 'HNR', 'IBKR', 'ICO', 'JEF', 'LUV',
#        'MU', 'NXEO', 'NXEOU', 'PKX', 'PNCL', 'POT', 'RACE', 'SHLDQ',
#        'SRG', 'TECK', 'TEX', 'TX', 'WFC', 'ZINC'], dtype=object), array(['ALLE', 'BK', 'CC', 'DD', 'DD-OLD', 'FDO', 'GE', 'IR', 'LM',
#        'MDLZ', 'NVT', 'PEP', 'PG', 'PNR', 'PPG', 'SYY', 'TIF', 'WEN'],
#       dtype=object), array(['ANSS', 'AVLR', 'AYX', 'BAM', 'CHGG', 'CMPR', 'DESP', 'DG', 'DSGX',
#        'EBAY', 'FB', 'GOOG', 'PYPL', 'ROKU', 'ROP', 'SITE', 'TTD', 'WIX',
#        'WK', 'YELP'], dtype=object), array(['AA', 'ABH', 'ABT', 'AGX', 'ALR', 'ALTR', 'ATCO', 'AZN', 'BB',
#        'BCE', 'BEN', 'BKNG', 'BNI', 'BNS', 'BRK.A', 'BRK.B', 'BRO',
#        'BWINB-OLD', 'BYI', 'C', 'CBI', 'CBST', 'CCAP', 'CRAY', 'CRESY',
#        'CRR', 'CSX', 'CTB', 'CTL', 'CTRX', 'CVX', 'DELL-OL', 'DRC',
#        'DSSI', 'DXM', 'EROS', 'FIT', 'FLR', 'FTR', 'GCI', 'GE', 'GM',
#        'GOOGL', 'GSK', 'HP', 'IBM', 'IBN', 'ICO', 'IDIX', 'INTC', 'IPI',
#        'JEC', 'JEF', 'JNJ', 'KG', 'KLIC', 'KW', 'LMNS', 'LRN', 'LVLT',
#        'LXK', 'MCFT', 'MDLZ', 'MDR', 'MGA', 'MHK', 'MMI', 'MON', 'MU',
#        'MYRG', 'NEU', 'NTES', 'NVDQ', 'NWPX', 'NXY', 'NYCB', 'NYT',
#        'ONCE', 'ORH', 'ORI', 'OSTK', 'PFE', 'PGH', 'PGR', 'PKX', 'PPO',
#        'RAIL', 'RE', 'RFP', 'RPXC', 'RYAAY', 'RYAM', 'SBNY', 'SD', 'SIX',
#        'SLCA', 'SLH', 'SPMD', 'SSW', 'STEI', 'TRQ', 'TSM', 'UPL', 'USB',
#        'USG', 'VRUS', 'WFC', 'WMT', 'XCO', 'ZNT'], dtype=object), array(['ABC', 'ABT', 'AET', 'AIG', 'ALA', 'ALL', 'AMGN', 'ANTM', 'APOL',
#        'AXS', 'BA', 'BAC', 'BAX', 'BDX', 'BEN', 'BHI', 'BKR', 'BMY', 'BP',
#        'C', 'CA', 'CAH', 'CB', 'CI', 'CMA', 'COF', 'CSC', 'CTSH',
#        'DELL-OL', 'DLPH', 'DOV', 'EIX', 'EQH', 'ESRX', 'ETR', 'F', 'FMCC',
#        'FNF', 'FNMA', 'FO', 'FRX', 'GE', 'GL', 'GM', 'GOOGL', 'GS', 'HAL',
#        'HD', 'HLT', 'HPE', 'HPQ', 'INTC', 'IPG', 'IVZ', 'JCP', 'JNJ',
#        'JPM', 'KMB', 'LEA', 'LH', 'LLL', 'MAS', 'MAT', 'MCK', 'MET',
#        'MGA', 'MHK', 'MOT', 'MRK', 'MS', 'MSFT', 'MUR', 'MYL', 'NOC',
#        'NOV', 'NWL', 'NWSA', 'OMC', 'ORCL', 'PFE', 'PH', 'PNC', 'PPG',
#        'PVH', 'RDS.A', 'RF', 'SHW', 'SPLS', 'SRE', 'STT', 'STX', 'SWK',
#        'TAP', 'TEL', 'TJX', 'TRW', 'UBS', 'VOYA', 'WAB', 'WB-OLD', 'WEC',
#        'WFC', 'WHR', 'WLTW', 'WMT', 'XL', 'XOM', 'ZBH'], dtype=object), array(['A', 'AAPL', 'AB', 'ABB', 'ABM', 'ABT', 'AIG', 'AON', 'AVY', 'AXP',
#        'BAX', 'BBBY', 'BBT', 'BDX', 'BEN', 'BER', 'BK', 'BKC', 'BLK',
#        'BSX', 'BX', 'BYD', 'C', 'CAKE', 'CFG', 'CFN', 'CMCSA', 'CMI',
#        'CNDT', 'COF', 'COMM', 'COV', 'CRI', 'CSCO', 'CTAS', 'CVS', 'DAL',
#        'DBI', 'DBRN', 'DD-OLD', 'DDS', 'DE', 'DELL-OL', 'DENN', 'DGX',
#        'DIS', 'DISCK', 'DPS', 'EBAY', 'EFX', 'ESRX', 'EXPR', 'FD', 'FDX',
#        'FITB', 'FL', 'FOSL', 'FOX', 'GBX', 'GDI', 'GE', 'GM', 'GNRC',
#        'GNW', 'GOOG', 'GPS', 'GS', 'GT', 'HAL', 'HAR', 'HAS', 'HD', 'HEW',
#        'HLX', 'HOG', 'HPQ', 'HSP', 'IBM', 'IGT', 'IN', 'INTC', 'IR',
#        'IVZ', 'JAS', 'JLL', 'JNJ', 'JNS', 'JPM', 'KEYS', 'KLIC', 'KSS',
#        'LIFE', 'LM', 'LOW', 'M', 'MCD', 'MDT', 'MER', 'MHK', 'MMC', 'MMM',
#        'MS', 'MSFT', 'NAFC', 'NCR', 'NOV', 'NP', 'NR', 'NWL', 'NYX',
#        'ODP', 'OI', 'OMC', 'ORCL', 'OSK', 'PB', 'PBI', 'PDCO', 'PEP',
#        'PETM', 'PLL', 'PSS', 'PWR', 'RBC', 'ROST', 'RSH', 'RT', 'RTX',
#        'SAVE', 'SCHW', 'SEAS', 'SNI', 'SPLS', 'SRCL', 'ST', 'STZ', 'SYK',
#        'TAP', 'TDC', 'TEL', 'TER', 'TFX', 'TKR', 'TMO', 'TPR', 'TW-OLD',
#        'TYC', 'UNH', 'UPS', 'USB', 'V', 'VIAB', 'VIAC', 'VLO', 'VSI',
#        'VWR', 'WBA', 'WCC', 'WDC', 'WHR', 'WMB', 'WRK', 'XL', 'XOM',
#        'XRX', 'ZBH', 'ZBRA', 'ZQK'], dtype=object), array(['ABKFQ', 'ABT', 'ADP', 'AFL', 'AIG', 'AMAT', 'AMGN', 'ANTM', 'AXP',
#        'BAC', 'BAX', 'BDX', 'BMY', 'BP', 'BRK.B', 'BWP', 'C', 'CAH', 'CB',
#        'CBI', 'CHK', 'CL', 'CSCO', 'CTAS', 'DD', 'DD-OLD', 'DHR', 'DIS',
#        'DOW', 'DTV', 'EDS', 'EMC', 'ETN', 'FFH', 'GCI', 'GD', 'GE', 'GM',
#        'GRA', 'GS', 'HAE', 'HPE', 'HPQ', 'IBM', 'INTC', 'ITW', 'JNJ',
#        'JPM', 'KBR', 'KHC', 'KMX', 'L', 'LAB', 'LLY', 'MDLZ', 'MDT',
#        'MKL', 'MMC', 'MMM', 'OC', 'ORLY', 'PG', 'RDS.A', 'RSG', 'SPGI',
#        'SWK', 'SYY', 'T', 'TGNA', 'TRB-OLD', 'TUP', 'UNH', 'USEC', 'USG',
#        'VIAB', 'VMW', 'WBA', 'WFC', 'WU'], dtype=object), array(['AAPL', 'ABT', 'ACN', 'ADBE', 'ADP', 'AME', 'APH', 'BCR', 'BDX',
#        'CDW', 'CHRW', 'CL', 'CTSH', 'DHR', 'ECL', 'EFX', 'EMR', 'GE',
#        'GIS', 'GOOGL', 'INTU', 'JNJ', 'KO', 'LNAGF', 'MA', 'MDT', 'MMM',
#        'MSFT', 'NKE', 'OMC', 'ORCL', 'PAYX', 'PEP', 'PFE', 'PG', 'PX',
#        'RTX', 'SPGI', 'SYK', 'SYY', 'TJX', 'TROW', 'UNH', 'UPS', 'VAR',
#        'VFC', 'WAT', 'WFC'], dtype=object), array(['AAP', 'ACOPF', 'AMZN', 'ANET', 'APOL', 'BBBY', 'BDX', 'BHC',
#        'BKNG', 'BMBLF', 'BRK.A', 'BRK.B', 'BRO', 'CACC', 'CAT', 'CMG',
#        'CMI', 'CNSWF', 'COIHF', 'COST', 'DHR', 'DLRUF', 'EA', 'ERFSF',
#        'EXPD', 'FAST', 'FB', 'FSLR', 'FWONK', 'GOOG', 'GOOGL', 'GS',
#        'HCXLF', 'IBM', 'IDXX', 'IMIAF', 'INT', 'JEC', 'KMX', 'KNX',
#        'LBRDK', 'LOW', 'MA', 'MHK', 'MLM', 'MLSPF', 'NPSNY', 'NVZMY',
#        'OMC', 'ORLY', 'PAH3.DE', 'PCAR', 'PCP', 'PDCO', 'PGR', 'PPAMF',
#        'PRGO', 'PROSF', 'PX', 'QNTQF', 'RBA', 'RYCEF', 'SCHW', 'SIRO-OLD',
#        'SMTGF', 'TGT', 'TIF', 'TJX', 'UNH', 'VIVEF', 'VMC', 'VOPKF', 'W',
#        'WAT', 'WBA', 'WFC', 'WFM', 'WMT', 'XRAY'], dtype=object), array(['AAPL', 'ABBV', 'ADNT', 'AES', 'AET', 'AFL', 'AGN', 'AIG', 'ALB',
#        'ALXN', 'AMGN', 'AMH', 'AMP', 'AMZN', 'ANET', 'APA', 'AXP', 'AZO',
#        'BAC', 'BB', 'BIIB', 'BLK', 'BMY', 'BP', 'BRCM-OLD', 'BUD', 'C',
#        'CA', 'CAG', 'CELG', 'CFC', 'CL', 'CNX', 'COF', 'COP', 'CPN',
#        'CSCO', 'CTSH', 'CVS', 'CVX', 'DAL', 'DTV', 'DVN', 'DXC', 'EA',
#        'EBAY', 'EK', 'EMC', 'EQH', 'ESRX', 'EXC', 'EXPE', 'F', 'FB',
#        'FITB', 'FMCC', 'GE', 'GENZ', 'GILD', 'GNW', 'GOOGL', 'GS', 'GSK',
#        'HAL', 'HD', 'HNT', 'HPQ', 'IAC', 'IBM', 'ICE', 'INTC', 'JCI',
#        'JNJ', 'JPM', 'KMI', 'LOW', 'LYB', 'MCD', 'MDLZ', 'MDT', 'MER',
#        'MET', 'MRK', 'MRVL', 'MSFT', 'MYL', 'NEM', 'NLY', 'NXPI', 'NYX',
#        'ORCL', 'PAGP', 'PEP', 'PFE', 'PG', 'PHM', 'PM', 'PNC', 'PSX',
#        'PXD', 'Q-OLD', 'QCOM', 'QRVO', 'RGLD', 'RIG', 'RLGY', 'RTX', 'S',
#        'SHLDQ', 'SRCL', 'STT', 'SYF', 'TDC', 'TEVA', 'TGT', 'TWX', 'TXN',
#        'TYC', 'UAL', 'UHS', 'UNH', 'VIAB', 'WFC', 'YHOO'], dtype=object), array(['AA', 'AABA', 'ABC', 'ACMR', 'ADCT', 'AER', 'AGN', 'AIG', 'AKBA',
#        'ALDW', 'ALR', 'AMV', 'ANTM', 'ANV', 'APL', 'APOL', 'AR', 'AROC',
#        'ATRA', 'AUY', 'AVEO', 'BBEP', 'BGP', 'BMY', 'BP', 'BR', 'BXE',
#        'BYD', 'C', 'C.WS.A', 'CAH', 'CAR', 'CBIO', 'CBS', 'CDS.U', 'CELG',
#        'CIT', 'CLNS', 'CLNY', 'CORE', 'CPF', 'CSE', 'DSP', 'DTV', 'DVMT',
#        'EBAY', 'EGC', 'ELN', 'ELOS', 'EMC', 'ENZN', 'ESRX', 'EST', 'FACT',
#        'FAF', 'FB', 'FNF', 'FOX', 'FOXA', 'FRH', 'FTR', 'FWONA', 'FWP',
#        'FYR', 'GAV', 'GHC-OLD', 'GHQ', 'GNW', 'GOOG', 'HD', 'HDS', 'HEK',
#        'HES', 'HLS', 'HPQ', 'HRZ', 'IAC', 'IDIX', 'IMOS', 'INSP', 'INVA',
#        'IP', 'ITRN', 'JAZ', 'KERX', 'KGC', 'KIN', 'KLXI', 'KOS', 'LBTYA',
#        'LBTYK', 'LINE', 'LMDIA', 'LNG', 'LVNTA', 'MAQ', 'MCK', 'MGAM-OL',
#        'MLS', 'MSFT', 'MU', 'NAO-OLD', 'NAQ', 'NCQ', 'NFG', 'NG', 'NLX',
#        'NRF', 'NSAM', 'NUAN', 'NWS', 'NWSA', 'NXST', 'OCN', 'OLN', 'OMN',
#        'ORCL', 'PAX', 'PBF', 'PCG', 'PDLI', 'PRTK', 'PVG', 'PXD', 'PYPL',
#        'PYX', 'QCOM', 'QNTA', 'QRVO', 'REGN', 'RFMD', 'RHIE', 'ROVI',
#        'SCHS', 'SCMR', 'SEA', 'SEMI', 'SHA', 'SLM', 'SLRC', 'STRZA',
#        'SYF', 'T', 'TAK', 'TBIO', 'TBPH', 'TCW', 'TOH', 'TQNT', 'TRCO',
#        'TWX', 'UCO', 'UFS', 'UNH', 'UNVR', 'VIAC', 'VMW', 'VOXX', 'VRTV',
#        'VSAT'], dtype=object), array(['AAPL', 'ACN', 'ACT', 'ADBE', 'ADSK', 'AGN', 'AMP', 'AMX', 'AMZN',
#        'APH', 'APOL', 'ATVI', 'AVGO', 'AXP', 'AZO', 'BABA', 'BAC', 'BAM',
#        'BAX', 'BBBY', 'BHC', 'BIDU', 'BKNG', 'BLK', 'BUD', 'C', 'CBRE',
#        'CCI', 'CCL', 'CHTR', 'CL', 'CMCSA', 'CME', 'CP', 'CPRI', 'CRM',
#        'CSX', 'CTRP', 'CTSH', 'CVS', 'CX', 'DG', 'DHI', 'DIS', 'DISCA',
#        'DKS', 'DLB', 'DLTR', 'DPZ', 'DVA', 'EA', 'EBAY', 'ECL', 'EDU',
#        'EFX', 'EL', 'EP', 'EQIX', 'ESRX', 'ETR', 'EXP', 'EXPE', 'FAST',
#        'FB', 'FDC', 'FDO', 'FLIR', 'FLT', 'FMX', 'FOXA', 'FTI', 'GMCR',
#        'GOOG', 'GOOGL', 'GPN', 'GPS', 'GR', 'HANS', 'HPQ', 'HSBC', 'HTZ',
#        'HUM', 'ICE', 'ILMN', 'INFY', 'IQV', 'ISRG', 'JD', 'JPM', 'KMI',
#        'KO', 'LBTYK', 'LK', 'LMDIA', 'LNG', 'LO', 'LOW', 'LULU', 'LVS',
#        'MA', 'MCD', 'MELI', 'MHS', 'MJN', 'MNST', 'MON', 'MSFT', 'MSM',
#        'MTCH', 'NCC', 'NFLX', 'NKE', 'NLOK', 'NOC', 'NOW', 'NTAP', 'NTES',
#        'NVDA', 'NWSA', 'OII', 'ORLY', 'PCP', 'PEP', 'PM', 'PNC', 'PYPL',
#        'QCOM', 'RL', 'RLGY', 'SAI', 'SBAC', 'SCHW', 'SD', 'SFD', 'SHOP',
#        'SLB', 'SPGI', 'SQ', 'STRA', 'STZ', 'SWN', 'TDC', 'TDG', 'TECK',
#        'TIF', 'TMUS', 'TPR', 'TRU', 'TSM', 'TV', 'ULTA', 'UNH', 'UNP',
#        'UPS', 'URBN', 'V', 'VMC', 'VRSN', 'WBA', 'WBC', 'WFC', 'WFT',
#        'WMB', 'WYN', 'WYNN', 'XTO', 'YUM'], dtype=object), array(['AA', 'AABA', 'ABT', 'ADI', 'AIG', 'AIZ', 'ALLY', 'ANTM', 'AON',
#        'APA', 'ARKAY', 'ARNC', 'ARRS', 'AVGO', 'AXP', 'BAC', 'BIDU',
#        'BUD', 'C', 'CABJF', 'CFN', 'CHKP', 'CHTR', 'CIT', 'CKSNF',
#        'CMCSA', 'CNQ', 'COV', 'CSCO', 'CVS', 'EBAY', 'ESL', 'ESRX',
#        'EXPE', 'FB', 'GBLBF', 'GE', 'GMALF', 'GOOG', 'GOOGL', 'HCMLF',
#        'HPQ', 'IPG', 'JEF', 'JNJ', 'KMI', 'LOW', 'MEGGF', 'MSFT', 'MYL',
#        'NPSNY', 'OCR', 'OI', 'ORCL', 'ORKLY', 'OXY', 'PETM', 'PFE', 'PHG',
#        'RNSDF', 'RTX', 'TEL', 'TMO', 'TOT', 'TRH', 'TSCDF', 'UN', 'VAL',
#        'VOD', 'WBA', 'WDC', 'WFC', 'WMT', 'WPP', 'YHOO'], dtype=object), array(['ADP', 'BDX', 'BF.B', 'CHKP', 'CL', 'CLX', 'EFX', 'EL', 'FB',
#        'IDXX', 'INTU', 'JNJ', 'MAR', 'MASI', 'MKC', 'MMM', 'MSFT', 'NKE',
#        'PEP', 'PM', 'PYPL', 'SABR', 'SBUX', 'SYK', 'V', 'VRSK', 'WAT'],
#       dtype=object), array(['AKR', 'BAM', 'BK', 'CMA', 'CVCO', 'ESS', 'EXP', 'FCE.A', 'FNF',
#        'FPH', 'FR', 'GBGS', 'HA', 'HCC', 'LEN', 'LEN.B', 'LOW', 'MAC',
#        'MHK', 'ORI', 'ORIG', 'PLD', 'PNC', 'PNC.WS', 'PSA', 'RYN', 'TDW',
#        'TPHS', 'TRC', 'UHAL', 'VNO', 'WY', 'Y', 'ZION'], dtype=object), array(['AAPL', 'ADI', 'ADM', 'ADP', 'AMZN', 'BAC', 'BAM', 'BLK', 'BRK.A',
#        'BRK.B', 'BUD', 'C', 'CFX', 'DE', 'DEO', 'DIS', 'FCE.A', 'FFH',
#        'FII', 'FNF', 'GD', 'GE', 'GOOG', 'GOOGL', 'HD', 'IGT', 'JNJ',
#        'KMX', 'LFG', 'MAR', 'MBI', 'MMC', 'MSFT', 'NVO', 'RLI', 'SPGI',
#        'SYY', 'TXN', 'UBSH', 'UL', 'UNH', 'UPS', 'V', 'WBA', 'WMT', 'WPC',
#        'WTM', 'XL', 'XOM'], dtype=object), array(['ABT', 'BF.A', 'BF.B', 'BRK.A', 'BRK.B', 'BTI', 'BUD', 'CFRHF',
#        'CMCSA', 'CMCSK-OLD', 'DEO', 'GHC', 'GOOG', 'HAS', 'HKHHF', 'HRL',
#        'JCDXF', 'JPM', 'MA', 'MKL', 'MLHR', 'MLM', 'MO', 'NSRGY', 'PDRDF',
#        'PG', 'PM', 'SBMRY', 'SNI', 'UHR-D', 'UN', 'V', 'WFC', 'XOM'],
#       dtype=object), array(['AA', 'AAPL', 'ACN', 'ADT', 'AGO', 'AHONY', 'AIG', 'ALKS', 'ALL',
#        'AMZN', 'ANTM', 'APA', 'APD', 'APO', 'ARMK', 'ATVI', 'BA', 'BABA',
#        'BAC', 'BBY', 'BHC', 'BHI', 'BKNG', 'BNKJF', 'BX', 'C', 'CB',
#        'CCI', 'CCK', 'CFG', 'CHL', 'CHT', 'CINF', 'CMCSA', 'CME', 'COF',
#        'COP', 'CSC', 'CTSH', 'CVA', 'CVX', 'CYH', 'DELL-OL', 'DISH',
#        'DLMAF', 'DLPH', 'DNA', 'DOX', 'DPS', 'DTV', 'DVN', 'EPD', 'ESNT',
#        'ESRX', 'ETR', 'FB', 'FCX', 'FISV', 'FITB', 'FMCC', 'FTE', 'GE',
#        'GILD', 'GLW', 'GNW', 'GOLF', 'GOOG', 'GOOGL', 'GPS', 'GS', 'GSK',
#        'HAL', 'HFC', 'HIG', 'HPQ', 'HSBC', 'HTZ', 'HUN', 'IFF', 'IMS',
#        'ING', 'INTC', 'IPXHF', 'ITC', 'JBLU', 'JNJ', 'JPM', 'KDDIF',
#        'KHC', 'LLY', 'LOPE', 'LTM-OLD', 'LVLT', 'LVS', 'MDLZ', 'MDT',
#        'MET', 'MHK', 'MJN', 'MON', 'MOT', 'MRO', 'MSFT', 'MTU', 'NCLH',
#        'NFLX', 'NLSN', 'NMIH', 'NOMD', 'NORD', 'OAK', 'OGZPY', 'ORLY',
#        'PAHC', 'PCU', 'PMT', 'PRGO', 'PSTG', 'RAD', 'RHHVF', 'RIG',
#        'RPCGY', 'RSG', 'SBUX', 'SCHW', 'SD', 'SFTBF', 'SGEN', 'SHLDQ',
#        'SPLS', 'STJ', 'SWCEY', 'T', 'TEVA', 'TGT', 'TM', 'TMO', 'TOKSF',
#        'TOT', 'TPH', 'TRH', 'TUP', 'UBS', 'USB', 'USFD', 'VAL', 'VAR',
#        'VIVEF', 'VRSN', 'WB-OLD', 'WBA', 'WFR', 'WFT', 'WH', 'WMT', 'WYE',
#        'X', 'XOM', 'YHOO', 'YUM', 'ZAYO', 'ZTS'], dtype=object), array(['ABN', 'AIG', 'ANAT', 'ANFGF', 'AXELF', 'AXP', 'AZO', 'BAC',
#        'BAESF', 'BAX', 'BIDU', 'BK', 'BNI', 'BRK.A', 'BSBR', 'BTI',
#        'CMCSA', 'CMCSK-OLD', 'CNHI', 'CNPAF', 'CNW', 'COP', 'CSCO', 'DEO',
#        'DVN', 'EMR', 'FII', 'FMCC', 'GETVF', 'GL', 'GOOG', 'GOOGL', 'GSK',
#        'HAL', 'HD', 'HENKY', 'HKHHF', 'HYMLF', 'JEF', 'JNJ', 'LNAGF',
#        'MA', 'MBI', 'MMM', 'MRC', 'MURGF', 'NSRGY', 'NVS', 'NWLI', 'PFE',
#        'PM', 'PNC', 'RDS.A', 'RHHVF', 'RYN', 'SCBFF', 'SKM', 'SNY',
#        'SWCEY', 'TOT', 'TRH', 'UL', 'UN', 'UNF', 'UNP', 'UOVEY', 'WFC',
#        'WMT', 'WPP', 'ZFSVF'], dtype=object), array(['ACN', 'ADI', 'AGN', 'AIG', 'AMZN', 'ANTM', 'AON', 'APA', 'APOL',
#        'AXP', 'AZO', 'BHC', 'BKNG', 'BRK.B', 'BUD', 'CFC', 'CMCSA',
#        'CMCSK-OLD', 'COP', 'COV', 'CRM', 'CSGP', 'CTRX', 'CVS', 'DELL-OL',
#        'DEO', 'DHR', 'DIS', 'DISCA', 'DISCK', 'DLTR', 'DTV', 'EBAY',
#        'ENDP', 'EOG', 'ESRX', 'EXPE', 'FB', 'FNMA', 'FOX', 'FOXA',
#        'FWONA', 'FWONK', 'GHC', 'GOOG', 'GOOGL', 'HPQ', 'IAC', 'JPM',
#        'KMX', 'LBRDK', 'LBTYK', 'LH', 'LMDIA', 'LMT', 'LNAGF', 'LOW',
#        'LSXMK', 'MA', 'MLM', 'MON', 'MSFT', 'MSI', 'NWSA', 'OCR', 'OMC',
#        'ORCL', 'PCP', 'PX', 'PXD', 'QRTEA', 'RRC', 'RWT', 'SCHW', 'SWN',
#        'TDG', 'TDS.S', 'TGT', 'TMO', 'TXN', 'TYC', 'UNH', 'UPS', 'USG',
#        'V', 'VMC', 'WFC', 'WMT'], dtype=object), array(['AAL', 'AAPL', 'AMP', 'AMZN', 'ANTM', 'AXP', 'BAC', 'BK', 'BNI',
#        'BUD', 'CBI', 'CEG', 'CHTR', 'CMCSK-OLD', 'COP', 'COST', 'CVS',
#        'DAL', 'DE', 'DG', 'DJ', 'DTV', 'DVA', 'FISV', 'FWONA', 'GD', 'GE',
#        'GHC', 'GL', 'GM', 'GS', 'GSK', 'IBM', 'INTC', 'IR', 'IRM', 'JNJ',
#        'JPM', 'KHC', 'KMX', 'KO', 'LSXMK', 'LUV', 'MA', 'MCO', 'MDLZ',
#        'MON', 'MTB', 'NKE', 'NLC', 'NOV', 'NRG', 'NSC', 'NSRGY', 'ORCL',
#        'PCP', 'PG', 'PSX', 'RSG', 'SNY', 'SU', 'T', 'TT', 'TYC', 'UAL',
#        'UNP', 'UPS', 'USB', 'USG', 'V', 'VIAB', 'VRSN', 'VZ', 'WFC',
#        'WMT', 'WSC', 'XOM'], dtype=object), array(['A', 'ABEV', 'ABV-OLD', 'ACN', 'ADI', 'ADSK', 'AGN', 'ALTR', 'AMT',
#        'AMZN', 'AON', 'AVGO', 'AVP', 'AXP', 'AZO', 'BAP', 'BAX', 'BBD',
#        'BCO', 'BDX', 'BIDU', 'BITA', 'BKNG', 'BTI', 'CACC', 'CAG', 'CBRE',
#        'CL', 'CLB', 'CME', 'CMPR', 'COV', 'ECL', 'EFX', 'FIS', 'GOOG',
#        'GOOGL', 'GWW', 'HOG', 'HRB', 'ICE', 'KMB', 'KO', 'LKQ', 'MSM',
#        'NXPI', 'OPEN', 'ORCL', 'PFE', 'PM', 'SERV', 'SIRO-OLD', 'SLH',
#        'SNN', 'SPGI', 'SSNC', 'ST', 'TMO', 'TNET', 'TRV', 'UL', 'V',
#        'VRSN', 'WAT', 'WLTW', 'ZTS'], dtype=object)])

# %%
#把dictionary的每一個vlaue放進set裡，就unique
unique_spam_set = set()
for lst in unique_spam.values():
    for val in lst:
        #print(val)
        unique_spam_set.add(val)

# %%
unique_spam_set
# Out:
# {'WPC',
#  'ADP',
#  'FRX',
#  'EL',
#  'ON',
#  'VSH',
#  'SXT',
#  'BBD',
#  'BIG',
#  'HEES',
#  'TNET',
#  'MCO',
#  'MAS',
#  'GPS',
#  'V',
#  'MMM',
#  'DF',
#  'VRS',
#  'PBI',
#  'DTV',
#  'SDRL',
#  'CYD',
#  'CFG',
#  'LLL',
#  'ADT',
#  'BANC',
#  'VR',
#  'TA',
#  'PTEN',
#  'JCDXF',
#  'ALD',
#  'TRMB',
#  'ITW',
#  'MPG',
#  'GRS',
#  'LULU',
#  'MRK',
#  'LNCE',
#  'GEO',
#  'BEAV',
#  'COOP',
#  'LIFE',
#  'AMCX',
#  'BBBY',
#  'ET',
#  'HYMLF',
#  'ALX',
#  'RJET',
#  'MRC',
#  'WRB',
#  'CPN',
#  'SWCH',
#  'IPGP',
#  'WB-OLD',
#  'C.WS.A',
#  'HOFD',
#  'PM',
#  'GTY',
#  'STEI',
#  'HRL',
#  'CP',
#  'PNM',
#  'CFRHF',
#  'FTDR',
#  'HLS',
#  'MEDI',
#  'JD',
#  'SSE',
#  'NS',
#  'TOT',
#  'SSW',
#  'LGF.A',
#  'PAX',
#  'ACF',
#  'AUY',
#  'FSUMF',
#  'HRI',
#  'SMMX',
#  'ESVIF',
#  'AMLP',
#  'SERV',
#  'RHJIF',
#  'PGH',
#  'SMG',
#  'STL',
#  'AHONY',
#  'HCXLF',
#  'ABFS',
#  'IPXL',
#  'PFE',
#  'GRA',
#  'INTL',
#  'AKBA',
#  'AN',
#  'TAK',
#  'EGN',
#  'JEC',
#  'INTC',
#  'KBR',
#  'OMN',
#  'PAHC',
#  'PDRDF',
#  'BEE',
#  'MVC',
#  'FWP',
#  'CSCO',
#  'ANET',
#  'MRVL',
#  'AIN',
#  'ARCO',
#  'CLD',
#  'OSK',
#  'CHB',
#  'MENT',
#  'LILA',
#  'NTES',
#  'GLBR',
#  'HSBC',
#  'CB',
#  'JEF',
#  'FEIC',
#  'FNB',
#  'BHF',
#  'RGLD',
#  'BCO',
#  'GMALF',
#  'PXD',
#  'SCHS',
#  'FTV',
#  'ARIA',
#  'ALLY',
#  'RHI',
#  'ZION',
#  'EK',
#  'APTV',
#  'WAB',
#  'PSS',
#  'IAC',
#  'SBAC',
#  'SUNE',
#  'PH',
#  'MTW',
#  'ODFL',
#  'AGNC',
#  'KW',
#  'AGX',
#  'TIBX',
#  'ABG',
#  'BHE',
#  'UBSH',
#  'NORD',
#  'UAL',
#  'MSI',
#  'PE',
#  'WAC',
#  'FLXN',
#  'FN',
#  'TTC',
#  'C',
#  'MTZ',
#  'GCI',
#  'PBNY',
#  'WAT',
#  'CTRX',
#  'CYH',
#  'LAMR',
#  'TWTR',
#  'IPCR',
#  'GIS',
#  'UFPI',
#  'ORIG',
#  'PD',
#  'BAC',
#  'RHHBY',
#  'SYA',
#  'FTR',
#  'NOC',
#  'TTM',
#  'NPPKF',
#  'PVTB',
#  'EOG',
#  'ADES',
#  'AFL',
#  'GM.WS.B',
#  'ITRN',
#  'AFI',
#  'JOE',
#  'ANSS',
#  'FMX',
#  'SAM',
#  'PNR',
#  'EAF',
#  'BBEP',
#  'SE-OLD',
#  'IMS',
#  'MDLZ',
#  'AVA',
#  'HA',
#  'CAKE',
#  'GEOI',
#  'UPL',
#  'MON',
#  'BWXT',
#  'EXC',
#  'ZEUS',
#  'BPFH',
#  'WYNN',
#  'SPWH',
#  'CVBF',
#  'GYI',
#  'GLPW',
#  'DHI',
#  'FLR',
#  'OUTR',
#  'WTM',
#  'QNTQF',
#  'BBY',
#  'TPIC',
#  'LII',
#  'SKX',
#  'ROSE',
#  'UFS',
#  'RNR',
#  'AREX',
#  'GOOG',
#  'NSC',
#  'PBR',
#  'CVX',
#  'AAN',
#  'SHLDQ',
#  'IFF',
#  'ALDW',
#  'CBST',
#  'GMCR',
#  'PAH3.DE',
#  'CKHUY',
#  'QUOT',
#  'RBS',
#  'WCN',
#  'DLR',
#  'CALM',
#  'BNED',
#  'DBD',
#  'MWA',
#  'LFG',
#  'JCP',
#  'AXP',
#  'LBRDA',
#  'QNTA',
#  'MEG',
#  'UFI',
#  'PRGO',
#  'PEP',
#  'SLCA',
#  'CPB',
#  'RSG',
#  'TRB-OLD',
#  'VOD',
#  'ANV',
#  'RRC',
#  'ALTR',
#  'EROS',
#  'SIG',
#  'CHNG',
#  'CMG',
#  'VRRM',
#  'ASPS',
#  'TV',
#  'NWLI',
#  'HAE',
#  'BX',
#  'CTAS',
#  'HOLX',
#  'SCBFF',
#  'PACD',
#  'COLD',
#  'BRL',
#  'BUD',
#  'GL',
#  'AVP',
#  'CTXS',
#  'OSG',
#  'SU',
#  'PSO',
#  'FOXA',
#  'UIL',
#  'ABM',
#  'HMN',
#  'BG',
#  'SINA',
#  'ITC',
#  'DSWL',
#  'PB',
#  'DOOR',
#  'UGI',
#  'TLM',
#  'VNOM',
#  'WBA',
#  'DENN',
#  'FOCS',
#  'SEAS',
#  'MASI',
#  'COTY',
#  'D',
#  'TLRD',
#  'ABR',
#  'PRTK',
#  'ADS',
#  'ALXN',
#  'VST',
#  'MAC',
#  'RTLR',
#  'ABCW',
#  'AKAM',
#  'CPLG',
#  'RYN',
#  'AXE',
#  'TOWN',
#  'BKI',
#  'VLTC',
#  'GLF',
#  'WTRH',
#  'BAX',
#  'CST',
#  'SYT',
#  'SNN',
#  'CWEN.A',
#  'EST',
#  'YUM',
#  'ENWV',
#  'FYR',
#  'HGV',
#  'IDWM',
#  'SABR',
#  'DFZ',
#  'ZLC',
#  'URBN',
#  'PRU',
#  'KEA',
#  'DCI',
#  'SGEN',
#  'TRGP',
#  'NFLX',
#  'GOOGL',
#  'BIIB',
#  'ORI',
#  'CCL',
#  'MDCO',
#  'AHMIQ',
#  'KNX',
#  'KGC',
#  'BSX',
#  'BYI',
#  'CVCO',
#  'PIR',
#  'TRCO',
#  'NSM',
#  'UHAL',
#  'KLXI',
#  'TCW',
#  'NTAP',
#  'IPMLF',
#  'BXS',
#  'EURN',
#  'COWN',
#  'HSC',
#  'NICK',
#  'CYN',
#  'TRQ',
#  'REXI',
#  'INT',
#  'OMC',
#  'NDN',
#  'UNT',
#  'VOYA',
#  'STE',
#  'FWONK',
#  'GNTX',
#  'MIK',
#  'VECO',
#  'AZO',
#  'CSG',
#  'OSTK',
#  'TTD',
#  'EDS',
#  'RTN',
#  'KOS',
#  'GLT',
#  'GTS',
#  'ISCA',
#  'CYT',
#  'CMCSA',
#  'RRD',
#  'BITA',
#  'CAB',
#  'TSL',
#  'XLE',
#  'GHC',
#  'PETM',
#  'NXST',
#  'BBT',
#  'CLNS',
#  'UCO',
#  'SSNC',
#  'ADI',
#  'DG',
#  'ISRG',
#  'UN',
#  'SNY',
#  'BNS',
#  'DLB',
#  'FR',
#  'AIV',
#  'BHP',
#  'MURGF',
#  'UWBK',
#  'TRA',
#  'AROC',
#  'BIOF',
#  'SCHW',
#  'AYI',
#  'SLRC',
#  'UI',
#  'CONN',
#  'DNOW',
#  'FNF',
#  'NODK',
#  'VOXX',
#  'EBAY',
#  'BCBP',
#  'SC',
#  'HAIN',
#  'UTIW',
#  'FTNT',
#  'SCU',
#  'SQ',
#  'UNH',
#  'ANAT',
#  'UTSI',
#  'NGLS',
#  'RLGY',
#  'OXY',
#  'WM-OLD',
#  'TW-OLD',
#  'GWW',
#  'WM',
#  'FIT',
#  'SYMS',
#  'PDCO',
#  'UNF',
#  'ABN',
#  'RPCGY',
#  'AIG',
#  'ANF',
#  'KS',
#  'GLRE',
#  'NVDA',
#  'TRWH',
#  'AMMD',
#  'GOLD-OLD',
#  'SLGN',
#  'I',
#  'ICO',
#  'BNI',
#  'GD',
#  'HRZ',
#  'PHG',
#  'KRNY',
#  'DGX',
#  'JAS',
#  'ETFC',
#  'ROK',
#  'ESGR',
#  'CBI',
#  'GSKY',
#  'SANW',
#  'THS',
#  'SCSS',
#  'FLA',
#  'ARO',
#  'FBHS',
#  'BKC',
#  'MAM',
#  'FBN',
#  'GLPI',
#  'GSM',
#  'HOT',
#  'IBN',
#  'MDP',
#  'OGZPY',
#  'WFR',
#  'UBS',
#  'HNZ',
#  'LB',
#  'NOW',
#  'AMTD',
#  'ENR',
#  'PDE',
#  'BGC',
#  'MELI',
#  'OXPS',
#  'AT',
#  'PCG',
#  'INTU',
#  'WR',
#  'WK',
#  'UPS',
#  'PULS',
#  'VMW',
#  'GRBK',
#  'ISBC',
#  'ANTM',
#  'LEN',
#  'VEC',
#  'TTWO',
#  'AEM',
#  'AMD',
#  'APOL',
#  'QIHU',
#  'LSXMA',
#  'BEC',
#  'RSTK-D',
#  'RSYS',
#  'PCZ',
#  'CPRT',
#  'BMY.R',
#  'DD-OLD',
#  'XL',
#  'FTE',
#  'SKM',
#  'FHB',
#  'CABJF',
#  'MNST',
#  'IDT.C',
#  'HLX',
#  'LEN.B',
#  'PBF',
#  'SHPG',
#  'NUAN',
#  'PSTG',
#  'HNGR',
#  'IDIX',
#  'CNX',
#  'BABA',
#  'TOO',
#  'MGI',
#  'LYB',
#  'APO',
#  'RVR',
#  'WFT',
#  'ESS',
#  'CME',
#  'LH',
#  'REGI',
#  'MER',
#  'AVX',
#  'CON.DE',
#  'HNR',
#  'RH',
#  'MDC',
#  'FMCC',
#  'ACIW',
#  'ESRX',
#  'IBKR',
#  'WPG',
#  'LK',
#  'GT',
#  'SAFRY',
#  'XYL',
#  'AGN',
#  'PKX',
#  'MKC',
#  'TROW',
#  'CNDT',
#  'GNW',
#  'ARGKF',
#  'FSC',
#  'QRTEA',
#  'IPG',
#  'MS',
#  'MEE',
#  'CAM',
#  'PAY',
#  'UAUA',
#  'NBR',
#  'PRMW',
#  'AYE',
#  'ELOS',
#  'OMF',
#  'CSX',
#  'SEMI',
#  'PYX',
#  'QSR',
#  'TWX',
#  'AET',
#  'BYND',
#  'XCO',
#  'GILD',
#  'TPR',
#  'MCY',
#  'DISCA',
#  'VMI',
#  'TBPH',
#  'LCC',
#  'MCHP',
#  'ATRA',
#  'OI',
#  'DK',
#  'SNA',
#  'ZQK',
#  'GPT',
#  'TWI',
#  'FB',
#  'DAR',
#  'JWN',
#  'NVTRQ',
#  'GNRT',
#  'INFY',
#  'WCBO',
#  'MRO',
#  'HUM',
#  'BOIVF',
#  'CKSNF',
#  'AGR',
#  'USB',
#  'POWI',
#  'LTD',
#  'ALKS',
#  'XTXI',
#  'RAVN',
#  'YPF',
#  'MEL',
#  'BPO',
#  'CFFN',
#  'RTX',
#  'EME',
#  'ENH',
#  'VRSN',
#  'NLOK',
#  'LGF.B',
#  'GOLF',
#  'LPLA',
#  'RYCEF',
#  'DOX',
#  'EQT',
#  'LFGEF',
#  'MBI',
#  'BAM',
#  'ONE',
#  'PCAR',
#  'PCP',
#  'ANK',
#  'SODA',
#  'CRESY',
#  'EFX',
#  'NTP',
#  'FPAC.UN',
#  'TX',
#  'RFMD',
#  'PGN',
#  'S',
#  'LDG',
#  'COMM',
#  'VWR',
#  'VIV',
#  'GBGS',
#  'MLSPF',
#  'FLML-OLD',
#  'AVY',
#  'VRTV',
#  'HIG',
#  'IDXX',
#  'TAM',
#  'PLXS',
#  'NPSNY',
#  'WY',
#  'INSP',
#  'SJM',
#  'APA',
#  'CSL',
#  'UNVR',
#  'HAL',
#  'CRL',
#  'KERX',
#  'FFH',
#  'BRP',
#  'CXW',
#  'BAESF',
#  'CDS.U',
#  'FLIR',
#  'DE',
#  'STRA',
#  'TQNT',
#  'TMUS',
#  'HANS',
#  'OII',
#  'JNS',
#  'IRM',
#  'MO',
#  'BAC.WS.B',
#  'LNG',
#  'ALR',
#  'NFG',
#  'DPS',
#  'JPM.WS',
#  'A',
#  'XELT',
#  'HP',
#  'RS',
#  'AYX',
#  'MET',
#  'BANR',
#  'RCL',
#  'FD',
#  'COST',
#  'PG',
#  'AVEO',
#  'LOW',
#  'AGO',
#  'HTH',
#  'TOH',
#  'TRC',
#  'CEIX',
#  'SBMRY',
#  'PNC.WS',
#  'IAAC',
#  'PROSF',
#  'GS',
#  'X',
#  'TERP',
#  'DVN',
#  'TEG',
#  'GPC',
#  'NTRS',
#  'HOS',
#  'CMA',
#  'RL',
#  'CHRW',
#  'CCO',
#  'ABT',
#  'IBM',
#  'AMR',
#  'BPOP',
#  'MNK',
#  'VCI',
#  'VRSK',
#  'FCE.A',
#  'DMND',
#  'WLK',
#  'VIVEF',
#  'MGM',
#  'IPXHF',
#  'KFN',
#  'FRH',
#  'NR',
#  'USEC',
#  'BPY',
#  'CTSH',
#  'REGN',
#  'CTRP',
#  'WWW',
#  'LNY',
#  'APD',
#  'ITUB',
#  'GSHD',
#  'GLIBA',
#  'BXLT',
#  'WLTW',
#  'GW',
#  'TKR',
#  'RDS.A',
#  'RHIE',
#  'HEGIF',
#  'DSGX',
#  'FLEX',
#  'NDAQ',
#  'ATMI',
#  'MGAM-OL',
#  'DDAIF',
#  'LYV',
#  'RAH',
#  'FL',
#  'SMCG',
#  'NEWM',
#  'CEO',
#  'RCII',
#  'NPK',
#  'AZUL',
#  'PLAB',
#  'SWCEY',
#  'TBBK',
#  'OGBY',
#  'AEO',
#  'CMCSK-OLD',
#  'DD',
#  'WHR',
#  'SNAP',
#  'GFI',
#  'BWINB-OLD',
#  'AVD',
#  'MTG',
#  'BHC',
#  'CCS',
#  'WPX',
#  'FNFG',
#  'NWA',
#  'LANC',
#  'DESP',
#  'AR',
#  'BIVV',
#  'ORKLY',
#  'ARKAY',
#  'AY',
#  'XRAY',
#  'JBHGF',
#  'LABC',
#  'LONE',
#  'LUV',
#  'CWEN',
#  'VOPKF',
#  'USG',
#  'NEM',
#  'NVLS-OLD',
#  'EXPR',
#  'CHPXF',
#  'ITT',
#  'KLIC',
#  'EMR',
#  'ERFSF',
#  'ETE',
#  'CTVA',
#  'ABH',
#  'BXE',
#  'MIM',
#  'BMC',
#  'LAZ',
#  'LBTYK',
#  'XRX',
#  'FRGI',
#  'GETVF',
#  'BER',
#  'CBRE',
#  'NYX',
#  'M',
#  'ENDP',
#  'ONCE',
#  'PLL',
#  'NG',
#  'IVC',
#  'RTH',
#  'HAR',
#  'ORH',
#  'SEIC',
#  'NKTR',
#  'CSGP',
#  'ACGL',
#  'GDI',
#  'TDG',
#  'EQ',
#  'UL',
#  'AMP',
#  'BC',
#  'UMPQ',
#  'SLE',
#  'MHK',
#  'GOLD',
#  'WLT',
#  'DHIL',
#  'EVA',
#  'KEQU',
#  'PETQ',
#  'ETP',
#  'DDS',
#  'SD',
#  'SRSC',
#  'NYRT',
#  'FPH',
#  'RDN',
#  'CNC',
#  'MCK',
#  'KALU',
#  'ETN',
#  'ADSK',
#  'AJG',
#  'NCQ',
#  'NAQ',
#  'BCC',
#  'CAR',
#  'CACI',
#  'TFX',
#  'FAF',
#  'PSX',
#  'KMB',
#  'CXPO',
#  'CPF',
#  'HMA',
#  'TYIDF',
#  'PLD',
#  'EMN',
#  'LM',
#  'CTL',
#  'SFD',
#  'SRCL',
#  'STT',
#  'AUQ',
#  'VIAC',
#  'HCC',
#  'FARM',
#  'MKSI',
#  'MERC',
#  'XTO',
#  'SPXC',
#  'PPO',
#  'CEG',
#  'FE',
#  'OSH',
#  'KHC',
#  'SCMR',
#  'ADM',
#  'BZH',
#  'WYN',
#  'HST',
#  'SBNY',
#  'NEW',
#  'WMGI',
#  'FCX',
#  'DKS',
#  'UOVEY',
#  'CNO',
#  'ALC',
#  'THO',
#  'CHKGF',
#  'SYK',
#  'PPG',
#  'FTI',
#  'OVV',
#  'BTI',
#  'SJT',
#  'NCC',
#  'HSY',
#  'ROST',
#  'NRZ',
#  'MODL',
#  'LAB',
#  'PSN',
#  'NRG',
#  'SPMD',
#  'KSS',
#  'CNW',
#  'CORE',
#  'FWLT',
#  'CDW',
#  'MAR',
#  'PGR',
#  'NLC',
#  'DAL',
#  'ACOPF',
#  'DLPH',
#  'HEK',
#  'HUN',
#  'DRC',
#  'CVET',
#  'FICC',
#  'JEF-OLD',
#  'BDK',
#  'SHOP',
#  'CVEO',
#  'JPM',
#  'CNHI',
#  'BBU',
#  'NOMD',
#  'CAH',
#  'ALL',
#  'MNRO',
#  'HKHHF',
#  'SPGI',
#  'PAYX',
#  'LNKD',
#  'AMH',
#  'FLT',
#  'PRI',
#  'CEN',
#  'RPXC',
#  'PDLI',
#  'TMS-OLD',
#  'MXL',
#  'LYO',
#  'SCAI',
#  'SAVE',
#  'TM',
#  'BKR',
#  'ORBK',
#  'SRG',
#  'PCU',
#  'TRN',
#  'GR',
#  'AES',
#  'WMS',
#  'CAG',
#  'BF.A',
#  ...}

# %%
#轉成list, 把"."和之後的str丟掉
unique_spam_lst = list(unique_spam_set)
len(pd.unique(unique_spam_lst))
# Out:
# 1936

# %%
unique_spam_lst.sort()

# %%
unique_spam_lst
# Out:
# ['A',
#  'AA',
#  'AABA',
#  'AAIGF',
#  'AAL',
#  'AAN',
#  'AAP',
#  'AAPL',
#  'AB',
#  'ABB',
#  'ABBC',
#  'ABBV',
#  'ABC',
#  'ABCW',
#  'ABEV',
#  'ABFS',
#  'ABG',
#  'ABH',
#  'ABKFQ',
#  'ABM',
#  'ABN',
#  'ABR',
#  'ABT',
#  'ABV-OLD',
#  'ACA',
#  'ACBI',
#  'ACCL',
#  'ACF',
#  'ACGL',
#  'ACIW',
#  'ACM',
#  'ACMR',
#  'ACN',
#  'ACOPF',
#  'ACT',
#  'ACXM',
#  'ADBE',
#  'ADCT',
#  'ADES',
#  'ADI',
#  'ADM',
#  'ADNT',
#  'ADP',
#  'ADS',
#  'ADSK',
#  'ADT',
#  'ADTN',
#  'AEM',
#  'AEO',
#  'AEP',
#  'AER',
#  'AES',
#  'AET',
#  'AFI',
#  'AFL',
#  'AFSI',
#  'AGCO',
#  'AGN',
#  'AGNC',
#  'AGO',
#  'AGP',
#  'AGR',
#  'AGU',
#  'AGX',
#  'AHL',
#  'AHMIQ',
#  'AHONY',
#  'AIG',
#  'AIG.WS',
#  'AIN',
#  'AIQ',
#  'AIV',
#  'AIZ',
#  'AJG',
#  'AJRD',
#  'AKAM',
#  'AKBA',
#  'AKR',
#  'ALA',
#  'ALB',
#  'ALC',
#  'ALD',
#  'ALDW',
#  'ALEX',
#  'ALGT',
#  'ALK',
#  'ALKS',
#  'ALL',
#  'ALLE',
#  'ALLY',
#  'ALNY',
#  'ALR',
#  'ALRM',
#  'ALSN',
#  'ALTR',
#  'ALX',
#  'ALXN',
#  'AM-OLD',
#  'AMAT',
#  'AMBA',
#  'AMCX',
#  'AMD',
#  'AME',
#  'AMG',
#  'AMGN',
#  'AMGP',
#  'AMH',
#  'AMLP',
#  'AMMD',
#  'AMP',
#  'AMR',
#  'AMT',
#  'AMTD',
#  'AMV',
#  'AMX',
#  'AMZN',
#  'AN',
#  'ANAT',
#  'ANDV',
#  'ANET',
#  'ANF',
#  'ANFGF',
#  'ANK',
#  'ANSS',
#  'ANTM',
#  'ANV',
#  'AON',
#  'AOS',
#  'APA',
#  'APC',
#  'APD',
#  'APFH',
#  'APH',
#  'APL',
#  'APO',
#  'APOL',
#  'APTV',
#  'AR',
#  'ARCO',
#  'ARES',
#  'AREX',
#  'ARGKF',
#  'ARIA',
#  'ARII',
#  'ARKAY',
#  'ARMK',
#  'ARNC',
#  'ARO',
#  'AROC',
#  'ARRS',
#  'ARW',
#  'ASA',
#  'ASBFF',
#  'ASCMA',
#  'ASH',
#  'ASPS',
#  'ASTE',
#  'AT',
#  'ATCO',
#  'ATGE',
#  'ATI',
#  'ATLS',
#  'ATMI',
#  'ATR',
#  'ATRA',
#  'ATSG',
#  'ATUS',
#  'ATVI',
#  'ATW',
#  'AU',
#  'AUQ',
#  'AUY',
#  'AVA',
#  'AVD',
#  'AVEO',
#  'AVGO',
#  'AVLR',
#  'AVP',
#  'AVT',
#  'AVTR',
#  'AVX',
#  'AVY',
#  'AW',
#  'AWH',
#  'AWI',
#  'AXE',
#  'AXELF',
#  'AXL',
#  'AXLL',
#  'AXP',
#  'AXS',
#  'AXTA',
#  'AY',
#  'AYE',
#  'AYI',
#  'AYX',
#  'AZN',
#  'AZO',
#  'AZUL',
#  'BA',
#  'BABA',
#  'BAC',
#  'BAC.WS.A',
#  'BAC.WS.B',
#  'BAESF',
#  'BAGL',
#  'BAM',
#  'BANC',
#  'BANR',
#  'BAP',
#  'BAX',
#  'BB',
#  'BBBY',
#  'BBD',
#  'BBEP',
#  'BBT',
#  'BBU',
#  'BBY',
#  'BC',
#  'BCBP',
#  'BCC',
#  'BCE',
#  'BCEI',
#  'BCO',
#  'BCR',
#  'BDC',
#  'BDK',
#  'BDX',
#  'BEAM',
#  'BEAV',
#  'BEC',
#  'BEE',
#  'BEN',
#  'BER',
#  'BF.A',
#  'BF.B',
#  'BG',
#  'BGC',
#  'BGP',
#  'BHC',
#  'BHE',
#  'BHF',
#  'BHI',
#  'BHP',
#  'BID',
#  'BIDU',
#  'BIG',
#  'BIIB',
#  'BIOF',
#  'BIP',
#  'BITA',
#  'BIVV',
#  'BJS',
#  'BK',
#  'BKC',
#  'BKH',
#  'BKI',
#  'BKNG',
#  'BKR',
#  'BKS',
#  'BKW-OLD',
#  'BLK',
#  'BLL',
#  'BLT',
#  'BMBLF',
#  'BMC',
#  'BMCH',
#  'BMS',
#  'BMY',
#  'BMY.R',
#  'BNED',
#  'BNI',
#  'BNKJF',
#  'BNS',
#  'BNTGF',
#  'BOH',
#  'BOIVF',
#  'BOKF',
#  'BOL',
#  'BP',
#  'BPFH',
#  'BPO',
#  'BPOP',
#  'BPY',
#  'BR',
#  'BRCM-OLD',
#  'BRFS',
#  'BRK.A',
#  'BRK.B',
#  'BRL',
#  'BRO',
#  'BRP',
#  'BRS',
#  'BRY',
#  'BSBR',
#  'BSC',
#  'BSX',
#  'BTI',
#  'BUD',
#  'BURL',
#  'BW',
#  'BWA',
#  'BWINB-OLD',
#  'BWP',
#  'BWXT',
#  'BX',
#  'BXE',
#  'BXLT',
#  'BXS',
#  'BYD',
#  'BYI',
#  'BYND',
#  'BZH',
#  'C',
#  'C.WS.A',
#  'CA',
#  'CAB',
#  'CABJF',
#  'CACC',
#  'CACH',
#  'CACI',
#  'CAG',
#  'CAH',
#  'CAKE',
#  'CALM',
#  'CAM',
#  'CAR',
#  'CARE',
#  'CARS',
#  'CAT',
#  'CB',
#  'CBI',
#  'CBIO',
#  'CBRE',
#  'CBS',
#  'CBST',
#  'CBT',
#  'CBWBF',
#  'CBY',
#  'CC',
#  'CC-OLD',
#  'CCAP',
#  'CCE-OLD',
#  'CCG',
#  'CCI',
#  'CCK',
#  'CCL',
#  'CCO',
#  'CCR',
#  'CCRT',
#  'CCS',
#  'CDS.U',
#  'CDW',
#  'CEG',
#  'CEIX',
#  'CELG',
#  'CEN',
#  'CEO',
#  'CEPH',
#  'CF',
#  'CFC',
#  'CFFN',
#  'CFG',
#  'CFN',
#  'CFRHF',
#  'CFX',
#  'CHB',
#  'CHEF',
#  'CHGG',
#  'CHK',
#  'CHKGF',
#  'CHKP',
#  'CHL',
#  'CHNG',
#  'CHPXF',
#  'CHRS',
#  'CHRW',
#  'CHT',
#  'CHTR',
#  'CI',
#  'CIM',
#  'CINF',
#  'CISN',
#  'CIT',
#  'CKH',
#  'CKHUY',
#  'CKSNF',
#  'CL',
#  'CLB',
#  'CLD',
#  'CLDR',
#  'CLF',
#  'CLH',
#  'CLMT',
#  'CLNS',
#  'CLNY',
#  'CLPR',
#  'CLR',
#  'CLX',
#  'CMA',
#  'CMCSA',
#  'CMCSK-OLD',
#  'CME',
#  'CMG',
#  'CMI',
#  'CMLS',
#  'CMP',
#  'CMPR',
#  'CMTL',
#  'CNC',
#  'CNDT',
#  'CNHI',
#  'CNI',
#  'CNL',
#  'CNO',
#  'CNPAF',
#  'CNQ',
#  'CNR',
#  'CNSWF',
#  'CNW',
#  'CNX',
#  'COF',
#  'COG',
#  'COGN',
#  'COIHF',
#  'COL',
#  'COLB',
#  'COLD',
#  'COMM',
#  'CON.DE',
#  'CONN',
#  'COOP',
#  'COP',
#  'COR',
#  'CORE',
#  'COST',
#  'COT',
#  'COTY',
#  'COV',
#  'COWN',
#  'CP',
#  'CPB',
#  'CPF',
#  'CPLG',
#  'CPN',
#  'CPRI',
#  'CPRT',
#  'CPWR',
#  'CR',
#  'CRAY',
#  'CRESY',
#  'CRI',
#  'CRL',
#  'CRM',
#  'CRR',
#  'CRYP',
#  'CS',
#  'CSC',
#  'CSCO',
#  'CSE',
#  'CSG',
#  'CSGP',
#  'CSL',
#  'CST',
#  'CSWC',
#  'CSX',
#  'CTAS',
#  'CTB',
#  'CTL',
#  'CTRP',
#  'CTRX',
#  'CTSH',
#  'CTVA',
#  'CTX',
#  'CTXS',
#  'CUB',
#  'CVA',
#  'CVBF',
#  'CVCO',
#  'CVE',
#  'CVEO',
#  'CVET',
#  'CVH',
#  'CVI',
#  'CVRR',
#  'CVS',
#  'CVX',
#  'CW',
#  'CWEN',
#  'CWEN.A',
#  'CWGL',
#  'CWH',
#  'CWH-OLD',
#  'CX',
#  'CXG',
#  'CXO',
#  'CXPO',
#  'CXW',
#  'CYD',
#  'CYH',
#  'CYN',
#  'CYT',
#  'CZR',
#  'D',
#  'DAL',
#  'DAN',
#  'DAR',
#  'DB',
#  'DBD',
#  'DBI',
#  'DBRN',
#  'DCI',
#  'DD',
#  'DD-OLD',
#  'DDAIF',
#  'DDS',
#  'DE',
#  'DELL',
#  'DELL-OL',
#  'DENN',
#  'DEO',
#  'DESP',
#  'DEST',
#  'DF',
#  'DFS',
#  'DFZ',
#  'DG',
#  'DGX',
#  'DHI',
#  'DHIL',
#  'DHR',
#  'DIS',
#  'DISCA',
#  'DISCK',
#  'DISH',
#  'DJ',
#  'DJCO',
#  'DK',
#  'DKS',
#  'DLB',
#  'DLMAF',
#  'DLPH',
#  'DLR',
#  'DLRUF',
#  'DLTR',
#  'DMND',
#  'DNA',
#  'DNB',
#  'DNOW',
#  'DO',
#  'DOOR',
#  'DOV',
#  'DOW',
#  'DOX',
#  'DPS',
#  'DPTHL',
#  'DPZ',
#  'DRC',
#  'DRI',
#  'DSGX',
#  'DSP',
#  'DSSI',
#  'DST',
#  'DSWL',
#  'DTV',
#  'DUK',
#  'DVA',
#  'DVMT',
#  'DVN',
#  'DXC',
#  'DXM',
#  'DYN',
#  'EA',
#  'EAF',
#  'EAT',
#  'EBAY',
#  'ECL',
#  'ECPG',
#  'EDS',
#  'EDU',
#  'EFX',
#  'EGC',
#  'EGL',
#  'EGLE',
#  'EGN',
#  'EIG',
#  'EIGI',
#  'EIX',
#  'EK',
#  'EL',
#  'ELAN',
#  'ELN',
#  'ELOS',
#  'EMC',
#  'EME',
#  'EMN',
#  'EMR',
#  'ENDP',
#  'ENH',
#  'ENLC',
#  'ENR',
#  'ENS',
#  'ENT',
#  'ENWV',
#  'ENZN',
#  'EOG',
#  'EP',
#  'EPD',
#  'EPL',
#  'EQ',
#  'EQC',
#  'EQH',
#  'EQIX',
#  'EQNR',
#  'EQT',
#  'ERFSF',
#  'EROS',
#  'ES-OLD',
#  'ESGR',
#  'ESL',
#  'ESNT',
#  'ESRX',
#  'ESS',
#  'EST',
#  'ESVIF',
#  'ET',
#  'ETE',
#  'ETFC',
#  'ETN',
#  'ETP',
#  'ETR',
#  'EURN',
#  'EVA',
#  'EVHC',
#  'EW',
#  'EXC',
#  'EXP',
#  'EXPD',
#  'EXPE',
#  'EXPR',
#  'F',
#  'FACT',
#  'FAF',
#  'FANG',
#  'FARM',
#  'FAST',
#  'FB',
#  'FBHS',
#  'FBN',
#  'FBP',
#  'FBTX',
#  'FCAU',
#  'FCE.A',
#  'FCNCA',
#  'FCX',
#  'FD',
#  'FDC',
#  'FDML',
#  'FDO',
#  'FDS',
#  'FDX',
#  'FE',
#  'FEIC',
#  'FELE',
#  'FEYE',
#  'FFH',
#  'FHB',
#  'FI',
#  'FICC',
#  'FII',
#  'FIS',
#  'FISV',
#  'FIT',
#  'FITB',
#  'FIVE',
#  'FL',
#  'FLA',
#  'FLE',
#  'FLEX',
#  'FLIR',
#  'FLML-OLD',
#  'FLO',
#  'FLR',
#  'FLS',
#  'FLT',
#  'FLXN',
#  'FMC',
#  'FMCC',
#  'FMX',
#  'FN',
#  'FNB',
#  'FNF',
#  'FNFG',
#  'FNMA',
#  'FO',
#  'FOCS',
#  'FOE',
#  'FOSL',
#  'FOX',
#  'FOXA',
#  'FPAC',
#  'FPAC.UN',
#  'FPH',
#  'FR',
#  'FRED',
#  'FRGI',
#  'FRH',
#  'FRNK',
#  'FRSH',
#  'FRX',
#  'FSC',
#  'FSGI',
#  'FSLR',
#  'FSP',
#  'FST',
#  'FSUMF',
#  'FTCH',
#  'FTDR',
#  'FTE',
#  'FTI',
#  'FTNT',
#  'FTO',
#  'FTR',
#  'FTV',
#  'FUL',
#  'FUR',
#  'FWLT',
#  'FWONA',
#  'FWONK',
#  'FWP',
#  'FYR',
#  'GAV',
#  'GBGS',
#  'GBL',
#  'GBLBF',
#  'GBX',
#  'GCI',
#  'GCVRZ',
#  'GD',
#  'GDI',
#  'GE',
#  'GENZ',
#  'GEO',
#  'GEOI',
#  'GETVF',
#  'GFG',
#  'GFI',
#  'GG',
#  'GGG',
#  'GGP',
#  'GHC',
#  'GHC-OLD',
#  'GHQ',
#  'GIL',
#  'GILD',
#  'GIS',
#  'GL',
#  'GLBR',
#  'GLF',
#  'GLIBA',
#  'GLPI',
#  'GLPW',
#  'GLRE',
#  'GLT',
#  'GLW',
#  'GM',
#  'GM.WS.B',
#  'GMALF',
#  'GMCR',
#  'GME',
#  'GMT',
#  'GNE',
#  'GNRC',
#  'GNRT',
#  'GNTX',
#  'GNW',
#  'GOLD',
#  'GOLD-OLD',
#  'GOLF',
#  'GOOG',
#  'GOOGL',
#  'GPC',
#  'GPI',
#  'GPK',
#  'GPN',
#  'GPS',
#  'GPT',
#  'GR',
#  'GRA',
#  'GRBK',
#  'GRS',
#  'GRUB',
#  'GS',
#  'GSHD',
#  'GSK',
#  'GSKY',
#  'GSM',
#  'GT',
#  'GTIV',
#  'GTS',
#  'GTY',
#  'GW',
#  'GWR',
#  'GWW',
#  'GYI',
#  'H',
#  'HA',
#  'HAE',
#  'HAIN',
#  'HAL',
#  'HANS',
#  'HAR',
#  'HAS',
#  'HBI',
#  'HCA',
#  'HCBK',
#  'HCC',
#  'HCMLF',
#  'HCXLF',
#  'HD',
#  'HDS',
#  'HE',
#  'HEES',
#  'HEGIF',
#  'HEI',
#  'HEK',
#  'HENKY',
#  'HEOP',
#  'HES',
#  'HEW',
#  'HFC',
#  'HGV',
#  'HHC',
#  'HIG',
#  'HII',
#  'HKHHF',
#  'HLF',
#  'HLI',
#  'HLS',
#  'HLT',
#  'HLX',
#  'HMA',
#  'HMC',
#  'HME',
#  'HMHC',
#  'HMN',
#  'HNGR',
#  'HNR',
#  'HNT',
#  'HNZ',
#  'HOFD',
#  'HOG',
#  'HOLX',
#  'HON',
#  'HOS',
#  'HOT',
#  'HP',
#  'HPE',
#  'HPQ',
#  'HPY',
#  'HRB',
#  'HRG',
#  'HRI',
#  'HRL',
#  'HRS',
#  'HRZ',
#  'HSBC',
#  'HSC',
#  'HSNI',
#  'HSP',
#  'HST',
#  'HSY',
#  'HTCH',
#  'HTH',
#  'HTS',
#  'HTV',
#  'HTZ',
#  'HUM',
#  'HUN',
#  'HURN',
#  'HXL',
#  'HYMLF',
#  'I',
#  'IAA',
#  'IAAC',
#  'IAC',
#  'IAG',
#  'IBKR',
#  'IBM',
#  'IBN',
#  'ICE',
#  'ICLR',
#  'ICO',
#  'IDCC',
#  'IDIX',
#  'IDT',
#  'IDT.B',
#  'IDT.C',
#  'IDWM',
#  'IDXX',
#  'IEP',
#  'IFF',
#  'IGT',
#  'IHG',
#  'ILMN',
#  'IM',
#  'IMIAF',
#  'IMOS',
#  'IMS',
#  'IN',
#  'INFA',
#  'INFN',
#  'INFY',
#  'ING',
#  'INSP',
#  'INT',
#  'INTC',
#  'INTL',
#  'INTU',
#  'INVA',
#  'INWK',
#  'INXN',
#  'IP',
#  'IPCR',
#  'IPG',
#  'IPGP',
#  'IPI',
#  'IPMLF',
#  'IPXHF',
#  'IPXL',
#  'IQV',
#  'IR',
#  'IRC',
#  'IRDM',
#  'IRM',
#  'ISBC',
#  'ISCA',
#  'ISRG',
#  'ITC',
#  'ITRN',
#  'ITT',
#  'ITUB',
#  'ITW',
#  'IVC',
#  'IVZ',
#  'JAS',
#  'JAVA',
#  'JAZ',
#  'JBHGF',
#  'JBHT',
#  'JBLU',
#  'JBX',
#  'JCDXF',
#  'JCI',
#  'JCP',
#  'JD',
#  'JEC',
#  'JEF',
#  'JEF-OLD',
#  'JLL',
#  'JNJ',
#  'JNS',
#  'JOE',
#  'JOY',
#  'JPM',
#  'JPM.WS',
#  'JW.A',
#  'JWN',
#  'JZEOF',
#  'K',
#  'KALU',
#  'KAR',
#  'KBH',
#  'KBR',
#  'KDDIF',
#  'KEA',
#  'KEQU',
#  'KERX',
#  'KEX',
#  'KEY',
#  'KEYS',
#  'KFN',
#  'KFY',
#  'KG',
#  'KGC',
#  'KHC',
#  'KIN',
#  'KKR',
#  'KLAC',
#  'KLIC',
#  'KLXI',
#  'KMB',
#  'KMI',
#  'KMT',
#  'KMX',
#  'KNX',
#  'KO',
#  'KOF',
#  'KOS',
#  'KRNY',
#  ...]

# %%
unique_spam_reduced_lst = []
for item in unique_spam_lst:
    if "." in item:
        item = item.split(sep = '.')[0]
    elif "-" in item:
        item = item.split(sep = '-')[0]
    unique_spam_reduced_lst.append(item)
unique_spam_reduced_lst = pd.unique(unique_spam_reduced_lst)

# %%
len(unique_spam_reduced_lst)
# Out:
# 1907

# %%
for item in unique_spam_reduced_lst:
    print(item, end = ' ')
# Out:
# A AA AABA AAIGF AAL AAN AAP AAPL AB ABB ABBC ABBV ABC ABCW ABEV ABFS ABG ABH ABKFQ ABM ABN ABR ABT ABV ACA ACBI ACCL ACF ACGL ACIW ACM ACMR ACN ACOPF ACT ACXM ADBE ADCT ADES ADI ADM ADNT ADP ADS ADSK ADT ADTN AEM AEO AEP AER AES AET AFI AFL AFSI AGCO AGN AGNC AGO AGP AGR AGU AGX AHL AHMIQ AHONY AIG AIN AIQ AIV AIZ AJG AJRD AKAM AKBA AKR ALA ALB ALC ALD ALDW ALEX ALGT ALK ALKS ALL ALLE ALLY ALNY ALR ALRM ALSN ALTR ALX ALXN AM AMAT AMBA AMCX AMD AME AMG AMGN AMGP AMH AMLP AMMD AMP AMR AMT AMTD AMV AMX AMZN AN ANAT ANDV ANET ANF ANFGF ANK ANSS ANTM ANV AON AOS APA APC APD APFH APH APL APO APOL APTV AR ARCO ARES AREX ARGKF ARIA ARII ARKAY ARMK ARNC ARO AROC ARRS ARW ASA ASBFF ASCMA ASH ASPS ASTE AT ATCO ATGE ATI ATLS ATMI ATR ATRA ATSG ATUS ATVI ATW AU AUQ AUY AVA AVD AVEO AVGO AVLR AVP AVT AVTR AVX AVY AW AWH AWI AXE AXELF AXL AXLL AXP AXS AXTA AY AYE AYI AYX AZN AZO AZUL BA BABA BAC BAESF BAGL BAM BANC BANR BAP BAX BB BBBY BBD BBEP BBT BBU BBY BC BCBP BCC BCE BCEI BCO BCR BDC BDK BDX BEAM BEAV BEC BEE BEN BER BF BG BGC BGP BHC BHE BHF BHI BHP BID BIDU BIG BIIB BIOF BIP BITA BIVV BJS BK BKC BKH BKI BKNG BKR BKS BKW BLK BLL BLT BMBLF BMC BMCH BMS BMY BNED BNI BNKJF BNS BNTGF BOH BOIVF BOKF BOL BP BPFH BPO BPOP BPY BR BRCM BRFS BRK BRL BRO BRP BRS BRY BSBR BSC BSX BTI BUD BURL BW BWA BWINB BWP BWXT BX BXE BXLT BXS BYD BYI BYND BZH C CA CAB CABJF CACC CACH CACI CAG CAH CAKE CALM CAM CAR CARE CARS CAT CB CBI CBIO CBRE CBS CBST CBT CBWBF CBY CC CCAP CCE CCG CCI CCK CCL CCO CCR CCRT CCS CDS CDW CEG CEIX CELG CEN CEO CEPH CF CFC CFFN CFG CFN CFRHF CFX CHB CHEF CHGG CHK CHKGF CHKP CHL CHNG CHPXF CHRS CHRW CHT CHTR CI CIM CINF CISN CIT CKH CKHUY CKSNF CL CLB CLD CLDR CLF CLH CLMT CLNS CLNY CLPR CLR CLX CMA CMCSA CMCSK CME CMG CMI CMLS CMP CMPR CMTL CNC CNDT CNHI CNI CNL CNO CNPAF CNQ CNR CNSWF CNW CNX COF COG COGN COIHF COL COLB COLD COMM CON CONN COOP COP COR CORE COST COT COTY COV COWN CP CPB CPF CPLG CPN CPRI CPRT CPWR CR CRAY CRESY CRI CRL CRM CRR CRYP CS CSC CSCO CSE CSG CSGP CSL CST CSWC CSX CTAS CTB CTL CTRP CTRX CTSH CTVA CTX CTXS CUB CVA CVBF CVCO CVE CVEO CVET CVH CVI CVRR CVS CVX CW CWEN CWGL CWH CX CXG CXO CXPO CXW CYD CYH CYN CYT CZR D DAL DAN DAR DB DBD DBI DBRN DCI DD DDAIF DDS DE DELL DENN DEO DESP DEST DF DFS DFZ DG DGX DHI DHIL DHR DIS DISCA DISCK DISH DJ DJCO DK DKS DLB DLMAF DLPH DLR DLRUF DLTR DMND DNA DNB DNOW DO DOOR DOV DOW DOX DPS DPTHL DPZ DRC DRI DSGX DSP DSSI DST DSWL DTV DUK DVA DVMT DVN DXC DXM DYN EA EAF EAT EBAY ECL ECPG EDS EDU EFX EGC EGL EGLE EGN EIG EIGI EIX EK EL ELAN ELN ELOS EMC EME EMN EMR ENDP ENH ENLC ENR ENS ENT ENWV ENZN EOG EP EPD EPL EQ EQC EQH EQIX EQNR EQT ERFSF EROS ES ESGR ESL ESNT ESRX ESS EST ESVIF ET ETE ETFC ETN ETP ETR EURN EVA EVHC EW EXC EXP EXPD EXPE EXPR F FACT FAF FANG FARM FAST FB FBHS FBN FBP FBTX FCAU FCE FCNCA FCX FD FDC FDML FDO FDS FDX FE FEIC FELE FEYE FFH FHB FI FICC FII FIS FISV FIT FITB FIVE FL FLA FLE FLEX FLIR FLML FLO FLR FLS FLT FLXN FMC FMCC FMX FN FNB FNF FNFG FNMA FO FOCS FOE FOSL FOX FOXA FPAC FPH FR FRED FRGI FRH FRNK FRSH FRX FSC FSGI FSLR FSP FST FSUMF FTCH FTDR FTE FTI FTNT FTO FTR FTV FUL FUR FWLT FWONA FWONK FWP FYR GAV GBGS GBL GBLBF GBX GCI GCVRZ GD GDI GE GENZ GEO GEOI GETVF GFG GFI GG GGG GGP GHC GHQ GIL GILD GIS GL GLBR GLF GLIBA GLPI GLPW GLRE GLT GLW GM GMALF GMCR GME GMT GNE GNRC GNRT GNTX GNW GOLD GOLF GOOG GOOGL GPC GPI GPK GPN GPS GPT GR GRA GRBK GRS GRUB GS GSHD GSK GSKY GSM GT GTIV GTS GTY GW GWR GWW GYI H HA HAE HAIN HAL HANS HAR HAS HBI HCA HCBK HCC HCMLF HCXLF HD HDS HE HEES HEGIF HEI HEK HENKY HEOP HES HEW HFC HGV HHC HIG HII HKHHF HLF HLI HLS HLT HLX HMA HMC HME HMHC HMN HNGR HNR HNT HNZ HOFD HOG HOLX HON HOS HOT HP HPE HPQ HPY HRB HRG HRI HRL HRS HRZ HSBC HSC HSNI HSP HST HSY HTCH HTH HTS HTV HTZ HUM HUN HURN HXL HYMLF I IAA IAAC IAC IAG IBKR IBM IBN ICE ICLR ICO IDCC IDIX IDT IDWM IDXX IEP IFF IGT IHG ILMN IM IMIAF IMOS IMS IN INFA INFN INFY ING INSP INT INTC INTL INTU INVA INWK INXN IP IPCR IPG IPGP IPI IPMLF IPXHF IPXL IQV IR IRC IRDM ...
