# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# # Dataroma
#
# https://www.dataroma.com/m/holdings.php?m=psc
#
# ### Target
#
# 1. Track holding history automatically.
#
# 2.
#
# # Yahoo Finance
#
# https://finance.yahoo.com/quote/CMG?p=CMG&.tsrc=fin-srch
#
# ### Target
#
# 1. Crawl the past price of the traget stock.
#
# 2. Combine the dataset sysmatically. -> Generate the right dataframe format as an output.
#
# 3. Compute the essential statistics with Python or R.

# %% [markdown]
# ### Inset Keywords

# %%
keywords = [i for i in input().split()]
# Out:
# A AA AABA AAIGF AAL AAN AAP AAPL AB ABB ABBC ABBV ABC ABCW ABEV ABFS ABG ABH ABKFQ ABM ABN ABR ABT ABV ACA ACBI ACCL ACF ACGL ACIW ACM ACMR ACN ACOPF ACT ACXM ADBE ADCT ADES ADI ADM ADNT ADP ADS ADSK ADT ADTN AEM AEO AEP AER AES AET AFI AFL AFSI AGCO AGN AGNC AGO AGP AGR AGU AGX AHL AHMIQ AHONY AIG AIN AIQ AIV AIZ AJG AJRD AKAM AKBA AKR ALA ALB ALC ALD ALDW ALEX ALGT ALK ALKS ALL ALLE ALLY ALNY ALR ALRM ALSN ALTR ALX ALXN AM AMAT AMBA AMCX AMD AME AMG AMGN AMGP AMH AMMD AMP AMR AMT AMTD AMV AMX AMZN AN ANAT ANDV ANET ANF ANFGF ANK ANSS ANTM ANV AON APA APC APD APFH APH APL APO APOL AR ARCO ARES AREX ARGKF ARIA ARII ARKAY ARMK ARNC ARO AROC ARRS ARW ASA ASCMA ASH ASPS ASTE AT ATGE ATI ATLS ATMI ATR ATRA ATSG ATUS ATVI ATW AU AUQ AUY AVA AVD AVEO AVGO AVLR AVP AVT AVX AVY AW AWH AWI AXE AXELF AXL AXLL AXP AXS AXTA AY AYE AYI AYX AZN AZO AZUL BA BABA BAC BAESF BAGL BAM BANC BANR BAP BAX BB BBBY BBD BBEP BBT BBU BBY BC BCBP BCC BCE BCEI BCO BCR BDC BDK BDX BEAM BEAV BEC BEE BEN BER BF BG BGC BGP BHC BHE BHF BHI BHP BID BIDU BIG BIIB BIOF BIP BITA BIVV BJS BK BKC BKH BKI BKNG BKR BKS BKW BLK BLL BLT BMBLF BMC BMCH BMS BMY BNED BNI BNKJF BNS BNTGF BOH BOIVF BOKF BOL BP BPFH BPO BPOP BPY BR BRCM BRFS BRK BRL BRO BRP BRS BRY BSBR BSC BSX BTI BUD BURL BW BWA BWINB BWP BWXT BX BXE BXLT BXS BYD BYI BYND BZH C CA CAB CABJF CACC CACH CACI CAG CAH CAKE CALM CAM CAR CARE CARS CAT CB CBI CBIO CBRE CBS CBST CBT CBWBF CBY CC CCE CCG CCI CCK CCL CCO CCR CCRT CCS CDS CDW CEG CEIX CELG CEN CEO CEPH CF CFC CFFN CFG CFN CFRHF CFX CHB CHEF CHGG CHK CHKGF CHKP CHL CHPXF CHRS CHRW CHT CHTR CI CIM CINF CISN CIT CKH CKHUY CKSNF CL CLB CLD CLDR CLF CLH CLMT CLNS CLNY CLPR CLR CLX CMA CMCSA CMCSK CME CMG CMI CMLS CMP CMPR CMTL CNC CNDT CNHI CNI CNL CNO CNPAF CNQ CNR CNSWF CNW CNX COF COG COGN COIHF COL COLB COLD COMM CONN COOP COP COR C
CSS SCT SCU SD SDRL SE SEA SEAS SEB SEE SEIC SEMI SERV SFD SFI SFLY SFTBF SFY SGEN SGMS SGP SGU SHA SHLD SHLDQ SHOP SHOS SHPG SHW SIG SIGI SINA SIRI SIRO SITE SIVB SJM SJT SKM SKS SKX SLB SLCA SLE SLGN SLH SLM SLRC SM SMCG SMCI SMG SMH SMMX SMTGF SNA SNAP SNE SNI SNN SNR SNY SO SODA SPB SPG SPGI SPH SPLS SPMD SPNC SPR SPWH SPXC SQ SRCL SRE SRG SRSC SSE SSNC SSW ST STBZ STE STEI STI STJ STKL STL STNE STNG STOR STRA STRP STRZA STT STX STZ SU SUG SUM SUN SUNE SWCEY SWI SWK SWKS SWN SWY SXT SYA SYF SYK SYMS SYNA SYT SYY T TA TAK TAM TAP TBBK TBIO TBPH TCF TCO TCW TDC TDG TDS TDW TECD TECH TECK TEG TEL TEN TER TERP TEVA TEX TFC TFSL TFX TGI TGNA TGP TGT THO THS TIBX TIF TIME TJX TKOMY TKR TKTM TLM TLRD TM TMDX TMH TMHC TMO TMS TMUS TNET TOH TOKSF TOO TOT TOWN TPCO TPH TPHS TPIC TPR TPX TQNT TRA TRB TRC TRCO TRGP TRH TRIP TRMB TRMD TRN TROW TRQ TRU TRV TRW TRWH TSCDF TSCO TSG TSL TSLA TSM TT TTC TTD TTF TTM TTWO TUP TV TVTY TW TWC TWI TWTR TWX TX TXN TYC TYIDF UA UAL UAUA UBS UBSH UCO UFI UFPI UFS UGI UHAL UHR UHS UI UIL UL ULTA ULTR UMPQ UN UNF UNH UNM UNP UNT UNVR UOVEY UPL UPS URBN URI URS USB USBE USEC USFD USG USMO USTR UTIW UTSI UVV UWBK V VAL VALE VAR VC VCI VEC VECO VEON VFC VG VIAB VIAC VICI VIV VIVEF VLO VLTC VMC VMED VMI VMW VNO VNOM VOD VOPKF VOXX VOYA VPHM VR VRNT VRRM VRS VRSK VRSN VRTV VRUS VSAT VSH VSI VST VSTO VVV VWR VZ W WAB WAC WAFD WAIR WAT WB WBA WBC WBMD WBT WCBO WCC WCG WCN WDC WEC WEN WERN WFC WFM WFR WFT WH WHR WINN WIX WK WLK WLT WLTW WM WMB WMGI WMS WMT WNG WNR WOSCF WP WPC WPG WPP WPS WPX WPZ WR WRB WRK WSBF WSC WTM WTRH WU WWW WWY WY WYE WYN WYNN X XCO XEC XELT XL XLE XLNX XLS XOM XON XPO XRAY XRX XTEX XTO XTXI XYL Y YELP YHOO YPF YUM ZAYO ZBH ZBRA ZEUS ZFSVF ZINC ZION ZLC ZNT ZQK ZTO ZTS

# %% [markdown]
# ### Selenium

# %%
import requests
from bs4 import BeautifulSoup
import sys
import codecs
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
import requests
import time
from fake_useragent import UserAgent
import csv
import pandas as pd

# %% [markdown]
# ### Use try & except

# %%
#Use fake UserAgent
def set_header_user_agent():
    user_agent = UserAgent()
    return user_agent.random

#open browser #打開瀏覽器，但不要載入圖片
options = webdriver.ChromeOptions()
prefs = {
    'profile.default_content_setting_values': {
        'images': 2,
        #'javascript': 2
    }
}
options.add_experimental_option('prefs', prefs)

#ua = "Mozilla/5.0 (Windows NT 10.0; WOW64; rv:53.0) Gecko/20100101 Firefox/53.0"
#headers = {'User-Agent': 'User-Agent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36'}
#user_agent = set_header_user_agent()
#headers={ 'user-agent': user_agent }
#options.add_argument("user-agent={}".format(user_agent)) # 使用偽造的 user-agent
#options.add_argument(headers)

driver = webdriver.Chrome('./chromedriver', chrome_options=options)


#define urls
url = 'https://finance.yahoo.com/quote/'

#for loop
i = 1
for keyword in keywords:
    
    try:

        #hist url
        hist_url = url+keyword+"/history?p="+keyword

        #開啟網頁
        driver.get(hist_url)
        driver.implicitly_wait(5)

        #點日期
        driver.find_element_by_xpath("""//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[1]/div[1]/div[1]/div/div/div/span""").click()
        driver.implicitly_wait(5)
        #time.sleep(0.5)
        #點max
        driver.find_element_by_xpath("""//*[@id="dropdown-menu"]/div/ul[2]/li[4]/button/span""").click()
        driver.implicitly_wait(5)
        #time.sleep(0.5)

        #點frequency
        #driver.find_element_by_xpath("""//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[1]/div[1]/div[3]/span/div/svg""").click()
        #driver.find_element_by_xpath("""//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[1]/div[1]/div[3]/span/div/span/span""").click()
        #點apply
        driver.find_element_by_xpath("""//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[1]/div[1]/button/span""").click()
        driver.implicitly_wait(20)
        #time.sleep(0.5)

        #html parse 抓下載檔案的網址
        hist_soup = BeautifulSoup(driver.page_source, 'html.parser')
        links = hist_soup.select(".Fl(end).Mt(3px).Cur(p)") #帶有空格的class需要用.來取

        #CSV file link
        csv_url = links[0]['href']
        df = pd.read_csv(csv_url)
        df = df[['Date','Close']]
        df.rename(columns={'Close':keyword}, inplace=True) #rename the column after the specific stock

        #把某支股票的歷史價格存成csv檔
        file_path = "prices/" + keyword+".csv"
        df.to_csv(file_path, index=False)
        
        #assign不同的股票到不同的dataframe, 迴圈跑完要merge在一起
        names = locals()
        names['df%s' % i] = df
        i+=1
    
    except:
        i+=1
    #time.sleep(1)

#df = df1 #df是最後要的pooled的dataFrame，先assign成df1，再逐個跟其後的合併
#for j in range(2, i):
#    df = pd.merge(df, names['df%s' % j], how = 'left', on = ["Date"])
    #check how to use pd.merge() in the ref: 
    #https://pandas-docs.github.io/pandas-docs-travis/user_guide/merging.html

#df = df1
#for j in range(2, len(keywords)+1):
#    try:
#        df = pd.merge(df, names['df%s' % j], how = 'left', on = ["Date"])
#    except:
#        print("missing df"+j)
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:23: DeprecationWarning: use options instead of chrome_options

# %%
df.head()
# Out:
#          Date       AAN
# 0  1982-11-04  1.012346
# 1  1982-11-05  1.024691
# 2  1982-11-08  1.037037
# 3  1982-11-09  1.037037
# 4  1982-11-10  1.074074

# %%
df = df1
count = 0
for j in range(2, len(keywords)+1):
    try:
        df = pd.merge(df, names['df%s' % j], how = 'left', on = ["Date"])
    except:
        count+=1
        print("missing df"+str(j))
print("total missing: ", str(count))
# Out:
# missing df127
# missing df129
# missing df133
# missing df137
# missing df139
# missing df144
# missing df149
# missing df165
# missing df176
# missing df177
# missing df182
# missing df197
# missing df206
# missing df207
# missing df216
# missing df221
# missing df223
# missing df226
# missing df235
# missing df239
# missing df243
# missing df250
# missing df251
# missing df254
# missing df258
# missing df261
# missing df262
# missing df271
# missing df275
# missing df281
# missing df291
# missing df295
# missing df296
# missing df299
# missing df313
# missing df323
# missing df326
# missing df329
# missing df335
# missing df341
# missing df344
# missing df349
# missing df352
# missing df374
# missing df1778
# missing df1782
# missing df1786
# missing df1788
# missing df1793
# missing df1797
# missing df1804
# missing df1806
# missing df1813
# missing df1820
# missing df1821
# missing df1823
# missing df1830
# missing df1841
# missing df1842
# missing df1845
# missing df1847
# missing df1851
# missing df1853
# missing df1857
# missing df1858
# missing df1859
# missing df1863
# missing df1871
# missing df1873
# missing df1874
# missing df1875
# total missing:  318

# %%
df.head()
# Out:
#          Date          A         AA       AABA  AAIGF  AAL       AAN  AAP  \
# 0  1999-11-18  31.473534  74.973602  53.468750    NaN  NaN  5.185185  NaN
# 1  1999-11-19  28.880543  76.319283  54.687500    NaN  NaN  5.185185  NaN
# 2  1999-11-22  31.473534  77.376602  56.703125    NaN  NaN  4.962963  NaN
# 3  1999-11-23  28.612303  78.193619  55.296875    NaN  NaN  4.814815  NaN
# 4  1999-11-24  29.372318  77.100258  57.750000    NaN  NaN  4.703704  NaN
#
#        AAPL       AB ...      YPF       YUM  ZAYO  ZBH       ZBRA   ZEUS  \
# 0  3.200893  32.2500 ...   37.875  7.750719   NaN  NaN  27.611111  5.250
# 1  3.301339  32.1250 ...   38.250  7.638390   NaN  NaN  27.833334  5.000
# 2  3.236607  31.3125 ...   38.625  7.514827   NaN  NaN  27.416666  5.000
# 3  3.314732  31.0625 ...   38.625  7.391265   NaN  NaN  26.458334  5.000
# 4  3.381696  30.8125 ...   38.750  7.211538   NaN  NaN  27.027779  4.875
#
#    ZFSVF     ZION  ZTO  ZTS
# 0    NaN  64.5000  NaN  NaN
# 1    NaN  64.6250  NaN  NaN
# 2    NaN  63.8125  NaN  NaN
# 3    NaN  62.5000  NaN  NaN
# 4    NaN  62.8750  NaN  NaN
#
# [5 rows x 1560 columns]

# %%
df.tail()
# Out:
#             Date          A    AA  AABA  AAIGF    AAL        AAN         AAP  \
# 5145  2020-05-04  74.559998  7.80   NaN   8.60   9.82  30.959999  120.110001
# 5146  2020-05-05  76.370003  7.81   NaN   8.68   9.51  29.400000  121.190002
# 5147  2020-05-06  77.870003  7.71   NaN   8.83   9.25  28.799999  121.160004
# 5148  2020-05-07  78.500000  7.49   NaN   8.82   9.54  33.349998  119.610001
# 5149  2020-05-08  79.709999  8.07   NaN   8.89  10.14  35.779999  124.849998
#
#             AAPL         AB     ...       YPF        YUM  ZAYO         ZBH  \
# 5145  293.160004  22.540001     ...      3.71  83.089996   NaN  114.070000
# 5146  297.559998  22.260000     ...      3.66  83.279999   NaN  118.019997
# 5147  300.630005  21.900000     ...      3.61  83.169998   NaN  115.879997
# 5148  303.739990  22.600000     ...      3.85  84.599998   NaN  119.400002
# 5149  310.130005  22.799999     ...      4.05  86.180000   NaN  121.860001
#
#             ZBRA  ZEUS       ZFSVF       ZION        ZTO         ZTS
# 5145  228.770004  9.42  302.079987  30.670000  27.580000  127.440002
# 5146  233.149994  9.29  300.000000  30.180000  28.570000  131.300003
# 5147  232.419998  8.69  296.000000  29.879999  28.920000  125.690002
# 5148  233.860001  8.90  297.920013  29.570000  29.889999  124.239998
# 5149  242.919998  9.77  301.649994  30.719999  31.150000  125.470001
#
# [5 rows x 1560 columns]

# %% [markdown]
# # Save Files

# %%
df.to_csv('ALL_Prices.csv', index=False)
